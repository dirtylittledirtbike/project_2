# %%
import pandas as pd
import numpy as np
import re

# %%
df1 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/chicago_il.csv')
df2 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/evanston_il.csv')
df3 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/glenview_il.csv')
df4 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/naperville_il.csv')
df5 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/oak_park_il.csv')
df6 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/skokie_il.csv')
df7 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/cicero_il.csv')
df8 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/oak_lawn_il.csv')

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8]).drop(columns=['Unnamed: 0']).reset_index()
df.groupby('URL').size().value_counts()
# Out:
# 1    2596
# 2       7
# dtype: int64

# %%
df.groupby('Address').size().value_counts()
# Out:
# 1    2590
# 2      10
# dtype: int64

# %%
# there are a few duplicate urls so we will drop those
df.drop_duplicates(subset=['URL'], inplace=True)

# %%
df.replace(to_replace=['None', 'No Data'], value=np.nan, inplace=True)

# %%
df.isna().sum()
# Out:
# index                    0
# Type                     0
# Year built              89
# Heating                289
# Cooling                535
# Parking                254
# HOA                   1554
# Price/sqft             546
# Total Price              0
# Address                  0
# Square Feet            365
# New construction         0
# Bedrooms                 2
# Bathrooms               10
# Full bathrooms         207
# neighborhood_stats       0
# URL                      0
# Lot                   1273
# Half bathrooms        1621
# Status                2226
# dtype: int64

# %%
def acres_to_sqft(x):
    if isinstance(x, list):
        if 'acres' in x:
            sqft = float(x[0]) * 43560
            return round(sqft, 2)
        else:
            return float(x[0].replace(',',''))
    else:
        return x
    
    
def sqft_to_int(x):
    if isinstance(x, str):
        if x != '--':
            x_formatted = re.sub("[^0-9]", "", x)
            return int(x_formatted)
        else:
            return np.nan
    else:
        return x
    
    
def group_cooling(x):
    a = 'Central, Geothermal, Other'
    b = 'Geothermal'
    c = 'Central, Refrigeration'
    d = 'Geothermal, Other'
    if x == a:
        return 'Other'
    elif x == b:
        return 'Other'
    elif x == c:
        return 'Other'
    elif x == d:
        return 'Other'
    else:
        return x

# get the historic median neighborhood price for property
def get_median_value(x):
    median = x.split('.')[-2]
    median2 = median.split(' is ')
    char = median2[0][0:10]
    val =  median2[-1]
    val_formatted = int(re.sub('[^0-9]', '', val))
    return val_formatted

def get_zip(x):
    test = x.split(',')
    city_zip = test[-1].split(' ')
    return city_zip[-1]


# df['zip'] = df.Address.apply(get_zip)


df['Total Price'] = df['Total Price'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)
df['zip'] = df.Address.apply(get_zip)
df['Square Feet'] = df['Square Feet'].apply(sqft_to_int)
df['HOA'] = df['HOA'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)
df['HOA'] = df['HOA'].apply(lambda x: 'Yes' if np.isnan(x) else 'No')
df['Bedrooms'] = df['Bedrooms'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)
df['Bathrooms'] = df['Bathrooms'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)
df['Full bathrooms'] = df['Full bathrooms'].apply(lambda x: int(x) if isinstance(x, str) else x)
df['Half bathrooms'].fillna(0, inplace=True)
df['Half bathrooms'] = df['Half bathrooms'].astype(int)
df['Year built'] = df['Year built'].apply(lambda x: int(x) if isinstance(x, str) else x)
df['Cooling'] = df.Cooling.replace('Refrigerator', 'Refrigeration')
df.Cooling.fillna('None', inplace=True)
df['Lot'] = df['Lot'].apply(lambda x: x.lower() if isinstance(x, str) else x)
df['Lot Temp'] = df['Lot'].str.split(' ')
df['Lot'] = df['Lot Temp'].apply(acres_to_sqft)
df['Cooling'] = df.Cooling.apply(group_cooling)
df['median_nhv2'] = df.neighborhood_stats.apply(get_median_value)
# df['median_nhv'] = df.groupby(['zip', 'Type'])['Total Price'].transform('median')

#imputing missing year built values with median for that zip code
year_built_dict = dict(df.groupby('zip')['Year built'].median())
df['Year built'] = df['Year built'].fillna(df.zip.map(year_built_dict))
df['Bathrooms'].fillna(df.Bathrooms.median(), inplace=True)
df.drop(columns=['Lot Temp', 'Price/sqft', 'index', 'Status'], inplace=True)

# %%
for item in df.columns.to_list():
    print(item + ':')
    print(df[item].value_counts())
    print()
# Out:
# Type:
# Single Family            1285
# Condo                     917
# Townhouse                 195
# Multi Family              107
# Multiple Occupancy         93
# Mobile / Manufactured       4
# Apartment                   1
# Miscellaneous               1
# Name: Type, dtype: int64
#
# Year built:
# 2020.0    120
# 2005.0     63
# 2006.0     61
# 2008.0     47
# 2004.0     46
#          ...
# 1930.5      1
# 1935.0      1
# 1868.0      1
# 1925.5      1
# 1875.0      1
# Name: Year built, Length: 152, dtype: int64
#
# Heating:
# Forced air                              860
# Forced air, Gas                         574
# Gas                                     501
# Baseboard                                78
# Other                                    65
# Electric                                 51
# Radiant                                  29
# Forced air, Electric                     28
# Baseboard, Gas                           27
# Other, Gas                               19
# Electric, Gas                            15
# Radiant, Gas                             10
# Forced air, Electric, Gas                 6
# Other, Radiant                            4
# Heat pump                                 4
# Forced air, Other                         4
# Baseboard, Forced air                     4
# Forced air, Heat pump                     3
# Forced air, Radiant                       3
# Other, Electric                           3
# Baseboard, Forced air, Electric, Gas      2
# Baseboard, Radiant                        2
# Baseboard, Electric                       2
# Baseboard, Radiant, Gas                   2
# Forced air, Solar                         1
# Radiant, Other                            1
# Forced air, Propane / Butane              1
# Baseboard, Electric, Gas                  1
# Gas, Other                                1
# Forced air, Radiant, Gas                  1
# Radiant, Electric                         1
# Forced air, Stove                         1
# Baseboard, Other                          1
# Forced air, Heat pump, Other              1
# Baseboard, Heat pump, Electric            1
# Baseboard, Forced air, Gas                1
# Solar                                     1
# Forced air, Wall                          1
# Wall, Electric                            1
# None, Baseboard                           1
# None, Forced air                          1
# Forced air, Heat pump, Other, Gas         1
# Name: Heating, dtype: int64
#
# Cooling:
# Central          1909
# None              535
# Wall               74
# Other              55
# Refrigeration      30
# Name: Cooling, dtype: int64
#
# Parking:
# 2 spaces           1178
# 1 space             769
# 3 spaces            232
# 4 spaces             78
# 6 spaces             20
# 5 spaces             14
# Attached Garage      14
# 10 spaces             7
# 7 spaces              6
# 8 spaces              6
# 42 spaces             5
# Detached Garage       5
# 9 spaces              3
# 12 spaces             2
# 11 spaces             1
# 38 spaces             1
# On street             1
# Off street            1
# 13 spaces             1
# 14 spaces             1
# 17 spaces             1
# 20 spaces             1
# 31 spaces             1
# 21 spaces             1
# Name: Parking, dtype: int64
#
# HOA:
# Yes    1554
# No     1049
# Name: HOA, dtype: int64
#
# Total Price:
# 350000.0    21
# 299900.0    18
# 599000.0    18
# 299000.0    17
# 249900.0    17
#             ..
# 505000.0     1
# 231670.0     1
# 269737.0     1
# 770000.0     1
# 512000.0     1
# Name: Total Price, Length: 1137, dtype: int64
#
# Address:
# 8621 Monticello Ave, Skokie, IL 60076           2
# (Undisclosed Address), Chicago, IL 60628        2
# 9525 Meade Ave, Oak Lawn, IL 60453              2
# 814 Dobson St #1W, Evanston, IL 60202           1
# 735 Pleasant Ln, Glenview, IL 60025             1
#                                                ..
# 125 N Euclid Ave APT 404, Oak Park, IL 60301    1
# 7S409 Arbor Dr, Naperville, IL 60540            1
# 422 Elmwood Ave #1, Evanston, IL 60202          1
# 3240 Barnes Ln, Naperville, IL 60564            1
# 616 W Fulton St APT 504, Chicago, IL 60661      1
# Name: Address, Length: 2600, dtype: int64
#
# Square Feet:
# 1200.0    61
# 1000.0    55
# 1100.0    36
# 900.0     34
# 1300.0    33
#           ..
# 2022.0     1
# 1426.0     1
# 1343.0     1
# 2098.0     1
# 2619.0     1
# Name: Square Feet, Length: 1181, dtype: int64
#
# New construction:
#  No     2433
#  Yes     170
# Name: New construction, dtype: int64
#
# Bedrooms:
# 3.0     707
# 2.0     621
# 4.0     579
# 5.0     276
# 1.0     214
# 6.0     115
# 7.0      32
# 8.0      22
# 9.0      12
# 0.0      11
# 10.0      6
# 11.0      5
# 12.0      1
# Name: Bedrooms, dtype: int64
#
# Bathrooms:
# 2.0     959
# 3.0     622
# 1.0     494
# 4.0     277
# 5.0     144
# 6.0      70
# 7.0      16
# 8.0      15
# 9.0       3
# 10.0      1
# 11.0      1
# 0.0       1
# Name: Bathrooms, dtype: int64
#
# Full bathrooms:
# 2.0    1102
# 1.0     606
# 3.0     416
# 4.0     156
# 5.0      78
# 6.0      26
# 7.0       9
# 8.0       2
# 9.0       1
# Name: Full bathrooms, dtype: int64
#
# neighborhood_stats:
# Home values in 60453 have risen 1.3 % (↑) over the past 12 months.Zillow predicts the home values in 60453 will increase 1.3% (↑) in the next year.This home is valued 18.7% higher (↑) than the median home in 60453.The median Zestimate® for this neighborhood is $210,544.                                                3
# Home values in 60302 have fallen 4.6 % (↓) over the past 12 months.Zillow predicts the home values in 60302 will fall 4.5% (↓) in the next year.This home is valued 23.5% higher (↑) than the median home in 60302.The median Zestimate® for this neighborhood is $425,027.                                                   3
# Home values in 60304 have fallen 4.6 % (↓) over the past 12 months.Zillow predicts the home values in 60304 will fall 4.3% (↓) in the next year.This home is valued 15% higher (↑) than the median home in 60304.The median Zestimate® for this neighborhood is $369,676.                                                     3
# Home values in 60302 have fallen 4.6 % (↓) over the past 12 months.Zillow predicts the home values in 60302 will fall 4.5% (↓) in the next year.This home is valued 35.3% higher (↑) than the median home in 60302.The median Zestimate® for this neighborhood is $425,027.                                                   3
# Home values in 60302 have fallen 4.6 % (↓) over the past 12 months.Zillow predicts the home values in 60302 will fall 4.5% (↓) in the next year.This home is valued 29.7% lower (↓) than the median home in 60302.The median Zestimate® for this neighborhood is $425,027.                                                    3
#                                                                                                                                                                                                                                                                                                                              ..
# Home values in Wrightwood Neighbors have risen 0.6 % (↑) over the past 12 months.Zillow predicts the home values in Wrightwood Neighbors will decrease 0.5% (↓) in the next year.This home is valued 41.7% lower (↓) than the median home in Wrightwood Neighbors.The median Zestimate® for this neighborhood is $677,229.    1
# Home values in 60620 have risen 0.6 % (↑) over the past 12 months.Zillow predicts the home values in West Chatham will fall 1.9% (↓) in the next year.This home is valued 92.1% higher (↑) than the median home in West Chatham.The median Zestimate® for this neighborhood is $130,070.                                      1
# Home values in 60453 have risen 1.3 % (↑) over the past 12 months.Zillow predicts the home values in 60453 will rise 1.3% (↑) in the next year.This home is valued 4.8% lower (↓) than the median home in 60453.The median Zestimate® for this neighborhood is $210,544.                                                      1
# Home values in 60540 have risen 1.0 % (↑) over the past 12 months.Zillow predicts the home values in 60540 will rise 1.3% (↑) in the next year.This home is valued 1.4% higher (↑) than the median home in 60540.The median Zestimate® for this neighborhood is $413,252.                                                     1
# Home values in 60025 have fallen 3.1 % (↓) over the past 12 months.Zillow predicts the home values in 60025 will decrease 3.6% (↓) in the next year.This home is valued 677.8% higher (↑) than the median home in 60025.The median Zestimate® for this neighborhood is $462,196.                                              1
# Name: neighborhood_stats, Length: 2445, dtype: int64
#
# URL:
# https://www.zillow.com/homedetails/1212-N-Lombard-Ave-Oak-Park-IL-60302/3797830_zpid/           1
# https://www.zillow.com/homedetails/301-S-Euclid-Ave-Oak-Park-IL-60302/3806304_zpid/             1
# https://www.zillow.com/homedetails/745-W-Wellington-Ave-APT-3-Chicago-IL-60657/3720449_zpid/    1
# https://www.zillow.com/homedetails/6325-W-Berenice-Ave-Chicago-IL-60634/3658829_zpid/           1
# https://www.zillow.com/homedetails/1032-Bette-Ln-Glenview-IL-60025/3350652_zpid/                1
#                                                                                                ..
# https://www.zillow.com/homedetails/1433-S-60th-Ct-Cicero-IL-60804/3821004_zpid/                 1
# https://www.zillow.com/homedetails/8800-Lowell-Ter-Skokie-IL-60076/3523640_zpid/                1
# https://www.zillow.com/homedetails/5519-S-Throop-St-Chicago-IL-60636/2132471437_zpid/           1
# https://www.zillow.com/homedetails/936-Douglas-Ave-Naperville-IL-60540/4506436_zpid/            1
# https://www.zillow.com/homedetails/5015-2-W-31st-Pl-Cicero-IL-60804/2078055100_zpid/            1
# Name: URL, Length: 2603, dtype: int64
#
# Lot:
# 3750.0     29
# 11325.6    26
# 3920.0     24
# 10890.0    23
# 11761.2    20
#            ..
# 7570.0      1
# 5771.0      1
# 3650.0      1
# 10497.0     1
# 8555.0      1
# Name: Lot, Length: 631, dtype: int64
#
# Half bathrooms:
# 0    1621
# 1     889
# 2      83
# 3      10
# Name: Half bathrooms, dtype: int64
#
# zip:
# 60302    234
# 60025    221
# 60453    185
# 60201    147
# 60202    132
#         ...
# 60093      3
# 60633      2
# 60602      1
# 43147      1
# 60604      1
# Name: zip, Length: 75, dtype: int64
#
# median_nhv2:
# 425027    234
# 462196    221
# 210544    185
# 498460    147
# 329995    132
#          ...
# 92849       1
# 248475      1
# 191129      1
# 271872      1
# 382923      1
# Name: median_nhv2, Length: 160, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(df.Parking, bins=15);
plt.xticks(rotation=90);

# %%
df.Parking.isna().sum()
# Out:
# 254

# %%
df.drop(columns=['Lot'], inplace=True)

# %%
df['Parking_Binned'] = df.Parking.apply(lambda x: 'Yes' if isinstance(x, str) else 'No')

# %%
df
# Out:
#                Type  Year built          Heating        Cooling   Parking  \
# 0             Condo      1910.0              Gas        Central       NaN
# 1     Single Family      1957.0       Forced air        Central  2 spaces
# 2             Condo      2007.0       Forced air        Central       NaN
# 3             Condo      2008.0              Gas        Central  2 spaces
# 4     Single Family      1971.0       Forced air        Central  4 spaces
# ...             ...         ...              ...            ...       ...
# 2605          Condo      2005.0       Forced air        Central   1 space
# 2606  Single Family      1973.0              Gas        Central  2 spaces
# 2607          Condo      1973.0            Other  Refrigeration   1 space
# 2608  Single Family      1949.0  Forced air, Gas        Central  2 spaces
# 2609          Condo      1983.0       Forced air        Central  2 spaces
#
#       HOA  Total Price                                          Address  \
# 0      No     249900.0          5329 S Harper Ave #2, Chicago, IL 60615
# 1     Yes     399000.0              7144 N Ozark Ave, Chicago, IL 60631
# 2      No     169898.0     1673 W Farwell Ave APT 1S, Chicago, IL 60626
# 3      No     489900.0  1400 S Michigan Ave APT 2203, Chicago, IL 60605
# 4     Yes     389000.0            10606 S Leavitt St, Chicago, IL 60643
# ...   ...          ...                                              ...
# 2605   No     168999.0      9440 S 51st Ave APT 502, Oak Lawn, IL 60453
# 2606  Yes     399900.0            9246 S Keeler Ave, Oak Lawn, IL 60453
# 2607   No      94500.0       4929 W 87th St APT 3NW, Oak Lawn, IL 60453
# 2608  Yes     249900.0               9117 S 53rd Ct, Oak Lawn, IL 60453
# 2609   No     124900.0       4003 W 105th St APT 3W, Oak Lawn, IL 60453
#
#       Square Feet New construction  Bedrooms  Bathrooms  Full bathrooms  \
# 0          1000.0               No       2.0        2.0             2.0
# 1          1224.0               No       2.0        2.0             2.0
# 2           775.0               No       2.0        1.0             1.0
# 3          1273.0               No       2.0        2.0             2.0
# 4          2179.0               No       3.0        3.0             2.0
# ...           ...              ...       ...        ...             ...
# 2605       1052.0               No       1.0        1.0             1.0
# 2606       3400.0               No       4.0        3.0             3.0
# 2607        852.0               No       2.0        1.0             1.0
# 2608       1343.0               No       3.0        2.0             1.0
# 2609       1000.0               No       2.0        2.0             2.0
#
#                                      neighborhood_stats  \
# 0     Home values in Hyde Park have risen 0.6 % (↑) ...
# 1     Home values in Edison Park have risen 0.6 % (↑...
# 2     Home values in Rogers Park have risen 0.6 % (↑...
# 3     Home values in South Loop have risen 0.6 % (↑)...
# 4     Home values in Beverly have risen 0.6 % (↑) ov...
# ...                                                 ...
# 2605  Home values in 60453 have risen 1.3 % (↑) over...
# 2606  Home values in 60453 have risen 1.3 % (↑) over...
# 2607  Home values in 60453 have risen 1.3 % (↑) over...
# 2608  Home values in 60453 have risen 1.3 % (↑) over...
# 2609  Home values in 60453 have risen 1.3 % (↑) over...
#
#                                                     URL  Half bathrooms  \
# 0     https://www.zillow.com/homedetails/5329-S-Harp...               0
# 1     https://www.zillow.com/homedetails/7144-N-Ozar...               0
# 2     https://www.zillow.com/homedetails/1673-W-Farw...               0
# 3     https://www.zillow.com/homedetails/1400-S-Mich...               0
# 4     https://www.zillow.com/homedetails/10606-S-Lea...               1
# ...                                                 ...             ...
# 2605  https://www.zillow.com/homedetails/9440-S-51st...               0
# 2606  https://www.zillow.com/homedetails/9246-S-Keel...               0
# 2607  https://www.zillow.com/homedetails/4929-W-87th...               0
# 2608  https://www.zillow.com/homedetails/9117-S-53rd...               1
# 2609  https://www.zillow.com/homedetails/4003-W-105t...               0
#
#         zip  median_nhv2 Parking_Binned
# 0     60615       396553             No
# 1     60631       356353            Yes
# 2     60626       226102             No
# 3     60605       376901            Yes
# 4     60643       346385            Yes
# ...     ...          ...            ...
# 2605  60453       210544            Yes
# 2606  60453       210544            Yes
# 2607  60453       210544            Yes
# 2608  60453       210544            Yes
# 2609  60453       210544            Yes
#
# [2603 rows x 19 columns]

# %%
df.Type.value_counts()
# Out:
# Single Family            1285
# Condo                     917
# Townhouse                 195
# Multi Family              107
# Multiple Occupancy         93
# Mobile / Manufactured       4
# Apartment                   1
# Miscellaneous               1
# Name: Type, dtype: int64

# %%
df['Full bathrooms'].fillna(0, inplace=True)
df['Bathrooms_adj'] = abs(df['Bathrooms'] - df['Full bathrooms'])
df['Bedrooms'].fillna(df.Bedrooms.median(), inplace=True)

# %%
df_final = df[(df['Type'] != 'Miscellaneous') & (df['Type'] != 'Apartment') & (df.zip != '43147')].copy()

# %%
plt.hist(df_final['Square Feet'])
# Out:
# (array([875., 719., 319., 186.,  59.,  39.,  14.,   5.,  11.,   8.]),
#  array([  400. ,  1409.5,  2419. ,  3428.5,  4438. ,  5447.5,  6457. ,
#          7466.5,  8476. ,  9485.5, 10495. ]),
#  <BarContainer object of 10 artists>)

# %%
df_final.isna().sum()
# Out:
# Type                    0
# Year built              0
# Heating               288
# Cooling                 0
# Parking               254
# HOA                     0
# Total Price             0
# Address                 0
# Square Feet           365
# New construction        0
# Bedrooms                0
# Bathrooms               0
# Full bathrooms          0
# neighborhood_stats      0
# URL                     0
# Half bathrooms          0
# zip                     0
# median_nhv2             0
# Parking_Binned          0
# Bathrooms_adj           0
# dtype: int64

# %%
df_final.drop(columns=['Parking'])
# Out:
#                Type  Year built          Heating        Cooling  HOA  \
# 0             Condo      1910.0              Gas        Central   No
# 1     Single Family      1957.0       Forced air        Central  Yes
# 2             Condo      2007.0       Forced air        Central   No
# 3             Condo      2008.0              Gas        Central   No
# 4     Single Family      1971.0       Forced air        Central  Yes
# ...             ...         ...              ...            ...  ...
# 2605          Condo      2005.0       Forced air        Central   No
# 2606  Single Family      1973.0              Gas        Central  Yes
# 2607          Condo      1973.0            Other  Refrigeration   No
# 2608  Single Family      1949.0  Forced air, Gas        Central  Yes
# 2609          Condo      1983.0       Forced air        Central   No
#
#       Total Price                                          Address  \
# 0        249900.0          5329 S Harper Ave #2, Chicago, IL 60615
# 1        399000.0              7144 N Ozark Ave, Chicago, IL 60631
# 2        169898.0     1673 W Farwell Ave APT 1S, Chicago, IL 60626
# 3        489900.0  1400 S Michigan Ave APT 2203, Chicago, IL 60605
# 4        389000.0            10606 S Leavitt St, Chicago, IL 60643
# ...           ...                                              ...
# 2605     168999.0      9440 S 51st Ave APT 502, Oak Lawn, IL 60453
# 2606     399900.0            9246 S Keeler Ave, Oak Lawn, IL 60453
# 2607      94500.0       4929 W 87th St APT 3NW, Oak Lawn, IL 60453
# 2608     249900.0               9117 S 53rd Ct, Oak Lawn, IL 60453
# 2609     124900.0       4003 W 105th St APT 3W, Oak Lawn, IL 60453
#
#       Square Feet New construction  Bedrooms  Bathrooms  Full bathrooms  \
# 0          1000.0               No       2.0        2.0             2.0
# 1          1224.0               No       2.0        2.0             2.0
# 2           775.0               No       2.0        1.0             1.0
# 3          1273.0               No       2.0        2.0             2.0
# 4          2179.0               No       3.0        3.0             2.0
# ...           ...              ...       ...        ...             ...
# 2605       1052.0               No       1.0        1.0             1.0
# 2606       3400.0               No       4.0        3.0             3.0
# 2607        852.0               No       2.0        1.0             1.0
# 2608       1343.0               No       3.0        2.0             1.0
# 2609       1000.0               No       2.0        2.0             2.0
#
#                                      neighborhood_stats  \
# 0     Home values in Hyde Park have risen 0.6 % (↑) ...
# 1     Home values in Edison Park have risen 0.6 % (↑...
# 2     Home values in Rogers Park have risen 0.6 % (↑...
# 3     Home values in South Loop have risen 0.6 % (↑)...
# 4     Home values in Beverly have risen 0.6 % (↑) ov...
# ...                                                 ...
# 2605  Home values in 60453 have risen 1.3 % (↑) over...
# 2606  Home values in 60453 have risen 1.3 % (↑) over...
# 2607  Home values in 60453 have risen 1.3 % (↑) over...
# 2608  Home values in 60453 have risen 1.3 % (↑) over...
# 2609  Home values in 60453 have risen 1.3 % (↑) over...
#
#                                                     URL  Half bathrooms  \
# 0     https://www.zillow.com/homedetails/5329-S-Harp...               0
# 1     https://www.zillow.com/homedetails/7144-N-Ozar...               0
# 2     https://www.zillow.com/homedetails/1673-W-Farw...               0
# 3     https://www.zillow.com/homedetails/1400-S-Mich...               0
# 4     https://www.zillow.com/homedetails/10606-S-Lea...               1
# ...                                                 ...             ...
# 2605  https://www.zillow.com/homedetails/9440-S-51st...               0
# 2606  https://www.zillow.com/homedetails/9246-S-Keel...               0
# 2607  https://www.zillow.com/homedetails/4929-W-87th...               0
# 2608  https://www.zillow.com/homedetails/9117-S-53rd...               1
# 2609  https://www.zillow.com/homedetails/4003-W-105t...               0
#
#         zip  median_nhv2 Parking_Binned  Bathrooms_adj
# 0     60615       396553             No            0.0
# 1     60631       356353            Yes            0.0
# 2     60626       226102             No            0.0
# 3     60605       376901            Yes            0.0
# 4     60643       346385            Yes            1.0
# ...     ...          ...            ...            ...
# 2605  60453       210544            Yes            0.0
# 2606  60453       210544            Yes            0.0
# 2607  60453       210544            Yes            0.0
# 2608  60453       210544            Yes            1.0
# 2609  60453       210544            Yes            0.0
#
# [2600 rows x 19 columns]

# %%
df_final.Type.value_counts()
# Out:
# Single Family            1284
# Condo                     917
# Townhouse                 195
# Multi Family              107
# Multiple Occupancy         93
# Mobile / Manufactured       4
# Name: Type, dtype: int64

# %%
df_final.isna().sum()
# Out:
# Type                    0
# Year built              0
# Heating               288
# Cooling                 0
# Parking               254
# HOA                     0
# Total Price             0
# Address                 0
# Square Feet           365
# New construction        0
# Bedrooms                0
# Bathrooms               0
# Full bathrooms          0
# neighborhood_stats      0
# URL                     0
# Half bathrooms          0
# zip                     0
# median_nhv2             0
# Parking_Binned          0
# Bathrooms_adj           0
# dtype: int64

# %%
df_final[df_final['zip'] == '43147']
# Out:
# Empty DataFrame
# Columns: [Type, Year built, Heating, Cooling, Parking, HOA, Total Price, Address, Square Feet, New construction, Bedrooms, Bathrooms, Full bathrooms, neighborhood_stats, URL, Half bathrooms, zip, median_nhv2, Parking_Binned, Bathrooms_adj]
# Index: []

# %%
def clean_address(x):
    if 'UNIT' in x:
        temp = x.split(' UNIT')
        street_num = temp[0]
        temp2 = temp[1].split(', ')
        city_zip = temp2[1::]
        formatted_address = ' '.join([street_num] + city_zip)
        return formatted_address
    elif 'APT' in x:
        temp = x.split(' APT')
        street_num = temp[0]
        temp2 = temp[1].split(', ')
        city_zip = temp2[1::]
        formatted_address = ' '.join([street_num] + city_zip)
        return formatted_address
    elif '#' in x:
        temp = x.split(' #')
        street_num = temp[0]
        temp2 = temp[1].split(', ')
        city_zip = temp2[1::]
        formatted_address = ' '.join([street_num] + city_zip)
        return formatted_address
    elif 'PENTHOUSE' in x:
        temp = x.split(' PENTHOUSE')
        street_num = temp[0]
        temp2 = temp[1].split(', ')
        city_zip = temp2[1::]
        formatted_address = ' '.join([street_num] + city_zip)
        return formatted_address
    elif 'SUITE' in x:
        temp = x.split(' SUITE')
        street_num = temp[0]
        temp2 = temp[1].split(', ')
        city_zip = temp2[1::]
        formatted_address = ' '.join([street_num] + city_zip)
        return formatted_address
    # just return zip code for weird addresses like these so we can still have gps
    # for these properties
#     elif '(Undisclosed Address)' in x:
#         return x.split(' ')[-1]
#     elif 'Floor plan' in x:
#         return x.split(' ')[-1]
#     elif 'Buildable plan' in x:
#         return x.split(' ')[-1]
    else:
        return x

# %%
df_final['address_clean'] = df_final.Address.apply(clean_address)

# %%
from geopy.geocoders import Nominatim
# geolocator = Nominatim(user_agent="geopy/2.0.0")
# location = geolocator.geocode("910 west lake street, chicago il, 60607")

def get_coordinates(x):
    geolocator = Nominatim(user_agent="geopy/2.0.0")
    try:
        location_details = geolocator.geocode(x)
        lat_long = location_details[-1]
        in_chicago = (40 <= lat_long[0] <= 44) and (-89 <= lat_long[1] <= -86)
        if in_chicago:
            print(lat_long)
            return list(lat_long)
        else:
            print(x)
            return np.nan
    except:
        return np.nan

# going to have to remove apartment numbers before you can do get geo location... 
# df_final['lat-lng'] = df_final.address_clean.apply(get_coordinates)

# %%
df_final['lat-lng'] = df_final.address_clean.apply(get_coordinates)
# Out:
# (41.798760558651544, -87.58896251138316)
# (42.0105906, -87.82028962404709)
# (42.00624365, -87.67281299358012)
# (41.86377655, -87.62454866743403)
# (41.700669500000004, -87.67690644999999)
# (41.9053114, -87.62553364357132)
# (41.7201647, -87.59263204999999)
# (41.8623707, -87.6662151)
# (41.915067050000005, -87.7036016427013)
# (41.888304, -87.792792)
# 339 Home Ave Oak Park IL 60302
# (41.88877049591293, -87.79794799997782)
# (41.86734166894314, -87.78759735269233)
# (41.89704530511394, -87.7881081325266)
# (41.890986749999996, -87.8020975713958)
# (41.8976288, -87.8053652)
# (41.867959849849775, -87.79373186314534)
# (41.90746066791331, -87.79661734429295)
# 430 Home Ave Oak Park IL 60302
# (41.866260876336504, -87.78756123738968)
# (41.880633820780666, -87.80140925033736)
# (41.870007196093724, -87.78545091282749)
# (41.87326510749185, -87.78779922210008)
# 1112 Linden Ave, Oak Park, IL 60302
# (41.88137670476454, -87.80104271412769)
# (41.905023418291584, -87.78706681233434)
# (41.88450161372269, -87.80391961056385)
# (41.86636466681627, -87.77773933333866)
# (41.8561149, -87.7885903)
# (41.88094722670027, -87.80245833895978)
# (41.8561149, -87.7885903)
# 1046 Home Ave, Oak Park, IL 60304
# (41.881544, -87.789569)
# (41.8976288, -87.8053652)
# (41.907383, -87.788819)
# (41.8561149, -87.7885903)
# (41.8561149, -87.7885903)
# (41.90040628254695, -87.80101576702205)
# 511 Highland Ave, Oak Park, IL 60304
# (41.881495458582805, -87.79302334400998)
# (41.87000377517546, -87.78032121385614)
# (41.89864195855375, -87.79768999863364)
# 300 Linden Ave, Oak Park, IL 60302
# (41.875696626546684, -87.79400131426581)
# (41.87420621125493, -87.77556548939116)
# (41.87497846812428, -87.78316784917811)
# (41.88966833614182, -87.80255561054727)
# (41.88154071428571, -87.80104771428572)
# (41.886706980717356, -87.7845369615365)
# (41.88103067352188, -87.7970635353234)
# (41.90777636880223, -87.7874134381352)
# (41.8817615758135, -87.7864340980087)
# (41.8829052364457, -87.8025266348519)
# (41.88083857574795, -87.7927557191916)
# (41.8849887932472, -87.78612038424019)
# (41.8911231, -87.8030507569323)
# (41.88912499084688, -87.79762766468185)
# (41.886283204081636, -87.77496471428572)
# (41.866865344890165, -87.78780150250627)
# (41.88745, -87.792782)
# (41.88445759430482, -87.80413823374903)
# (41.8561149, -87.7885903)
# 1014 Hayes Ave, Oak Park, IL 60302
# (41.88633041911378, -87.79723052675861)
# (41.868679, -87.793978)
# (41.87790912736431, -87.79081123077697)
# (41.89213155, -87.80114391222808)
# (41.879281939727655, -87.79747887248865)
# (41.897109, -87.775322)
# 425 Home Ave Oak Park IL 60302
# (41.88489631088422, -87.80393318959463)
# (41.89041110521226, -87.7944496501533)
# (41.867565732856555, -87.77923046224319)
# (41.8905928, -87.79645129930181)
# (41.88402723293378, -87.80234080461996)
# (41.90405930190397, -87.7765391680777)
# (41.86891004449952, -87.77559254710948)
# (41.86991036796606, -87.78790500290057)
# 1033 Highland Ave, Oak Park, IL 60304
# (41.88984748741208, -87.77649077203134)
# (41.889816077191675, -87.7764898593857)
# (41.8915911, -87.80337627771715)
# (41.89414540235053, -87.80423998548022)
# (41.88966833614182, -87.80255561054727)
# 330 Home Ave, Oak Park, IL 60302
# (41.87583316056563, -87.80383691815773)
# (41.90087644919521, -87.77765609318365)
# (41.887550320242575, -87.7972330155168)
# (41.886294, -87.80242433333333)
# (41.904257345565746, -87.79481528676408)
# (41.868580257670345, -87.77558053920687)
# (41.88178655, -87.77525748384929)
# (41.8799853, -87.8023156)
# (41.87212025, -87.77955919971234)
# (41.871327124530566, -87.79406850379667)
# (41.88152860716052, -87.80175403431878)
# (41.867919516040594, -87.78024916402698)
# (41.883322, -87.784442)
# 6436 Roosevelt Rd Oak Park IL 60304
# (41.90215312496485, -87.77791520849205)
# (41.88884352740833, -87.79280654233844)
# (41.882101, -87.786259)
# 1152 Home Ave, Oak Park, IL 60304
# (41.88522, -87.776342)
# (41.88117424515162, -87.77784686873636)
# (41.902378992317914, -87.77648441765052)
# (41.891977088392565, -87.78306081087392)
# (41.870562192277454, -87.7830191897531)
# (41.87416067549646, -87.78314115385672)
# (41.90053564451444, -87.77664435481715)
# 441 S Taylor St Oak Park IL 60302
# (41.88321736081354, -87.79377330364824)
# (41.893921, -87.775212)
# (41.89052235021692, -87.78486423401951)
# (41.89562828185285, -87.776891966642)
# (41.90039220150257, -87.78028956038025)
# (41.90066131345905, -87.78029876564398)
# (41.89414540235053, -87.80423998548022)
# (41.894729707901135, -87.77937656264224)
# (41.881543, -87.80091)
# (41.89206999241586, -87.79289533392007)
# (41.88856827412524, -87.79503029605311)
# (41.886877761728705, -87.7869011589778)
# (41.88305313377929, -87.7844348858408)
# (41.90008424010188, -87.80100561278304)
# (41.8776852613472, -87.77569818239753)
# (41.89686433057327, -87.77833753787797)
# (41.87978755435801, -87.7978416660422)
# (41.881091, -87.77969571428571)
# (41.88155433314382, -87.80031234849473)
# (41.874015778753986, -87.78782374388642)
# (41.904725648078774, -87.78166559955814)
# (41.8976288, -87.8053652)
# (41.90148022790555, -87.80281194334214)
# (41.890082976755835, -87.79819097609938)
# (41.88670958120224, -87.78779777845268)
# (41.88243016012118, -87.80406751255227)
# (41.89033077237342, -87.79744108663667)
# (41.87576256767726, -87.78442782021865)
# (41.8561149, -87.7885903)
# (41.886294, -87.80242433333333)
# (41.90014885343581, -87.80535066593455)
# (41.89636584438521, -87.80452369426838)
# (41.880442, -87.778046)
# (41.88167525354584, -87.78161366881096)
# (41.90586670456551, -87.79507549006445)
# (41.905988211492414, -87.78338838120018)
# (41.877525379541034, -87.77591199427289)
# (41.88745, -87.792782)
# (41.8659409869895, -87.80325902464412)

# %%
def get_zip_coordinates(x):
    geolocator = Nominatim(user_agent="geopy/2.0.0")
    try:
        location = geolocator.geocode(x)
        if location != None:
            print(list(location[-1]))
            return list(location[-1])
        else:
            print(x)
            return np.nan
    except:
        return np.nan

# %%
# fill na lat-lng values with lat-lng of zip code
mask = df_final['lat-lng'].isna()
df_final.loc[mask, 'lat-lng'] = df_final.loc[mask, 'zip'].apply(get_zip_coordinates)

# %%
df_final['lat-lng'].isna().sum()

# %%
df_temp = df_final['lat-lng'].apply(pd.Series)
df_temp.columns = ['lat', 'long']

complete_df = df_temp.join(df)
complete_df.drop(columns=['lat-lng'], inplace=True)

# %%
complete_df.to_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/clean_data/all_neighborhoods_clean.csv')
