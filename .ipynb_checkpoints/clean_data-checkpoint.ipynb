# %%
import pandas as pd
import numpy as np
import re

# %%
df1 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/chicago_il.csv')
df2 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/evanston_il.csv')
df3 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/glenview_il.csv')
df4 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/naperville_il.csv')
df5 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/oak_park_il.csv')
df6 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/skokie_il.csv')
df7 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/cicero_il.csv')
df8 = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/neighborhoods_/oak_lawn_il.csv')

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8]).drop(columns=['Unnamed: 0']).reset_index()
df.groupby('URL').size().value_counts()
# Out:
# 1    2596
# 2       7
# dtype: int64

# %%
df.groupby('Address').size().value_counts()
# Out:
# 1    2590
# 2      10
# dtype: int64

# %%
# there are a few duplicate urls so we will drop those
df.drop_duplicates(subset=['URL'], inplace=True)

# %%
df.replace(to_replace=['None', 'No Data'], value=np.nan, inplace=True)

# %%
df.isna().sum()
# Out:
# index                    0
# Type                     0
# Year built              89
# Heating                289
# Cooling                535
# Parking                254
# HOA                   1554
# Price/sqft             546
# Total Price              0
# Address                  0
# Square Feet            365
# New construction         0
# Bedrooms                 2
# Bathrooms               10
# Full bathrooms         207
# neighborhood_stats       0
# URL                      0
# Lot                   1273
# Half bathrooms        1621
# Status                2226
# dtype: int64

# %%
def acres_to_sqft(x):
    if isinstance(x, list):
        if 'acres' in x:
            sqft = float(x[0]) * 43560
            return round(sqft, 2)
        else:
            return float(x[0].replace(',',''))
    else:
        return x
    
    
def sqft_to_int(x):
    if isinstance(x, str):
        if x != '--':
            x_formatted = re.sub("[^0-9]", "", x)
            return int(x_formatted)
        else:
            return np.nan
    else:
        return x
    
    
def group_cooling(x):
    a = 'Central, Geothermal, Other'
    b = 'Geothermal'
    c = 'Central, Refrigeration'
    d = 'Geothermal, Other'
    if x == a:
        return 'Other'
    elif x == b:
        return 'Other'
    elif x == c:
        return 'Other'
    elif x == d:
        return 'Other'
    else:
        return x

# get the historic median neighborhood price for property
def get_median_value(x):
    median = x.split('.')[-2]
    median2 = median.split(' is ')
    char = median2[0][0:10]
    val =  median2[-1]
    val_formatted = int(re.sub('[^0-9]', '', val))
    return val_formatted

def get_zip(x):
    test = x.split(',')
    city_zip = test[-1].split(' ')
    return city_zip[-1]


# df['zip'] = df.Address.apply(get_zip)


df['Total Price'] = df['Total Price'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)
df['zip'] = df.Address.apply(get_zip)
df['Square Feet'] = df['Square Feet'].apply(sqft_to_int)
df['HOA'] = df['HOA'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)
df['HOA'] = df['HOA'].apply(lambda x: 'Yes' if np.isnan(x) else 'No')
df['Bedrooms'] = df['Bedrooms'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)
df['Bathrooms'] = df['Bathrooms'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)
df['Full bathrooms'] = df['Full bathrooms'].apply(lambda x: int(x) if isinstance(x, str) else x)
df['Half bathrooms'].fillna(0, inplace=True)
df['Half bathrooms'] = df['Half bathrooms'].astype(int)
df['Year built'] = df['Year built'].apply(lambda x: int(x) if isinstance(x, str) else x)
df['Cooling'] = df.Cooling.replace('Refrigerator', 'Refrigeration')
df.Cooling.fillna('None', inplace=True)
df['Lot'] = df['Lot'].apply(lambda x: x.lower() if isinstance(x, str) else x)
df['Lot Temp'] = df['Lot'].str.split(' ')
df['Lot'] = df['Lot Temp'].apply(acres_to_sqft)
df['Cooling'] = df.Cooling.apply(group_cooling)
# df['median_nhv'] = df.neighborhood_stats.apply(get_median_value)
df['median_nhv'] = df.groupby(['zip', 'Type'])['Total Price'].transform('median')

#imputing missing year built values with median for that zip code
year_built_dict = dict(df.groupby('zip')['Year built'].median())
df['Year built'] = df['Year built'].fillna(df.zip.map(year_built_dict))
df['Bathrooms'].fillna(df.Bathrooms.median(), inplace=True)
df.drop(columns=['Lot Temp', 'Price/sqft', 'index', 'Status'], inplace=True)

# %%
for item in df.columns.to_list():
    print(item + ':')
    print(df[item].value_counts())
    print()
# Out:
# Type:
# Single Family            1285
# Condo                     917
# Townhouse                 195
# Multi Family              107
# Multiple Occupancy         93
# Mobile / Manufactured       4
# Apartment                   1
# Miscellaneous               1
# Name: Type, dtype: int64
#
# Year built:
# 2020.0    120
# 2005.0     63
# 2006.0     61
# 2008.0     47
# 2004.0     46
#          ...
# 1930.5      1
# 1935.0      1
# 1868.0      1
# 1925.5      1
# 1875.0      1
# Name: Year built, Length: 152, dtype: int64
#
# Heating:
# Forced air                              860
# Forced air, Gas                         574
# Gas                                     501
# Baseboard                                78
# Other                                    65
# Electric                                 51
# Radiant                                  29
# Forced air, Electric                     28
# Baseboard, Gas                           27
# Other, Gas                               19
# Electric, Gas                            15
# Radiant, Gas                             10
# Forced air, Electric, Gas                 6
# Baseboard, Forced air                     4
# Other, Radiant                            4
# Heat pump                                 4
# Forced air, Other                         4
# Forced air, Heat pump                     3
# Forced air, Radiant                       3
# Other, Electric                           3
# Baseboard, Radiant                        2
# Baseboard, Forced air, Electric, Gas      2
# Baseboard, Electric                       2
# Baseboard, Radiant, Gas                   2
# Solar                                     1
# Forced air, Heat pump, Other, Gas         1
# Baseboard, Forced air, Gas                1
# Forced air, Propane / Butane              1
# Forced air, Radiant, Gas                  1
# Forced air, Heat pump, Other              1
# Gas, Other                                1
# None, Forced air                          1
# None, Baseboard                           1
# Baseboard, Other                          1
# Wall, Electric                            1
# Radiant, Other                            1
# Radiant, Electric                         1
# Forced air, Stove                         1
# Baseboard, Heat pump, Electric            1
# Forced air, Wall                          1
# Baseboard, Electric, Gas                  1
# Forced air, Solar                         1
# Name: Heating, dtype: int64
#
# Cooling:
# Central          1909
# None              535
# Wall               74
# Other              55
# Refrigeration      30
# Name: Cooling, dtype: int64
#
# Parking:
# 2 spaces           1178
# 1 space             769
# 3 spaces            232
# 4 spaces             78
# 6 spaces             20
# 5 spaces             14
# Attached Garage      14
# 10 spaces             7
# 7 spaces              6
# 8 spaces              6
# 42 spaces             5
# Detached Garage       5
# 9 spaces              3
# 12 spaces             2
# 20 spaces             1
# 17 spaces             1
# 21 spaces             1
# On street             1
# 11 spaces             1
# 14 spaces             1
# Off street            1
# 38 spaces             1
# 31 spaces             1
# 13 spaces             1
# Name: Parking, dtype: int64
#
# HOA:
# Yes    1554
# No     1049
# Name: HOA, dtype: int64
#
# Total Price:
# 350000.0    21
# 299900.0    18
# 599000.0    18
# 299000.0    17
# 249900.0    17
#             ..
# 505000.0     1
# 231670.0     1
# 269737.0     1
# 770000.0     1
# 512000.0     1
# Name: Total Price, Length: 1137, dtype: int64
#
# Address:
# 9525 Meade Ave, Oak Lawn, IL 60453                                2
# 8621 Monticello Ave, Skokie, IL 60076                             2
# (Undisclosed Address), Chicago, IL 60628                          2
# 25W150 Fairmeadow Ln, Naperville, IL 60563                        1
# 11610 S Peoria St, Chicago, IL 60643                              1
#                                                                  ..
# 3048 N Greenview Ave #2, Chicago, IL 60657                        1
# 211 N Marion St APT 1B, Oak Park, IL 60302                        1
# Floor plan: P3 - Peoria Green, Peoria Green, Chicago, IL 60607    1
# 900 Chicago Ave UNIT 612, Evanston, IL 60202                      1
# 1029 N Honore St, Chicago, IL 60622                               1
# Name: Address, Length: 2600, dtype: int64
#
# Square Feet:
# 1200.0    61
# 1000.0    55
# 1100.0    36
# 900.0     34
# 1300.0    33
#           ..
# 2022.0     1
# 1426.0     1
# 1343.0     1
# 2098.0     1
# 2619.0     1
# Name: Square Feet, Length: 1181, dtype: int64
#
# New construction:
#  No     2433
#  Yes     170
# Name: New construction, dtype: int64
#
# Bedrooms:
# 3.0     707
# 2.0     621
# 4.0     579
# 5.0     276
# 1.0     214
# 6.0     115
# 7.0      32
# 8.0      22
# 9.0      12
# 0.0      11
# 10.0      6
# 11.0      5
# 12.0      1
# Name: Bedrooms, dtype: int64
#
# Bathrooms:
# 2.0     959
# 3.0     622
# 1.0     494
# 4.0     277
# 5.0     144
# 6.0      70
# 7.0      16
# 8.0      15
# 9.0       3
# 10.0      1
# 11.0      1
# 0.0       1
# Name: Bathrooms, dtype: int64
#
# Full bathrooms:
# 2.0    1102
# 1.0     606
# 3.0     416
# 4.0     156
# 5.0      78
# 6.0      26
# 7.0       9
# 8.0       2
# 9.0       1
# Name: Full bathrooms, dtype: int64
#
# neighborhood_stats:
# Home values in 60302 have fallen 4.6 % (↓) over the past 12 months.Zillow predicts the home values in 60302 will fall 4.5% (↓) in the next year.This home is valued 29.7% lower (↓) than the median home in 60302.The median Zestimate® for this neighborhood is $425,027.                            3
# Home values in 60302 have fallen 4.6 % (↓) over the past 12 months.Zillow predicts the home values in 60302 will decrease 4.5% (↓) in the next year.This home is valued 25.9% higher (↑) than the median home in 60302.The median Zestimate® for this neighborhood is $425,027.                       3
# Home values in 60302 have fallen 4.6 % (↓) over the past 12 months.Zillow predicts the home values in 60302 will fall 4.5% (↓) in the next year.This home is valued 52.9% higher (↑) than the median home in 60302.The median Zestimate® for this neighborhood is $425,027.                           3
# Home values in 60453 have risen 1.3 % (↑) over the past 12 months.Zillow predicts the home values in 60453 will increase 1.3% (↑) in the next year.This home is valued 42% higher (↑) than the median home in 60453.The median Zestimate® for this neighborhood is $210,544.                          3
# Home values in 60453 have risen 1.3 % (↑) over the past 12 months.Zillow predicts the home values in 60453 will increase 1.3% (↑) in the next year.This home is valued 18.7% higher (↑) than the median home in 60453.The median Zestimate® for this neighborhood is $210,544.                        3
#                                                                                                                                                                                                                                                                                                      ..
# Home values in 60563 have risen 1.0 % (↑) over the past 12 months.Zillow predicts the home values in 60563 will rise 0.9% (↑) in the next year.This home is valued 22.3% higher (↑) than the median home in 60563.The median Zestimate® for this neighborhood is $321,403.                            1
# Home values in Bucktown have risen 0.6 % (↑) over the past 12 months.Zillow predicts the home values in Bucktown will increase 0.5% (↑) in the next year.This home is valued 56.4% higher (↑) than the median home in Bucktown.The median Zestimate® for this neighborhood is $601,188.               1
# Home values in Lake View East have risen 0.6 % (↑) over the past 12 months.Zillow predicts the home values in Lake View East will fall 0.6% (↓) in the next year.This home is valued 24% lower (↓) than the median home in Lake View East.The median Zestimate® for this neighborhood is $315,541.    1
# Home values in South Loop have risen 0.6 % (↑) over the past 12 months.Zillow predicts the home values in South Loop will increase 3.2% (↑) in the next year.This home is valued 96.3% higher (↑) than the median home in South Loop.The median Zestimate® for this neighborhood is $376,901.         1
# Home values in Uptown have risen 0.6 % (↑) over the past 12 months.Zillow predicts the home values in Uptown will rise 2% (↑) in the next year.This home is valued 30.8% lower (↓) than the median home in Uptown.The median Zestimate® for this neighborhood is $303,469.                            1
# Name: neighborhood_stats, Length: 2445, dtype: int64
#
# URL:
# https://www.zillow.com/homedetails/1673-W-Farwell-Ave-APT-1S-Chicago-IL-60626/2122718550_zpid/      1
# https://www.zillow.com/homedetails/150-S-Oak-Park-Ave-APT-402-Oak-Park-IL-60302/2080018917_zpid/    1
# https://www.zillow.com/homedetails/2967-Chevy-Chase-Ln-Naperville-IL-60564/82635010_zpid/           1
# https://www.zillow.com/homedetails/143-Custer-Ave-Evanston-IL-60202/3570210_zpid/                   1
# https://www.zillow.com/homedetails/360-W-Illinois-St-APT-317-Chicago-IL-60654/2079442709_zpid/      1
#                                                                                                    ..
# https://www.zillow.com/homedetails/8433-Keystone-Ave-Skokie-IL-60076/3536583_zpid/                  1
# https://www.zillow.com/homedetails/2740-N-Pine-Grove-Ave-APT-8E-Chicago-IL-60614/3724915_zpid/      1
# https://www.zillow.com/homedetails/800-Elgin-Rd-APT-519-Evanston-IL-60201/70397019_zpid/            1
# https://www.zillow.com/homedetails/1155-S-Scoville-Ave-Oak-Park-IL-60304/3600539_zpid/              1
# https://www.zillow.com/homedetails/2823-Melrose-Ln-Naperville-IL-60564/82638064_zpid/               1
# Name: URL, Length: 2603, dtype: int64
#
# Lot:
# 3750.0     29
# 11325.6    26
# 3920.0     24
# 10890.0    23
# 11761.2    20
#            ..
# 7570.0      1
# 5771.0      1
# 3650.0      1
# 10497.0     1
# 8555.0      1
# Name: Lot, Length: 631, dtype: int64
#
# Half bathrooms:
# 0    1621
# 1     889
# 2      83
# 3      10
# Name: Half bathrooms, dtype: int64
#
# zip:
# 60302    234
# 60025    221
# 60453    185
# 60201    147
# 60202    132
#         ...
# 60093      3
# 60633      2
# 43147      1
# 60604      1
# 60602      1
# Name: zip, Length: 75, dtype: int64
#
# median_nhv:
# 749900.0    166
# 245170.0    121
# 598000.0    120
# 163499.5    116
# 219039.5     96
#            ...
# 385000.0      1
# 219900.0      1
# 574800.0      1
# 269000.0      1
# 179900.0      1
# Name: median_nhv, Length: 207, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(df.Parking, bins=15);
plt.xticks(rotation=90);

# %%
df.Parking.isna().sum()
# Out:
# 254

# %%
df.drop(columns=['Lot'], inplace=True)

# %%
df['Parking_Binned'] = df.Parking.apply(lambda x: 'Yes' if isinstance(x, str) else 'No')

# %%
df
# Out:
#                Type  Year built          Heating        Cooling   Parking  \
# 0             Condo      1910.0              Gas        Central       NaN
# 1     Single Family      1957.0       Forced air        Central  2 spaces
# 2             Condo      2007.0       Forced air        Central       NaN
# 3             Condo      2008.0              Gas        Central  2 spaces
# 4     Single Family      1971.0       Forced air        Central  4 spaces
# ...             ...         ...              ...            ...       ...
# 2605          Condo      2005.0       Forced air        Central   1 space
# 2606  Single Family      1973.0              Gas        Central  2 spaces
# 2607          Condo      1973.0            Other  Refrigeration   1 space
# 2608  Single Family      1949.0  Forced air, Gas        Central  2 spaces
# 2609          Condo      1983.0       Forced air        Central  2 spaces
#
#       HOA  Total Price                                          Address  \
# 0      No     249900.0          5329 S Harper Ave #2, Chicago, IL 60615
# 1     Yes     399000.0              7144 N Ozark Ave, Chicago, IL 60631
# 2      No     169898.0     1673 W Farwell Ave APT 1S, Chicago, IL 60626
# 3      No     489900.0  1400 S Michigan Ave APT 2203, Chicago, IL 60605
# 4     Yes     389000.0            10606 S Leavitt St, Chicago, IL 60643
# ...   ...          ...                                              ...
# 2605   No     168999.0      9440 S 51st Ave APT 502, Oak Lawn, IL 60453
# 2606  Yes     399900.0            9246 S Keeler Ave, Oak Lawn, IL 60453
# 2607   No      94500.0       4929 W 87th St APT 3NW, Oak Lawn, IL 60453
# 2608  Yes     249900.0               9117 S 53rd Ct, Oak Lawn, IL 60453
# 2609   No     124900.0       4003 W 105th St APT 3W, Oak Lawn, IL 60453
#
#       Square Feet New construction  Bedrooms  Bathrooms  Full bathrooms  \
# 0          1000.0               No       2.0        2.0             2.0
# 1          1224.0               No       2.0        2.0             2.0
# 2           775.0               No       2.0        1.0             1.0
# 3          1273.0               No       2.0        2.0             2.0
# 4          2179.0               No       3.0        3.0             2.0
# ...           ...              ...       ...        ...             ...
# 2605       1052.0               No       1.0        1.0             1.0
# 2606       3400.0               No       4.0        3.0             3.0
# 2607        852.0               No       2.0        1.0             1.0
# 2608       1343.0               No       3.0        2.0             1.0
# 2609       1000.0               No       2.0        2.0             2.0
#
#                                      neighborhood_stats  \
# 0     Home values in Hyde Park have risen 0.6 % (↑) ...
# 1     Home values in Edison Park have risen 0.6 % (↑...
# 2     Home values in Rogers Park have risen 0.6 % (↑...
# 3     Home values in South Loop have risen 0.6 % (↑)...
# 4     Home values in Beverly have risen 0.6 % (↑) ov...
# ...                                                 ...
# 2605  Home values in 60453 have risen 1.3 % (↑) over...
# 2606  Home values in 60453 have risen 1.3 % (↑) over...
# 2607  Home values in 60453 have risen 1.3 % (↑) over...
# 2608  Home values in 60453 have risen 1.3 % (↑) over...
# 2609  Home values in 60453 have risen 1.3 % (↑) over...
#
#                                                     URL  Half bathrooms  \
# 0     https://www.zillow.com/homedetails/5329-S-Harp...               0
# 1     https://www.zillow.com/homedetails/7144-N-Ozar...               0
# 2     https://www.zillow.com/homedetails/1673-W-Farw...               0
# 3     https://www.zillow.com/homedetails/1400-S-Mich...               0
# 4     https://www.zillow.com/homedetails/10606-S-Lea...               1
# ...                                                 ...             ...
# 2605  https://www.zillow.com/homedetails/9440-S-51st...               0
# 2606  https://www.zillow.com/homedetails/9246-S-Keel...               0
# 2607  https://www.zillow.com/homedetails/4929-W-87th...               0
# 2608  https://www.zillow.com/homedetails/9117-S-53rd...               1
# 2609  https://www.zillow.com/homedetails/4003-W-105t...               0
#
#         zip  median_nhv Parking_Binned
# 0     60615    174250.0             No
# 1     60631    515000.0            Yes
# 2     60626    194900.0             No
# 3     60605    465000.0            Yes
# 4     60643    154900.0            Yes
# ...     ...         ...            ...
# 2605  60453    121212.5            Yes
# 2606  60453    245170.0            Yes
# 2607  60453    121212.5            Yes
# 2608  60453    245170.0            Yes
# 2609  60453    121212.5            Yes
#
# [2603 rows x 19 columns]

# %%
# def group_cooling(x):
#     a = 'Central, Geothermal, Other'
#     b = 'Geothermal'
#     c = 'Central, Refrigeration'
#     d = 'Geothermal, Other'
#     if x == a:
#         return 'Other'
#     elif x == b:
#         return 'Other'
#     elif x == c:
#         return 'Other'
#     elif x == d:
#         return 'Other'
#     else:
#         return x
    
# df['cool_temp'] = df.Cooling.apply(group_cooling)

# %%
df['cool_temp'] = df.Cooling.apply(group_cooling)
df.cool_temp.value_counts()
# Out:
# Central          1909
# None              535
# Wall               74
# Other              55
# Refrigeration      30
# Name: cool_temp, dtype: int64

# %%
df.Type.value_counts()
# Out:
# Single Family            1285
# Condo                     917
# Townhouse                 195
# Multi Family              107
# Multiple Occupancy         93
# Mobile / Manufactured       4
# Apartment                   1
# Miscellaneous               1
# Name: Type, dtype: int64

# %%
df['Full bathrooms'].fillna(0, inplace=True)
df['Bathrooms_adj'] = abs(df['Bathrooms'] - df['Full bathrooms'])
df['Bedrooms'].fillna(df.Bedrooms.median(), inplace=True)

# %%
# Miscellaneous
# Apartment

df_final = df[(df['Type'] != 'Miscellaneous') & (df['Type'] != 'Apartment') & (df.zip != '43147')]

# %%
plt.hist(df_final['Square Feet'])
# Out:
# (array([875., 719., 319., 186.,  59.,  39.,  14.,   5.,  11.,   8.]),
#  array([  400. ,  1409.5,  2419. ,  3428.5,  4438. ,  5447.5,  6457. ,
#          7466.5,  8476. ,  9485.5, 10495. ]),
#  <BarContainer object of 10 artists>)

# %%
df_final.isna().sum()
# Out:
# Type                    0
# Year built              0
# Heating               288
# Cooling                 0
# Parking               254
# HOA                     0
# Total Price             0
# Address                 0
# Square Feet           365
# New construction        0
# Bedrooms                0
# Bathrooms               0
# Full bathrooms          0
# neighborhood_stats      0
# URL                     0
# Half bathrooms          0
# zip                     0
# median_nhv              0
# Parking_Binned          0
# cool_temp               0
# Bathrooms_adj           0
# dtype: int64

# %%
df_final.drop(columns=['Parking'])
# Out:
#                Type  Year built          Heating        Cooling  HOA  \
# 0             Condo      1910.0              Gas        Central   No
# 1     Single Family      1957.0       Forced air        Central  Yes
# 2             Condo      2007.0       Forced air        Central   No
# 3             Condo      2008.0              Gas        Central   No
# 4     Single Family      1971.0       Forced air        Central  Yes
# ...             ...         ...              ...            ...  ...
# 2605          Condo      2005.0       Forced air        Central   No
# 2606  Single Family      1973.0              Gas        Central  Yes
# 2607          Condo      1973.0            Other  Refrigeration   No
# 2608  Single Family      1949.0  Forced air, Gas        Central  Yes
# 2609          Condo      1983.0       Forced air        Central   No
#
#       Total Price                                          Address  \
# 0        249900.0          5329 S Harper Ave #2, Chicago, IL 60615
# 1        399000.0              7144 N Ozark Ave, Chicago, IL 60631
# 2        169898.0     1673 W Farwell Ave APT 1S, Chicago, IL 60626
# 3        489900.0  1400 S Michigan Ave APT 2203, Chicago, IL 60605
# 4        389000.0            10606 S Leavitt St, Chicago, IL 60643
# ...           ...                                              ...
# 2605     168999.0      9440 S 51st Ave APT 502, Oak Lawn, IL 60453
# 2606     399900.0            9246 S Keeler Ave, Oak Lawn, IL 60453
# 2607      94500.0       4929 W 87th St APT 3NW, Oak Lawn, IL 60453
# 2608     249900.0               9117 S 53rd Ct, Oak Lawn, IL 60453
# 2609     124900.0       4003 W 105th St APT 3W, Oak Lawn, IL 60453
#
#       Square Feet New construction  Bedrooms  Bathrooms  Full bathrooms  \
# 0          1000.0               No       2.0        2.0             2.0
# 1          1224.0               No       2.0        2.0             2.0
# 2           775.0               No       2.0        1.0             1.0
# 3          1273.0               No       2.0        2.0             2.0
# 4          2179.0               No       3.0        3.0             2.0
# ...           ...              ...       ...        ...             ...
# 2605       1052.0               No       1.0        1.0             1.0
# 2606       3400.0               No       4.0        3.0             3.0
# 2607        852.0               No       2.0        1.0             1.0
# 2608       1343.0               No       3.0        2.0             1.0
# 2609       1000.0               No       2.0        2.0             2.0
#
#                                      neighborhood_stats  \
# 0     Home values in Hyde Park have risen 0.6 % (↑) ...
# 1     Home values in Edison Park have risen 0.6 % (↑...
# 2     Home values in Rogers Park have risen 0.6 % (↑...
# 3     Home values in South Loop have risen 0.6 % (↑)...
# 4     Home values in Beverly have risen 0.6 % (↑) ov...
# ...                                                 ...
# 2605  Home values in 60453 have risen 1.3 % (↑) over...
# 2606  Home values in 60453 have risen 1.3 % (↑) over...
# 2607  Home values in 60453 have risen 1.3 % (↑) over...
# 2608  Home values in 60453 have risen 1.3 % (↑) over...
# 2609  Home values in 60453 have risen 1.3 % (↑) over...
#
#                                                     URL  Half bathrooms  \
# 0     https://www.zillow.com/homedetails/5329-S-Harp...               0
# 1     https://www.zillow.com/homedetails/7144-N-Ozar...               0
# 2     https://www.zillow.com/homedetails/1673-W-Farw...               0
# 3     https://www.zillow.com/homedetails/1400-S-Mich...               0
# 4     https://www.zillow.com/homedetails/10606-S-Lea...               1
# ...                                                 ...             ...
# 2605  https://www.zillow.com/homedetails/9440-S-51st...               0
# 2606  https://www.zillow.com/homedetails/9246-S-Keel...               0
# 2607  https://www.zillow.com/homedetails/4929-W-87th...               0
# 2608  https://www.zillow.com/homedetails/9117-S-53rd...               1
# 2609  https://www.zillow.com/homedetails/4003-W-105t...               0
#
#         zip  median_nhv Parking_Binned      cool_temp  Bathrooms_adj
# 0     60615    174250.0             No        Central            0.0
# 1     60631    515000.0            Yes        Central            0.0
# 2     60626    194900.0             No        Central            0.0
# 3     60605    465000.0            Yes        Central            0.0
# 4     60643    154900.0            Yes        Central            1.0
# ...     ...         ...            ...            ...            ...
# 2605  60453    121212.5            Yes        Central            0.0
# 2606  60453    245170.0            Yes        Central            0.0
# 2607  60453    121212.5            Yes  Refrigeration            0.0
# 2608  60453    245170.0            Yes        Central            1.0
# 2609  60453    121212.5            Yes        Central            0.0
#
# [2600 rows x 20 columns]

# %%
df_final.Type.value_counts()
# Out:
# Single Family            1284
# Condo                     917
# Townhouse                 195
# Multi Family              107
# Multiple Occupancy         93
# Mobile / Manufactured       4
# Name: Type, dtype: int64

# %%
df_final.isna().sum()
# Out:
# Type                    0
# Year built              0
# Heating               288
# Cooling                 0
# Parking               254
# HOA                     0
# Total Price             0
# Address                 0
# Square Feet           365
# New construction        0
# Bedrooms                0
# Bathrooms               0
# Full bathrooms          0
# neighborhood_stats      0
# URL                     0
# Half bathrooms          0
# zip                     0
# median_nhv              0
# Parking_Binned          0
# cool_temp               0
# Bathrooms_adj           0
# dtype: int64

# %%
df_final.to_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/clean_data/all_neighborhoods_clean.csv')

# %%
df_final[df_final['zip'] == '43147']
# Out:
# Empty DataFrame
# Columns: [Type, Year built, Heating, Cooling, Parking, HOA, Total Price, Address, Square Feet, New construction, Bedrooms, Bathrooms, Full bathrooms, neighborhood_stats, URL, Half bathrooms, zip, median_nhv, Parking_Binned, cool_temp, Bathrooms_adj]
# Index: []
#
# [0 rows x 21 columns]
