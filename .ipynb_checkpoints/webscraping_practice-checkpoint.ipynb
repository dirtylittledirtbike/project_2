# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time, os
import numpy as np
import requests
import re
import random

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
def get_property_urls(link):
    # omg thank god for some dude on github for this req_header 0 CAPTCHAS i owe you my life
    
    req_headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-US,en;q=0.8',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
    }


    r = requests.get(link, headers=req_headers)
    soup = BeautifulSoup(r.content, 'html.parser')

    table = soup.find('ul', class_='photo-cards photo-cards_wow photo-cards_short')
    li_tags = table.find_all('li')
    properties = [item.find('div', class_='list-card-info')for item in li_tags]

    property_urls = []

    for item in properties:
        if item != None:
            property_extensions = item.find('a')['href']
            property_urls.append(property_extensions)
            
    return property_urls

# %%
def get_property_features(link):
    
    """
    Description: Grab all features from a listings URL (HOMES FOR SALE)
    Parameters: Link to listing (str)
    Return: all features from that properties url (dict)
    """
    
    try:
    
        req_headers = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'en-US,en;q=0.8',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
        }

        r = requests.get(link, headers=req_headers)
        soup = BeautifulSoup(r.content, 'html.parser')
        facts_and_features_table = soup.find('div', class_='ds-home-facts-and-features reso-facts-features sheety-facts-features')

        # this is the code for extracting features our of the home fact list table
        # creating a features list variable that we will append each scraped feature to
        # I'm deciding to do this so we can pull all the data in a particular table 
        # all at once and just use their entries for our column names
        
        all_features = facts_and_features_table.find_all('li', class_='ds-home-fact-list-item')
        features_list = [item.text.split(':') for item in all_features]
        address = soup.find('h1', class_='ds-address-container').text.replace(',\xa0', ', ')
        price = soup.find('div', class_='ds-home-details-chip').find('span', class_='ds-value').text
        summary_info = soup.find_all('span', class_='ds-bed-bath-living-area')

        # getting the third element in summnary info which is square feet and then splitting/
        # reversing it so its formatted as ['Square Feet', '728'] and not ['728', 'square feet']
        for item in summary_info:
            if 'sqft' in item.text.lower() or 'square feet' in item.text.lower():
                sqft = item.text.split(" ", 1)[::-1]
            else:
                sqft = np.nan

        # trying neighborhood stats in new way if this doesnt work uncomment code above
        neighborhood_stats_formatted = soup.find(text = 'Neighborhood stats').next_element.get_text()

        # finding if building was recently constructed or renovated from construction details
        # table 
        construction_details = soup.find_all('span', class_='Text-aiai24-0 cZksOw')
        for item in construction_details:
            if 'new construction' in item.text.lower():
                construction = item.text.split(':')

        features_list.append(['Total Price', price])
        features_list.append(['Address', address])
        features_list.append(sqft)
        features_list.append(construction)

        # this is code for extracting number of bedroom/baths from a separate div
        # then formatting it to match our features from the first table and appending
        # to feature list
        beds_baths = soup.find(text='Bedrooms and bathrooms').next_element.text
        beds_baths = re.split('(\d+)',beds_baths.replace('1/2', 'Half'))[:-1]
        bed_baths_formatted = [i+j for i,j in zip(beds_baths[::2], beds_baths[1::2])]

        for item in bed_baths_formatted:
            features_list.append(item.split(':'))

        features_list.append(['neighborhood_stats', neighborhood_stats_formatted])
        features_list.append(['URL', link])
        
        print(features_list)
        return dict(features_list)
    except:
        return None

# %%
def get_property_features_sold(link):
    
    """
    Description: Grab all features from a listings URL (HOMES SOLD)
    Parameters: Link to listing (str)
    Return: all features from that properties url (dict)
    """
        
    try:
    
        req_headers = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'en-US,en;q=0.8',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
        }


        r = requests.get(link, headers=req_headers)
        soup = BeautifulSoup(r.content, 'html.parser')
        facts_and_features_table = soup.find('div', class_='ds-home-facts-and-features reso-facts-features sheety-facts-features')


        # this is the code for extracting features our of the home fact list table
        all_features = facts_and_features_table.find_all('li', class_='ds-home-fact-list-item')
        features_list = [item.text.split(':') for item in all_features]
        address = soup.find('h1', class_='ds-address-container').text.replace(',\xa0', ', ')
        price = soup.find('span', class_='sc-pscky hEQFyS ds-status-details').get_text().lower().split(':')
        
        # so zillow has homes sold filter but people flip properties very quickly i guess
        # anyway we dont want to grab duplicates homes from when we looked at only for sale homes
        # so im creating this condition to make sure the status bar for the home says "Sold"
        
        if 'sold' in price:

            summary_info = soup.find_all('span', class_='ds-bed-bath-living-area')

            # getting the third element in summnary info which is square feet and then splitting/
            # reversing it so its formatted as ['Square Feet', '728'] and not ['728', 'square feet']
            for item in summary_info:
                if 'sqft' in item.text.lower() or 'square feet' in item.text.lower():
                    sqft = item.text.split(" ", 1)[::-1]
                else:
                    sqft = np.nan

            # getting all text out of neighborhoods stats about market trends 
            neighborhood_stats_formatted = soup.find(text = 'Neighborhood stats').next_element.get_text()

            # finding if building was recently constructed or renovated from construction details
            construction_details = soup.find_all('span', class_='Text-aiai24-0 cZksOw')
            for item in construction_details:
                if 'new construction' in item.text.lower():
                    construction = item.text.split(':')

            features_list.append(['Total Price', price[1]])
            features_list.append(['Address', address])
            features_list.append(sqft)
            features_list.append(construction)

            # this is code for extracting number of bedroom/baths from a separate div
            # then formatting it to match our features from the first table and appending
            # to feature list
            beds_baths = soup.find(text='Bedrooms and bathrooms').next_element.text
            beds_baths = re.split('(\d+)',beds_baths.replace('1/2', 'Half'))[:-1]
            bed_baths_formatted = [i+j for i,j in zip(beds_baths[::2], beds_baths[1::2])]

            for item in bed_baths_formatted:
                features_list.append(item.split(':'))

            features_list.append(['neighborhood_stats', neighborhood_stats_formatted])
            features_list.append(['URL', link])

            print(features_list)
            return dict(features_list)
        else:
            # if the status isnt listed as sold just skip this property
            # we dont want to wind up with a bunch of rentals that we cant scrape
            pass
    except:
        return None

# %%
def generate_page_urls(location, sold=False):
    """
    Description: get urls for first 20 pages for a location
    Parameter 1: location (str): e.g. 'chicago-il'
    Parameter 2: status (str): 'sold' or 'for_sale'
    
    Return: first 20 page urls (list)
    """
    
    if sold:
        base_url = 'https://www.zillow.com/{}/sold/'.format(location)
    else:
        base_url = 'https://www.zillow.com/homes/{}/'.format(location)
    
    first_20_pages_ext = [base_url + str(i) + '_p' for i in range(2,21)]
    # as ganesh pointed out im not adding url for first page so im appending it here...
    first_20_pages_ext.append(base_url)
    return first_20_pages_ext

# %%
def get_all_property_urls(first_20_pages_ext):
    
    """
    Description: Get all the property urls for each page on Zillow
    Parameters: first 20 pages of urls (list)
    Return: urls for every property on each of the 20 pages
    """
    
    all_pages_property_urls = []
    for link in first_20_pages_ext:
        all_pages_property_urls.append(get_property_urls(link))

    # so right now i have a list of list and i want to flatten it for convenience
    all_urls = np.array(all_pages_property_urls).flatten()
    return all_urls

# %%
first_20_pages_ext = generate_page_urls('chicago-il', sold=False)
all_urls = get_all_property_urls(first_20_pages_ext)

# %%
########################## testing area ##############################

# %%
########################## testing end ##############################

# %%
# so this is where we are iterating over all the property links and calling our
# functions to scrape details from each url and return a dictionary of values
# also tracking when and on which links our functions failed to sucessfully scrape data
# so far bum links is usually only about 20 out of 800 so I'll live

data_list = []
bum_links = []
for link in all_urls:
    print(link)
    
    # change this to get property_features_sold if you want home info on properties
    # with the sold status... 
    data_raw = get_property_features(link)
    if data_raw != None:
        data_list.append(data_raw)
    else:
        # creating this so we can see what links didnt work and look into why later
        bum_links.append(link)
# Out:
# https://www.zillow.com/homedetails/4033-W-Van-Buren-St-Chicago-IL-60624/2094762639_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1900'], ['Heating', 'Gas'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Total Price', '$99,000'], ['Address', '4033 W Van Buren St, Chicago, IL 60624'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in West Garfield Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in West Garfield Park will rise 7.1% (↑) in the next year.This home is valued 12.6% lower (↓) than the median home in West Garfield Park.The median Zestimate® for this neighborhood is $113,328.'], ['URL', 'https://www.zillow.com/homedetails/4033-W-Van-Buren-St-Chicago-IL-60624/2094762639_zpid/']]
# https://www.zillow.com/homedetails/4817-W-Polk-St-Chicago-IL-60644/3813315_zpid/
# [['Type', 'Single Family'], ['Year built', '1931'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '3,101 sqft'], ['Price/sqft', '$22'], ['Total Price', '$25,000'], ['Address', '4817 W Polk St, Chicago, IL 60644'], ['Square Feet', '1,119'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 60644 have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Lawndale will increase 1.7% (↑) in the next year.This home is valued 84% lower (↓) than the median home in Lawndale.The median Zestimate® for this neighborhood is $156,242.'], ['URL', 'https://www.zillow.com/homedetails/4817-W-Polk-St-Chicago-IL-60644/3813315_zpid/']]
# https://www.zillow.com/homedetails/3315-W-Sunnyside-Ave-1B-Chicago-IL-60625/2077611698_zpid/
# [['Type', 'Condo'], ['Year built', '1998'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['HOA', '$204/mo'], ['Price/sqft', '$174'], ['Total Price', '$147,500'], ['Address', '3315 W Sunnyside Ave #1B, Chicago, IL 60625'], ['Square Feet', '850'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Albany Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Albany Park will decrease 1.1% (↓) in the next year.This home is valued 53.1% lower (↓) than the median home in Albany Park.The median Zestimate® for this neighborhood is $314,708.'], ['URL', 'https://www.zillow.com/homedetails/3315-W-Sunnyside-Ave-1B-Chicago-IL-60625/2077611698_zpid/']]
# https://www.zillow.com/homedetails/7016-S-Throop-St-Chicago-IL-60636/3998154_zpid/
# [['Type', 'Single Family'], ['Year built', '1908'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '3,746 sqft'], ['Price/sqft', '$40'], ['Total Price', '$59,900'], ['Address', '7016 S Throop St, Chicago, IL 60636'], ['Square Feet', '1,500'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Englewood have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Englewood will rise 9% (↑) in the next year.This home is valued 22.9% higher (↑) than the median home in Englewood.The median Zestimate® for this neighborhood is $48,744.'], ['URL', 'https://www.zillow.com/homedetails/7016-S-Throop-St-Chicago-IL-60636/3998154_zpid/']]
# https://www.zillow.com/homedetails/2008-S-Calumet-Ave-Chicago-IL-60616/65545547_zpid/
# [['Type', 'Single Family'], ['Year built', '2002'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$215/month'], ['Lot', '1,367 sqft'], ['Price/sqft', '$290'], ['Total Price', '$725,000'], ['Address', '2008 S Calumet Ave, Chicago, IL 60616'], ['Square Feet', '2,500'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in South Loop have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in South Loop will rise 3.2% (↑) in the next year.This home is valued 92.4% higher (↑) than the median home in South Loop.The median Zestimate® for this neighborhood is $376,901.'], ['URL', 'https://www.zillow.com/homedetails/2008-S-Calumet-Ave-Chicago-IL-60616/65545547_zpid/']]
# https://www.zillow.com/homedetails/5050-S-East-End-Ave-APT-3D-Chicago-IL-60615/2089435498_zpid/
# [['Type', 'Condo'], ['Year built', '1955'], ['Heating', 'Radiant'], ['Cooling', 'No Data'], ['Parking', 'None'], ['HOA', '$916/month'], ['Price/sqft', '$116'], ['Total Price', '$159,500'], ['Address', '5050 S East End Ave APT 3D, Chicago, IL 60615'], ['Square Feet', '1,375'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Kenwood have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Kenwood will fall 1.5% (↓) in the next year.This home is valued 53.3% lower (↓) than the median home in Kenwood.The median Zestimate® for this neighborhood is $341,888.'], ['URL', 'https://www.zillow.com/homedetails/5050-S-East-End-Ave-APT-3D-Chicago-IL-60615/2089435498_zpid/']]
# https://www.zillow.com/homedetails/235-W-Van-Buren-St-UNIT-3520-Chicago-IL-60607/159464613_zpid/
# [['Type', 'Condo'], ['Year built', '2009'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['HOA', '$297/mo'], ['Price/sqft', '$334'], ['Total Price', '$232,000'], ['Address', '235 W Van Buren St UNIT 3520, Chicago, IL 60607'], ['Square Feet', '695'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in The Loop have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in The Loop will decrease 3.3% (↓) in the next year.This home is valued 37.2% lower (↓) than the median home in The Loop.The median Zestimate® for this neighborhood is $369,141.'], ['URL', 'https://www.zillow.com/homedetails/235-W-Van-Buren-St-UNIT-3520-Chicago-IL-60607/159464613_zpid/']]
# https://www.zillow.com/homedetails/2753-W-Jackson-Blvd-Chicago-IL-60612/2133403662_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1886'], ['Heating', 'Forced air, Gas'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Total Price', '$249,900'], ['Address', '2753 W Jackson Blvd, Chicago, IL 60612'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 8'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Near West Side have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Near West Side will increase 1.8% (↑) in the next year.This home is valued 40.6% lower (↓) than the median home in Near West Side.The median Zestimate® for this neighborhood is $420,759.'], ['URL', 'https://www.zillow.com/homedetails/2753-W-Jackson-Blvd-Chicago-IL-60612/2133403662_zpid/']]
# https://www.zillow.com/homedetails/5323-W-Race-Ave-Chicago-IL-60644/3808638_zpid/
# [['Type', 'Single Family'], ['Year built', '1895'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '4,399 sqft'], ['Price/sqft', '$110'], ['Total Price', '$225,000'], ['Address', '5323 W Race Ave, Chicago, IL 60644'], ['Square Feet', '2,045'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in South Austin have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in South Austin will increase 3.4% (↑) in the next year.This home is valued 32.7% higher (↑) than the median home in South Austin.The median Zestimate® for this neighborhood is $169,507.'], ['URL', 'https://www.zillow.com/homedetails/5323-W-Race-Ave-Chicago-IL-60644/3808638_zpid/']]
# https://www.zillow.com/homedetails/5931-S-Campbell-Ave-Chicago-IL-60629/2142525861_zpid/
# [['Type', 'Multi Family'], ['Year built', '1921'], ['Heating', 'Forced air'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Price/sqft', 'No Data'], ['Total Price', '$279,900'], ['Address', '5931 S Campbell Ave, Chicago, IL 60629'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Chicago Lawn have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Chicago Lawn will increase 1.8% (↑) in the next year.This home is valued 69.6% higher (↑) than the median home in Chicago Lawn.The median Zestimate® for this neighborhood is $165,068.'], ['URL', 'https://www.zillow.com/homedetails/5931-S-Campbell-Ave-Chicago-IL-60629/2142525861_zpid/']]
# https://www.zillow.com/homedetails/11117-S-Sawyer-Ave-Chicago-IL-60655/4096742_zpid/
# [['Type', 'Single Family'], ['Year built', '1924'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '3,789 sqft'], ['Price/sqft', '$141'], ['Total Price', '$138,970'], ['Address', '11117 S Sawyer Ave, Chicago, IL 60655'], ['Square Feet', '988'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Mount Greenwood have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Mount Greenwood will rise 1.5% (↑) in the next year.This home is valued 42.8% lower (↓) than the median home in Mount Greenwood.The median Zestimate® for this neighborhood is $242,860.'], ['URL', 'https://www.zillow.com/homedetails/11117-S-Sawyer-Ave-Chicago-IL-60655/4096742_zpid/']]
# https://www.zillow.com/homedetails/7151-S-Green-St-Chicago-IL-60621/2077613010_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1930'], ['Heating', 'Forced air'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Total Price', '$99,900'], ['Address', '7151 S Green St, Chicago, IL 60621'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Englewood have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Englewood will rise 9% (↑) in the next year.This home is valued 104.9% higher (↑) than the median home in Englewood.The median Zestimate® for this neighborhood is $48,744.'], ['URL', 'https://www.zillow.com/homedetails/7151-S-Green-St-Chicago-IL-60621/2077613010_zpid/']]
# https://www.zillow.com/homedetails/620-W-60th-St-Chicago-IL-60621/3991519_zpid/
# [['Type', 'Single Family'], ['Year built', '1898'], ['Heating', 'Gas'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['HOA', 'None'], ['Lot', '3,301 sqft'], ['Price/sqft', '$27'], ['Total Price', '$39,900'], ['Address', '620 W 60th St, Chicago, IL 60621'], ['Square Feet', '1,498'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Englewood have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Englewood will increase 9% (↑) in the next year.This home is valued 18.1% lower (↓) than the median home in Englewood.The median Zestimate® for this neighborhood is $48,744.'], ['URL', 'https://www.zillow.com/homedetails/620-W-60th-St-Chicago-IL-60621/3991519_zpid/']]
# https://www.zillow.com/homedetails/5148-N-Monitor-Ave-APT-202-Chicago-IL-60630/63692654_zpid/
# [['Type', 'Condo'], ['Year built', '1934'], ['Heating', 'Forced air, Gas'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['HOA', '$234/mo'], ['Price/sqft', '$169'], ['Total Price', '$168,900'], ['Address', '5148 N Monitor Ave APT 202, Chicago, IL 60630'], ['Square Feet', '1,000'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Jefferson Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Jefferson Park will fall 2.4% (↓) in the next year.This home is valued 44.3% lower (↓) than the median home in Jefferson Park.The median Zestimate® for this neighborhood is $303,165.'], ['URL', 'https://www.zillow.com/homedetails/5148-N-Monitor-Ave-APT-202-Chicago-IL-60630/63692654_zpid/']]
# https://www.zillow.com/homedetails/7828-S-Colfax-Ave-Chicago-IL-60649/2077613653_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1922'], ['Heating', 'Forced air, Gas'], ['Cooling', 'No Data'], ['Parking', '3 spaces'], ['Total Price', '$320,000'], ['Address', '7828 S Colfax Ave, Chicago, IL 60649'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 9'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in South Shore have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in South Shore will increase 4.3% (↑) in the next year.This home is valued 194.7% higher (↑) than the median home in South Shore.The median Zestimate® for this neighborhood is $108,577.'], ['URL', 'https://www.zillow.com/homedetails/7828-S-Colfax-Ave-Chicago-IL-60649/2077613653_zpid/']]
# https://www.zillow.com/homedetails/1211-N-Honore-St-B-Chicago-IL-60622/3860141_zpid/
# [['Type', 'Condo'], ['Year built', '1892'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', 'None'], ['HOA', '$224/month'], ['Price/sqft', '$272'], ['Total Price', '$299,000'], ['Address', '1211 N Honore St #B, Chicago, IL 60622'], ['Square Feet', '1,100'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Wicker Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Wicker Park will rise 1.1% (↑) in the next year.This home is valued 48.9% lower (↓) than the median home in Wicker Park.The median Zestimate® for this neighborhood is $585,609.'], ['URL', 'https://www.zillow.com/homedetails/1211-N-Honore-St-B-Chicago-IL-60622/3860141_zpid/']]
# https://www.zillow.com/homedetails/348-W-109th-St-Chicago-IL-60628/4143151_zpid/
# [['Type', 'Single Family'], ['Year built', '1901'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', 'None'], ['HOA', 'None'], ['Lot', '3,101 sqft'], ['Price/sqft', '$33'], ['Total Price', '$39,900'], ['Address', '348 W 109th St, Chicago, IL 60628'], ['Square Feet', '1,200'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Roseland have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Roseland will increase 3.9% (↑) in the next year.This home is valued 52.5% lower (↓) than the median home in Roseland.The median Zestimate® for this neighborhood is $83,973.'], ['URL', 'https://www.zillow.com/homedetails/348-W-109th-St-Chicago-IL-60628/4143151_zpid/']]
# https://www.zillow.com/homedetails/2226-N-Kostner-Ave-Chicago-IL-60639/2077613898_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1916'], ['Heating', 'Gas'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Total Price', '$230,000'], ['Address', '2226 N Kostner Ave, Chicago, IL 60639'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Hermosa have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Hermosa will fall 0% (↓) in the next year.This home is valued 7.9% lower (↓) than the median home in Hermosa.The median Zestimate® for this neighborhood is $249,786.'], ['URL', 'https://www.zillow.com/homedetails/2226-N-Kostner-Ave-Chicago-IL-60639/2077613898_zpid/']]
# https://www.zillow.com/homedetails/6014-N-Wolcott-Ave-APT-2N-Chicago-IL-60660/80834208_zpid/
# [['Type', 'Condo'], ['Year built', '2005'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$214/month'], ['Price/sqft', '$256'], ['Total Price', '$319,900'], ['Address', '6014 N Wolcott Ave APT 2N, Chicago, IL 60660'], ['Square Feet', '1,250'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in West Rogers Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in West Rogers Park will increase 1.7% (↑) in the next year.This home is valued 5.3% higher (↑) than the median home in West Rogers Park.The median Zestimate® for this neighborhood is $303,895.'], ['URL', 'https://www.zillow.com/homedetails/6014-N-Wolcott-Ave-APT-2N-Chicago-IL-60660/80834208_zpid/']]
# https://www.zillow.com/homedetails/340-W-Diversey-Pkwy-APT-1219-Chicago-IL-60657/3723188_zpid/
# [['Type', 'Condo'], ['Year built', '1957'], ['Heating', 'Forced air'], ['Cooling', 'Other'], ['Parking', 'No Data'], ['HOA', '$1,106/mo'], ['Price/sqft', '$291'], ['Total Price', '$409,000'], ['Address', '340 W Diversey Pkwy APT 1219, Chicago, IL 60657'], ['Square Feet', '1,407'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Lake View East have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Lake View East will decrease 0.6% (↓) in the next year.This home is valued 29.6% higher (↑) than the median home in Lake View East.The median Zestimate® for this neighborhood is $315,541.'], ['URL', 'https://www.zillow.com/homedetails/340-W-Diversey-Pkwy-APT-1219-Chicago-IL-60657/3723188_zpid/']]
# https://www.zillow.com/homedetails/5104-W-Dakin-St-Chicago-IL-60641/3663101_zpid/
# [['Type', 'Single Family'], ['Year built', '1906'], ['Heating', 'Radiant, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Lot', '3,075 sqft'], ['Price/sqft', '$157'], ['Total Price', '$339,000'], ['Address', '5104 W Dakin St, Chicago, IL 60641'], ['Square Feet', '2,163'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Portage Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Portage Park will fall 2% (↓) in the next year.This home is valued 16.9% higher (↑) than the median home in Portage Park.The median Zestimate® for this neighborhood is $289,874.'], ['URL', 'https://www.zillow.com/homedetails/5104-W-Dakin-St-Chicago-IL-60641/3663101_zpid/']]
# https://www.zillow.com/homedetails/2111-W-Churchill-St-APT-212-Chicago-IL-60647/63696134_zpid/
# [['Type', 'Condo'], ['Year built', '2002'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$303/mo'], ['Price/sqft', '$400'], ['Total Price', '$339,900'], ['Address', '2111 W Churchill St APT 212, Chicago, IL 60647'], ['Square Feet', '850'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Bucktown have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Bucktown will rise 0.5% (↑) in the next year.This home is valued 43.5% lower (↓) than the median home in Bucktown.The median Zestimate® for this neighborhood is $601,188.'], ['URL', 'https://www.zillow.com/homedetails/2111-W-Churchill-St-APT-212-Chicago-IL-60647/63696134_zpid/']]
# https://www.zillow.com/homedetails/3506-W-66th-Pl-Chicago-IL-60629/3953666_zpid/
# [['Type', 'Single Family'], ['Year built', '1926'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '4,702 sqft'], ['Price/sqft', '$150'], ['Total Price', '$249,000'], ['Address', '3506 W 66th Pl, Chicago, IL 60629'], ['Square Feet', '1,663'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Marquette Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Marquette Park will increase 0.3% (↑) in the next year.This home is valued 53.9% higher (↑) than the median home in Marquette Park.The median Zestimate® for this neighborhood is $161,845.'], ['URL', 'https://www.zillow.com/homedetails/3506-W-66th-Pl-Chicago-IL-60629/3953666_zpid/']]
# https://www.zillow.com/homedetails/8626-S-Carpenter-St-Chicago-IL-60620/2137002729_zpid/
# [['Type', 'Multi Family'], ['Year built', '1905'], ['Heating', 'Gas'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Price/sqft', 'No Data'], ['Total Price', '$99,900'], ['Address', '8626 S Carpenter St, Chicago, IL 60620'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Gresham have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Gresham will fall 3.6% (↓) in the next year.This home is valued 20.8% lower (↓) than the median home in Gresham.The median Zestimate® for this neighborhood is $126,118.'], ['URL', 'https://www.zillow.com/homedetails/8626-S-Carpenter-St-Chicago-IL-60620/2137002729_zpid/']]
# https://www.zillow.com/homedetails/1337-N-Ashland-Ave-SUITE-4-Chicago-IL-60622/89941191_zpid/
# [['Type', 'Condo'], ['Year built', '2007'], ['Heating', 'Electric, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Total Price', '$499,900'], ['Address', '1337 N Ashland Ave SUITE 4, Chicago, IL 60622'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Noble Square have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Noble Square will fall 0.4% (↓) in the next year.This home is valued 2.7% higher (↑) than the median home in Noble Square.The median Zestimate® for this neighborhood is $486,715.'], ['URL', 'https://www.zillow.com/homedetails/1337-N-Ashland-Ave-SUITE-4-Chicago-IL-60622/89941191_zpid/']]
# https://www.zillow.com/homedetails/437-W-Division-St-APT-311-Chicago-IL-60610/101363003_zpid/
# [['Type', 'Condo'], ['Year built', '2008'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$450/month'], ['Price/sqft', '$277'], ['Total Price', '$360,000'], ['Address', '437 W Division St APT 311, Chicago, IL 60610'], ['Square Feet', '1,300'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 60610 have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Cabrini Green will fall 0.3% (↓) in the next year.This home is valued 15.9% lower (↓) than the median home in Cabrini Green.The median Zestimate® for this neighborhood is $427,846.'], ['URL', 'https://www.zillow.com/homedetails/437-W-Division-St-APT-311-Chicago-IL-60610/101363003_zpid/']]
# https://www.zillow.com/homedetails/728-W-Jackson-Blvd-APT-823-Chicago-IL-60661/3871263_zpid/
# [['Type', 'Condo'], ['Year built', '1915'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$616/mo'], ['Price/sqft', '$325'], ['Total Price', '$389,999'], ['Address', '728 W Jackson Blvd APT 823, Chicago, IL 60661'], ['Square Feet', '1,200'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in West Loop Gate have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in West Loop Gate will fall 0.5% (↓) in the next year.This home is valued 15.1% higher (↑) than the median home in West Loop Gate.The median Zestimate® for this neighborhood is $338,772.'], ['URL', 'https://www.zillow.com/homedetails/728-W-Jackson-Blvd-APT-823-Chicago-IL-60661/3871263_zpid/']]
# https://www.zillow.com/homedetails/7047-S-Carpenter-St-Chicago-IL-60621/2091230047_zpid/
# [['Type', 'Multi Family'], ['Year built', '1905'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Price/sqft', 'No Data'], ['Total Price', '$99,900'], ['Address', '7047 S Carpenter St, Chicago, IL 60621'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Englewood have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Englewood will rise 9% (↑) in the next year.This home is valued 104.9% higher (↑) than the median home in Englewood.The median Zestimate® for this neighborhood is $48,744.'], ['URL', 'https://www.zillow.com/homedetails/7047-S-Carpenter-St-Chicago-IL-60621/2091230047_zpid/']]
# https://www.zillow.com/homedetails/1560-N-Sandburg-Ter-APT-4211-Chicago-IL-60610/3854198_zpid/
# [['Type', 'Condo'], ['Year built', '1970'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$698/month'], ['Price/sqft', '$344'], ['Total Price', '$275,000'], ['Address', '1560 N Sandburg Ter APT 4211, Chicago, IL 60610'], ['Square Feet', '800'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Old Town have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Old Town will decrease 0.2% (↓) in the next year.This home is valued 31% lower (↓) than the median home in Old Town.The median Zestimate® for this neighborhood is $398,382.'], ['URL', 'https://www.zillow.com/homedetails/1560-N-Sandburg-Ter-APT-4211-Chicago-IL-60610/3854198_zpid/']]
# https://www.zillow.com/homedetails/1310-N-Hoyne-Ave-Chicago-IL-60622/2128767349_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1887'], ['Heating', 'Forced air, Gas'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Price/sqft', '$941'], ['Total Price', '$1,600,000'], ['Address', '1310 N Hoyne Ave, Chicago, IL 60622'], ['Square Feet', '1,700'], ['New construction', ' No'], ['Bedrooms', ' 10'], ['Bathrooms', ' 5'], ['Full bathrooms', ' 5'], ['neighborhood_stats', 'Home values in Wicker Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Wicker Park will rise 1.1% (↑) in the next year.This home is valued 173.2% higher (↑) than the median home in Wicker Park.The median Zestimate® for this neighborhood is $585,609.'], ['URL', 'https://www.zillow.com/homedetails/1310-N-Hoyne-Ave-Chicago-IL-60622/2128767349_zpid/']]
# https://www.zillow.com/homedetails/14-N-Francisco-Ave-Chicago-IL-60612/2077616739_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1890'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Total Price', '$199,999'], ['Address', '14 N Francisco Ave, Chicago, IL 60612'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in East Garfield Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Garfield Park will increase 8.8% (↑) in the next year.This home is valued 24.9% higher (↑) than the median home in East Garfield Park.The median Zestimate® for this neighborhood is $160,150.'], ['URL', 'https://www.zillow.com/homedetails/14-N-Francisco-Ave-Chicago-IL-60612/2077616739_zpid/']]
# https://www.zillow.com/homedetails/1700-S-Prairie-Ave-3-Chicago-IL-60616/253420054_zpid/
# [['Type', 'Townhouse'], ['Year built', '2017'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$283/month'], ['Lot', '1,011 sqft'], ['Price/sqft', '$359'], ['Total Price', '$1,089,000'], ['Address', '1700 S Prairie Ave #3, Chicago, IL 60616'], ['Square Feet', '3,030'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 5'], ['Full bathrooms', ' 4'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in South Loop have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in South Loop will rise 3.2% (↑) in the next year.This home is valued 188.9% higher (↑) than the median home in South Loop.The median Zestimate® for this neighborhood is $376,901.'], ['URL', 'https://www.zillow.com/homedetails/1700-S-Prairie-Ave-3-Chicago-IL-60616/253420054_zpid/']]
# https://www.zillow.com/homedetails/1932-1934-N-Seminary-Ave-Chicago-IL-60614/2077617229_zpid/
# [['Type', 'Single Family'], ['Year built', '1894'], ['Heating', 'Baseboard, Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '6,451 sqft'], ['Price/sqft', '$452'], ['Total Price', '$2,499,500'], ['Address', '1932-1934 N Seminary Ave, Chicago, IL 60614'], ['Square Feet', '5,534'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 4'], ['neighborhood_stats', 'Home values in Wrightwood Neighbors have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Wrightwood Neighbors will fall 0.5% (↓) in the next year.This home is valued 269.1% higher (↑) than the median home in Wrightwood Neighbors.The median Zestimate® for this neighborhood is $677,229.'], ['URL', 'https://www.zillow.com/homedetails/1932-1934-N-Seminary-Ave-Chicago-IL-60614/2077617229_zpid/']]
# https://www.zillow.com/homedetails/4647-N-Drake-Ave-G-Chicago-IL-60625/2077617318_zpid/
# [['Type', 'Condo'], ['Year built', '1920'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$196/month'], ['Price/sqft', '$164'], ['Total Price', '$229,900'], ['Address', '4647 N Drake Ave #G, Chicago, IL 60625'], ['Square Feet', '1,400'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Albany Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Albany Park will fall 1.1% (↓) in the next year.This home is valued 26.9% lower (↓) than the median home in Albany Park.The median Zestimate® for this neighborhood is $314,708.'], ['URL', 'https://www.zillow.com/homedetails/4647-N-Drake-Ave-G-Chicago-IL-60625/2077617318_zpid/']]
# https://www.zillow.com/homedetails/3048-N-Greenview-Ave-2-Chicago-IL-60657/65547529_zpid/
# [['Type', 'Condo'], ['Year built', '2001'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$283/month'], ['Price/sqft', '$282'], ['Total Price', '$700,000'], ['Address', '3048 N Greenview Ave #2, Chicago, IL 60657'], ['Square Feet', '2,481'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Lake View have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Lake View will fall 0.3% (↓) in the next year.This home is valued 29.5% higher (↑) than the median home in Lake View.The median Zestimate® for this neighborhood is $540,603.'], ['URL', 'https://www.zillow.com/homedetails/3048-N-Greenview-Ave-2-Chicago-IL-60657/65547529_zpid/']]
# https://www.zillow.com/homedetails/4987-N-Kolmar-Ave-Chicago-IL-60630/3638896_zpid/
# [['Type', 'Single Family'], ['Year built', '1921'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '4,260 sqft'], ['Price/sqft', '$263'], ['Total Price', '$499,900'], ['Address', '4987 N Kolmar Ave, Chicago, IL 60630'], ['Square Feet', '1,900'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Albany Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Albany Park will fall 1.1% (↓) in the next year.This home is valued 58.8% higher (↑) than the median home in Albany Park.The median Zestimate® for this neighborhood is $314,708.'], ['URL', 'https://www.zillow.com/homedetails/4987-N-Kolmar-Ave-Chicago-IL-60630/3638896_zpid/']]
# https://www.zillow.com/homedetails/346-W-106th-St-Chicago-IL-60628/4141795_zpid/
# [['Type', 'Single Family'], ['Year built', '1954'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '3,998 sqft'], ['Total Price', '$144,648'], ['Address', '346 W 106th St, Chicago, IL 60628'], ['Square Feet', '1,500'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['neighborhood_stats', 'Home values in Fernwood have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Fernwood will increase 0.8% (↑) in the next year.This home is valued 100% lower (↓) than the median home in Fernwood.The median Zestimate® for this neighborhood is $91,990.'], ['URL', 'https://www.zillow.com/homedetails/346-W-106th-St-Chicago-IL-60628/4141795_zpid/']]
# https://www.zillow.com/homedetails/3555-W-Sunnyside-Ave-APT-2-Chicago-IL-60625/49917060_zpid/
# [['Type', 'Condo'], ['Year built', '1923'], ['Heating', 'Gas'], ['Cooling', 'No Data'], ['Parking', 'None'], ['HOA', '$254/month'], ['Price/sqft', '$184'], ['Total Price', '$125,000'], ['Address', '3555 W Sunnyside Ave APT 2, Chicago, IL 60625'], ['Square Feet', '680'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Albany Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Albany Park will fall 1.1% (↓) in the next year.This home is valued 60.3% lower (↓) than the median home in Albany Park.The median Zestimate® for this neighborhood is $314,708.'], ['URL', 'https://www.zillow.com/homedetails/3555-W-Sunnyside-Ave-APT-2-Chicago-IL-60625/49917060_zpid/']]
# https://www.zillow.com/homedetails/4007-N-Leamington-Ave-1-Chicago-IL-60641/80846248_zpid/
# [['Type', 'Condo'], ['Year built', '1924'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['HOA', '$162/mo'], ['Total Price', '$139,000'], ['Address', '4007 N Leamington Ave #1, Chicago, IL 60641'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Portage Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Portage Park will decrease 2% (↓) in the next year.This home is valued 52% lower (↓) than the median home in Portage Park.The median Zestimate® for this neighborhood is $289,874.'], ['URL', 'https://www.zillow.com/homedetails/4007-N-Leamington-Ave-1-Chicago-IL-60641/80846248_zpid/']]
# https://www.zillow.com/homedetails/8057-S-Princeton-Ave-Chicago-IL-60620/4017070_zpid/
# [['Type', 'Single Family'], ['Year built', '1930'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '3,836 sqft'], ['Price/sqft', '$67'], ['Total Price', '$129,900'], ['Address', '8057 S Princeton Ave, Chicago, IL 60620'], ['Square Feet', '1,944'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 60620 have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in West Chatham will fall 1.9% (↓) in the next year.This home is valued 0.1% lower (↓) than the median home in West Chatham.The median Zestimate® for this neighborhood is $130,070.'], ['URL', 'https://www.zillow.com/homedetails/8057-S-Princeton-Ave-Chicago-IL-60620/4017070_zpid/']]
# https://www.zillow.com/community/parkline-chicago/2078738227_zpid/
# [['Type', 'Single Family'], ['Year built', 'No Data'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Lot', 'No Data'], ['Price/sqft', '$674'], ['Total Price', '$1,440,000'], ['Address', 'Buildable plan: Plan D, Parkline Chicago, Chicago, IL 60601'], ['sqft', '2,136'], ['New construction', ' Yes'], ['Bedrooms', ' 3'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in The Loop have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in The Loop will decrease 3.3% (↓) in the next year.This home is valued 290.1% higher (↑) than the median home in The Loop.The median Zestimate® for this neighborhood is $369,141.'], ['URL', 'https://www.zillow.com/community/parkline-chicago/2078738227_zpid/']]
# https://www.zillow.com/homedetails/1829-N-Sheffield-Ave-Chicago-IL-60614/2085554155_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1910'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Total Price', '$1,095,000'], ['Address', '1829 N Sheffield Ave, Chicago, IL 60614'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Ranch Triangle have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Ranch Triangle will decrease 3% (↓) in the next year.This home is valued 54.1% higher (↑) than the median home in Ranch Triangle.The median Zestimate® for this neighborhood is $710,767.'], ['URL', 'https://www.zillow.com/homedetails/1829-N-Sheffield-Ave-Chicago-IL-60614/2085554155_zpid/']]
# https://www.zillow.com/homedetails/1101-S-State-St-APT-704-Chicago-IL-60605/2078705652_zpid/
# [['Type', 'Condo'], ['Year built', '2005'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$1,026/mo'], ['Price/sqft', '$290'], ['Total Price', '$360,000'], ['Address', '1101 S State St APT 704, Chicago, IL 60605'], ['Square Feet', '1,241'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in South Loop have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in South Loop will rise 3.2% (↑) in the next year.This home is valued 4.5% lower (↓) than the median home in South Loop.The median Zestimate® for this neighborhood is $376,901.'], ['URL', 'https://www.zillow.com/homedetails/1101-S-State-St-APT-704-Chicago-IL-60605/2078705652_zpid/']]
# https://www.zillow.com/homedetails/1333-N-Halsted-St-APT-1N-Chicago-IL-60642/63697218_zpid/
# [['Type', 'Condo'], ['Year built', '2002'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$185/mo'], ['Total Price', '$260,000'], ['Address', '1333 N Halsted St APT 1N, Chicago, IL 60642'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Goose Island have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Goose Island will fall 0.6% (↓) in the next year.This home is valued 44% lower (↓) than the median home in Goose Island.The median Zestimate® for this neighborhood is $463,950.'], ['URL', 'https://www.zillow.com/homedetails/1333-N-Halsted-St-APT-1N-Chicago-IL-60642/63697218_zpid/']]
# https://www.zillow.com/homedetails/8346-S-Colfax-Ave-Chicago-IL-60617/2120997247_zpid/
# [['Type', 'Multi Family'], ['Year built', '1927'], ['Heating', 'Forced air'], ['Cooling', 'No Data'], ['Parking', 'None'], ['Price/sqft', 'No Data'], ['Total Price', '$120,000'], ['Address', '8346 S Colfax Ave, Chicago, IL 60617'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in South Chicago have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in South Chicago will fall 5.1% (↓) in the next year.This home is valued 24% higher (↑) than the median home in South Chicago.The median Zestimate® for this neighborhood is $96,782.'], ['URL', 'https://www.zillow.com/homedetails/8346-S-Colfax-Ave-Chicago-IL-60617/2120997247_zpid/']]
# https://www.zillow.com/homedetails/Chicago-IL-60628/2123598574_zpid/
# [['Type', 'Single Family'], ['Year built', '1961'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '4,051 sqft'], ['Price/sqft', '$161'], ['Total Price', '$257,000'], ['Address', '(Undisclosed Address), Chicago, IL 60628'], ['Square Feet', '1,600'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Longwood Manor have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Longwood Manor will decrease 4.4% (↓) in the next year.This home is valued 88.1% higher (↑) than the median home in Longwood Manor.The median Zestimate® for this neighborhood is $136,662.'], ['URL', 'https://www.zillow.com/homedetails/Chicago-IL-60628/2123598574_zpid/']]
# https://www.zillow.com/homedetails/2930-N-Sheridan-Rd-APT-1410-Chicago-IL-60657/89905106_zpid/
# [['Type', 'Condo'], ['Year built', '1968'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', 'None'], ['HOA', '$351/month'], ['Price/sqft', 'No Data'], ['Total Price', '$239,900'], ['Address', '2930 N Sheridan Rd APT 1410, Chicago, IL 60657'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Lake View East have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Lake View East will decrease 0.6% (↓) in the next year.This home is valued 24% lower (↓) than the median home in Lake View East.The median Zestimate® for this neighborhood is $315,541.'], ['URL', 'https://www.zillow.com/homedetails/2930-N-Sheridan-Rd-APT-1410-Chicago-IL-60657/89905106_zpid/']]
# https://www.zillow.com/homedetails/8216-S-Dobson-Ave-APT-E-Chicago-IL-60619/2077618251_zpid/
# [['Type', 'Townhouse'], ['Year built', '1966'], ['Heating', 'Baseboard, Gas'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['Lot', 'No Data'], ['Price/sqft', '$41'], ['Total Price', '$39,900'], ['Address', '8216 S Dobson Ave APT E, Chicago, IL 60619'], ['Square Feet', '980'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in East Chatham have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Chatham will fall 9.5% (↓) in the next year.This home is valued 46.4% lower (↓) than the median home in East Chatham.The median Zestimate® for this neighborhood is $74,450.'], ['URL', 'https://www.zillow.com/homedetails/8216-S-Dobson-Ave-APT-E-Chicago-IL-60619/2077618251_zpid/']]
# https://www.zillow.com/homedetails/520-N-Halsted-St-APT-510-Chicago-IL-60642/70465767_zpid/
# [['Type', 'Condo'], ['Year built', '2005'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$557/month'], ['Price/sqft', '$275'], ['Total Price', '$495,000'], ['Address', '520 N Halsted St APT 510, Chicago, IL 60642'], ['Square Feet', '1,800'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Fulton River District have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Fulton River District will decrease 0.3% (↓) in the next year.This home is valued 6.3% higher (↑) than the median home in Fulton River District.The median Zestimate® for this neighborhood is $465,877.'], ['URL', 'https://www.zillow.com/homedetails/520-N-Halsted-St-APT-510-Chicago-IL-60642/70465767_zpid/']]
# https://www.zillow.com/homedetails/3839-W-Jackson-Blvd-Chicago-IL-60624/2077618941_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1908'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Total Price', '$200,000'], ['Address', '3839 W Jackson Blvd, Chicago, IL 60624'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 8'], ['Bathrooms', ' 5'], ['Full bathrooms', ' 4'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in East Garfield Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Garfield Park will rise 8.8% (↑) in the next year.This home is valued 24.9% higher (↑) than the median home in East Garfield Park.The median Zestimate® for this neighborhood is $160,150.'], ['URL', 'https://www.zillow.com/homedetails/3839-W-Jackson-Blvd-Chicago-IL-60624/2077618941_zpid/']]
# https://www.zillow.com/homedetails/4170-N-Marine-Dr-APT-10L-Chicago-IL-60613/3704707_zpid/
# [['Type', 'Condo'], ['Year built', '1974'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$1,050/mo'], ['Price/sqft', '$242'], ['Total Price', '$379,000'], ['Address', '4170 N Marine Dr APT 10L, Chicago, IL 60613'], ['Square Feet', '1,568'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Uptown have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Uptown will rise 2% (↑) in the next year.This home is valued 24.9% higher (↑) than the median home in Uptown.The median Zestimate® for this neighborhood is $303,469.'], ['URL', 'https://www.zillow.com/homedetails/4170-N-Marine-Dr-APT-10L-Chicago-IL-60613/3704707_zpid/']]
# https://www.zillow.com/homedetails/5851-N-Bernard-St-Chicago-IL-60659/3621091_zpid/
# [['Type', 'Single Family'], ['Year built', '1941'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '3,746 sqft'], ['Price/sqft', '$231'], ['Total Price', '$340,000'], ['Address', '5851 N Bernard St, Chicago, IL 60659'], ['Square Feet', '1,475'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Hollywood Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Hollywood Park will increase 2.4% (↑) in the next year.This home is valued 3% lower (↓) than the median home in Hollywood Park.The median Zestimate® for this neighborhood is $350,566.'], ['URL', 'https://www.zillow.com/homedetails/5851-N-Bernard-St-Chicago-IL-60659/3621091_zpid/']]
# https://www.zillow.com/homedetails/12322-S-Yale-Ave-Chicago-IL-60628/4158399_zpid/
# [['Type', 'Single Family'], ['Year built', '1951'], ['Heating', 'Gas'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['Lot', '4,438 sqft'], ['Price/sqft', '$118'], ['Total Price', '$175,000'], ['Address', '12322 S Yale Ave, Chicago, IL 60628'], ['Square Feet', '1,485'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in West Pullman have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in West Pullman will rise 11.3% (↑) in the next year.This home is valued 81.8% higher (↑) than the median home in West Pullman.The median Zestimate® for this neighborhood is $96,277.'], ['URL', 'https://www.zillow.com/homedetails/12322-S-Yale-Ave-Chicago-IL-60628/4158399_zpid/']]
# https://www.zillow.com/homedetails/2335-W-Iowa-St-APT-2R-Chicago-IL-60622/101453826_zpid/
# [['Type', 'Condo'], ['Year built', '1912'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$472/mo'], ['Price/sqft', '$272'], ['Total Price', '$462,500'], ['Address', '2335 W Iowa St APT 2R, Chicago, IL 60622'], ['Square Feet', '1,700'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Ukrainian Village have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Ukrainian Village will rise 2.5% (↑) in the next year.This home is valued 7.4% lower (↓) than the median home in Ukrainian Village.The median Zestimate® for this neighborhood is $499,489.'], ['URL', 'https://www.zillow.com/homedetails/2335-W-Iowa-St-APT-2R-Chicago-IL-60622/101453826_zpid/']]
# https://www.zillow.com/homedetails/1413-W-Jonquil-Ave-2-Chicago-IL-60626/60260953_zpid/
# ...
# https://www.zillow.com/homedetails/1108-N-Karlov-Ave-Chicago-IL-60651/2106128617_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1913'], ['Heating', 'Gas'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Total Price', '$230,000'], ['Address', '1108 N Karlov Ave, Chicago, IL 60651'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in West Humboldt Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in West Humboldt Park will rise 1.5% (↑) in the next year.This home is valued 24.9% higher (↑) than the median home in West Humboldt Park.The median Zestimate® for this neighborhood is $184,189.'], ['URL', 'https://www.zillow.com/homedetails/1108-N-Karlov-Ave-Chicago-IL-60651/2106128617_zpid/']]
# https://www.zillow.com/homedetails/3127-N-Central-Park-Ave-1-Chicago-IL-60618/2077610562_zpid/
# [['Type', 'Condo'], ['Year built', '2020'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$150/mo'], ['Total Price', '$600,000'], ['Address', '3127 N Central Park Ave #1, Chicago, IL 60618'], ['sqft', '--'], ['New construction', ' Yes'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Logan Square have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Logan Square will increase 1.6% (↑) in the next year.This home is valued 48.6% higher (↑) than the median home in Logan Square.The median Zestimate® for this neighborhood is $403,670.'], ['URL', 'https://www.zillow.com/homedetails/3127-N-Central-Park-Ave-1-Chicago-IL-60618/2077610562_zpid/']]
# https://www.zillow.com/homedetails/438-W-Oak-St-UNIT-5-Chicago-IL-60610/245566846_zpid/
# [['Type', 'Condo'], ['Year built', '2015'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['HOA', '$262/mo'], ['Price/sqft', '$249'], ['Total Price', '$145,700'], ['Address', '438 W Oak St UNIT 5, Chicago, IL 60610'], ['Square Feet', '585'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 60610 have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Cabrini Green will decrease 0.3% (↓) in the next year.This home is valued 65.9% lower (↓) than the median home in Cabrini Green.The median Zestimate® for this neighborhood is $427,846.'], ['URL', 'https://www.zillow.com/homedetails/438-W-Oak-St-UNIT-5-Chicago-IL-60610/245566846_zpid/']]
# https://www.zillow.com/homedetails/235-W-Van-Buren-St-UNIT-2812-Chicago-IL-60607/159467772_zpid/
# [['Type', 'Condo'], ['Year built', '2009'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', 'Attached Garage'], ['HOA', '$456/month'], ['Price/sqft', '$325'], ['Total Price', '$410,000'], ['Address', '235 W Van Buren St UNIT 2812, Chicago, IL 60607'], ['Square Feet', '1,260'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in The Loop have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in The Loop will fall 3.3% (↓) in the next year.This home is valued 11.1% higher (↑) than the median home in The Loop.The median Zestimate® for this neighborhood is $369,141.'], ['URL', 'https://www.zillow.com/homedetails/235-W-Van-Buren-St-UNIT-2812-Chicago-IL-60607/159467772_zpid/']]
# https://www.zillow.com/homedetails/3127-N-Central-Park-Ave-Chicago-IL-60618/2077610604_zpid/
# [['Type', 'Condo'], ['Year built', '2020'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$150/month'], ['Price/sqft', 'No Data'], ['Total Price', '$550,000'], ['Address', '3127 N Central Park Ave, Chicago, IL 60618'], ['sqft', '--'], ['New construction', ' Yes'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Logan Square have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Logan Square will rise 1.6% (↑) in the next year.This home is valued 36.2% higher (↑) than the median home in Logan Square.The median Zestimate® for this neighborhood is $403,670.'], ['URL', 'https://www.zillow.com/homedetails/3127-N-Central-Park-Ave-Chicago-IL-60618/2077610604_zpid/']]
# https://www.zillow.com/homedetails/4724-N-Beacon-St-APT-1W-Chicago-IL-60640/89903415_zpid/
# [['Type', 'Condo'], ['Year built', '1924'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', 'None'], ['HOA', '$203/month'], ['Price/sqft', 'No Data'], ['Total Price', '$220,000'], ['Address', '4724 N Beacon St APT 1W, Chicago, IL 60640'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Uptown have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Uptown will increase 2% (↑) in the next year.This home is valued 27.5% lower (↓) than the median home in Uptown.The median Zestimate® for this neighborhood is $303,469.'], ['URL', 'https://www.zillow.com/homedetails/4724-N-Beacon-St-APT-1W-Chicago-IL-60640/89903415_zpid/']]
# https://www.zillow.com/homedetails/8633-S-Parnell-Ave-Chicago-IL-60620/70478257_zpid/
# [['Type', 'Single Family'], ['Year built', '2004'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '3,748 sqft'], ['Price/sqft', '$150'], ['Total Price', '$275,000'], ['Address', '8633 S Parnell Ave, Chicago, IL 60620'], ['Square Feet', '1,838'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Gresham have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Gresham will decrease 3.6% (↓) in the next year.This home is valued 118% higher (↑) than the median home in Gresham.The median Zestimate® for this neighborhood is $126,118.'], ['URL', 'https://www.zillow.com/homedetails/8633-S-Parnell-Ave-Chicago-IL-60620/70478257_zpid/']]
# https://www.zillow.com/homedetails/5700-S-New-England-Ave-Chicago-IL-60638/3944410_zpid/
# [['Type', 'Single Family'], ['Year built', '1959'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '5,105 sqft'], ['Price/sqft', '$170'], ['Total Price', '$459,900'], ['Address', '5700 S New England Ave, Chicago, IL 60638'], ['Square Feet', '2,700'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Garfield Ridge have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Garfield Ridge will increase 4.1% (↑) in the next year.This home is valued 90.6% higher (↑) than the median home in Garfield Ridge.The median Zestimate® for this neighborhood is $241,329.'], ['URL', 'https://www.zillow.com/homedetails/5700-S-New-England-Ave-Chicago-IL-60638/3944410_zpid/']]
# https://www.zillow.com/homedetails/3127-N-Central-Park-Ave-2-Chicago-IL-60618/2077610702_zpid/
# [['Type', 'Condo'], ['Year built', '2020'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$150/month'], ['Price/sqft', 'No Data'], ['Total Price', '$475,000'], ['Address', '3127 N Central Park Ave #2, Chicago, IL 60618'], ['sqft', '--'], ['New construction', ' Yes'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Logan Square have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Logan Square will increase 1.6% (↑) in the next year.This home is valued 17.7% higher (↑) than the median home in Logan Square.The median Zestimate® for this neighborhood is $403,670.'], ['URL', 'https://www.zillow.com/homedetails/3127-N-Central-Park-Ave-2-Chicago-IL-60618/2077610702_zpid/']]
# https://www.zillow.com/homedetails/5335-W-Winona-St-Chicago-IL-60630/3637411_zpid/
# [['Type', 'Single Family'], ['Year built', '1957'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '5 spaces'], ['Lot', '4,268 sqft'], ['Price/sqft', '$285'], ['Total Price', '$369,900'], ['Address', '5335 W Winona St, Chicago, IL 60630'], ['Square Feet', '1,300'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Jefferson Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Jefferson Park will fall 2.4% (↓) in the next year.This home is valued 22% higher (↑) than the median home in Jefferson Park.The median Zestimate® for this neighborhood is $303,165.'], ['URL', 'https://www.zillow.com/homedetails/5335-W-Winona-St-Chicago-IL-60630/3637411_zpid/']]
# https://www.zillow.com/homedetails/1423-W-Huron-St-Chicago-IL-60642/2077610870_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1870'], ['Heating', 'Gas'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Total Price', '$649,900'], ['Address', '1423 W Huron St, Chicago, IL 60642'], ['sqft', '--'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in West Town have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in West Town will rise 1.7% (↑) in the next year.This home is valued 28.1% higher (↑) than the median home in West Town.The median Zestimate® for this neighborhood is $507,475.'], ['URL', 'https://www.zillow.com/homedetails/1423-W-Huron-St-Chicago-IL-60642/2077610870_zpid/']]
# https://www.zillow.com/homedetails/4848-N-Kedvale-Ave-Chicago-IL-60630/3639824_zpid/
# [['Type', 'Single Family'], ['Year built', '1921'], ['Heating', 'Baseboard'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '4,443 sqft'], ['Price/sqft', '$307'], ['Total Price', '$395,000'], ['Address', '4848 N Kedvale Ave, Chicago, IL 60630'], ['Square Feet', '1,286'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Albany Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Albany Park will fall 1.1% (↓) in the next year.This home is valued 25.5% higher (↑) than the median home in Albany Park.The median Zestimate® for this neighborhood is $314,708.'], ['URL', 'https://www.zillow.com/homedetails/4848-N-Kedvale-Ave-Chicago-IL-60630/3639824_zpid/']]
# https://www.zillow.com/homedetails/2233-W-69th-St-Chicago-IL-60636/3996156_zpid/
# [['Type', 'Single Family'], ['Year built', '1929'], ['Heating', 'Forced air'], ['Cooling', 'No Data'], ['Parking', 'None'], ['HOA', 'None'], ['Lot', '3,123 sqft'], ['Price/sqft', '$62'], ['Total Price', '$49,900'], ['Address', '2233 W 69th St, Chicago, IL 60636'], ['Square Feet', '800'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in West Englewood have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in West Englewood will decrease 4.3% (↓) in the next year.This home is valued 20.1% lower (↓) than the median home in West Englewood.The median Zestimate® for this neighborhood is $62,424.'], ['URL', 'https://www.zillow.com/homedetails/2233-W-69th-St-Chicago-IL-60636/3996156_zpid/']]
# https://www.zillow.com/homedetails/11001-S-Saint-Louis-Ave-Chicago-IL-60655/4084054_zpid/
# [['Type', 'Single Family'], ['Year built', '1940'], ['Heating', 'Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '3,685 sqft'], ['Price/sqft', '$247'], ['Total Price', '$375,000'], ['Address', '11001 S Saint Louis Ave, Chicago, IL 60655'], ['Square Feet', '1,518'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Mount Greenwood have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Mount Greenwood will rise 1.5% (↑) in the next year.This home is valued 54.4% higher (↑) than the median home in Mount Greenwood.The median Zestimate® for this neighborhood is $242,860.'], ['URL', 'https://www.zillow.com/homedetails/11001-S-Saint-Louis-Ave-Chicago-IL-60655/4084054_zpid/']]
# https://www.zillow.com/homedetails/4741-S-Langley-Ave-3S-Chicago-IL-60615/70477565_zpid/
# [['Type', 'Condo'], ['Year built', '2006'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$281/month'], ['Price/sqft', '$160'], ['Total Price', '$399,900'], ['Address', '4741 S Langley Ave #3S, Chicago, IL 60615'], ['Square Feet', '2,500'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Bronzeville have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Bronzeville will rise 2.7% (↑) in the next year.This home is valued 50.9% higher (↑) than the median home in Bronzeville.The median Zestimate® for this neighborhood is $265,069.'], ['URL', 'https://www.zillow.com/homedetails/4741-S-Langley-Ave-3S-Chicago-IL-60615/70477565_zpid/']]
# https://www.zillow.com/homedetails/2654-W-Fitch-Ave-G-Chicago-IL-60645/2077611157_zpid/
# [['Type', 'Condo'], ['Year built', 'No Data'], ['Heating', 'Gas'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['HOA', '$278/mo'], ['Price/sqft', '$167'], ['Total Price', '$149,900'], ['Address', '2654 W Fitch Ave #G, Chicago, IL 60645'], ['Square Feet', '900'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in West Rogers Park have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in West Rogers Park will increase 1.7% (↑) in the next year.This home is valued 50.7% lower (↓) than the median home in West Rogers Park.The median Zestimate® for this neighborhood is $303,895.'], ['URL', 'https://www.zillow.com/homedetails/2654-W-Fitch-Ave-G-Chicago-IL-60645/2077611157_zpid/']]
# https://www.zillow.com/homedetails/4110-N-Pontiac-Ave-Chicago-IL-60634/3590682_zpid/
# [['Type', 'Single Family'], ['Year built', '1949'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '3,484 sqft'], ['Price/sqft', '$287'], ['Total Price', '$306,000'], ['Address', '4110 N Pontiac Ave, Chicago, IL 60634'], ['Square Feet', '1,066'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Irving Woods have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Irving Woods will decrease 3.6% (↓) in the next year.This home is valued 12.6% higher (↑) than the median home in Irving Woods.The median Zestimate® for this neighborhood is $271,872.'], ['URL', 'https://www.zillow.com/homedetails/4110-N-Pontiac-Ave-Chicago-IL-60634/3590682_zpid/']]
# https://www.zillow.com/homedetails/4817-W-Polk-St-Chicago-IL-60644/3813315_zpid/
# [['Type', 'Single Family'], ['Year built', '1931'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '3,101 sqft'], ['Price/sqft', '$22'], ['Total Price', '$25,000'], ['Address', '4817 W Polk St, Chicago, IL 60644'], ['Square Feet', '1,119'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 60644 have risen 0.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in Lawndale will increase 1.7% (↑) in the next year.This home is valued 84% lower (↓) than the median home in Lawndale.The median Zestimate® for this neighborhood is $156,242.'], ['URL', 'https://www.zillow.com/homedetails/4817-W-Polk-St-Chicago-IL-60644/3813315_zpid/']]

# %%
pd.DataFrame(data_list)
# Out:
#                    Type Year built          Heating  Cooling   Parking  \
# 0    Multiple Occupancy       1900              Gas  No Data   No Data
# 1         Single Family       1931          No Data  No Data  2 spaces
# 2                 Condo       1998  Forced air, Gas  Central   No Data
# 3         Single Family       1908              Gas  Central  2 spaces
# 4         Single Family       2002       Forced air  Central  2 spaces
# ..                  ...        ...              ...      ...       ...
# 775       Single Family       1940              Gas  Central  2 spaces
# 776               Condo       2006       Forced air  Central   1 space
# 777               Condo    No Data              Gas  No Data   No Data
# 778       Single Family       1949  Forced air, Gas  Central  2 spaces
# 779       Single Family       1931          No Data  No Data  2 spaces
#
#     Total Price                                      Address sqft  \
# 0       $99,000       4033 W Van Buren St, Chicago, IL 60624   --
# 1       $25,000            4817 W Polk St, Chicago, IL 60644  NaN
# 2      $147,500  3315 W Sunnyside Ave #1B, Chicago, IL 60625  NaN
# 3       $59,900          7016 S Throop St, Chicago, IL 60636  NaN
# 4      $725,000        2008 S Calumet Ave, Chicago, IL 60616  NaN
# ..          ...                                          ...  ...
# 775    $375,000   11001 S Saint Louis Ave, Chicago, IL 60655  NaN
# 776    $399,900    4741 S Langley Ave #3S, Chicago, IL 60615  NaN
# 777    $149,900       2654 W Fitch Ave #G, Chicago, IL 60645  NaN
# 778    $306,000        4110 N Pontiac Ave, Chicago, IL 60634  NaN
# 779     $25,000            4817 W Polk St, Chicago, IL 60644  NaN
#
#     New construction Bedrooms  ...  \
# 0                 No        6  ...
# 1                 No        3  ...
# 2                 No        1  ...
# 3                 No        3  ...
# 4                 No        3  ...
# ..               ...      ...  ...
# 775               No        3  ...
# 776               No        3  ...
# 777               No        2  ...
# 778               No        2  ...
# 779               No        3  ...
#
#                                                    URL         Lot Price/sqft  \
# 0    https://www.zillow.com/homedetails/4033-W-Van-...         NaN        NaN
# 1    https://www.zillow.com/homedetails/4817-W-Polk...  3,101 sqft        $22
# 2    https://www.zillow.com/homedetails/3315-W-Sunn...         NaN       $174
# 3    https://www.zillow.com/homedetails/7016-S-Thro...  3,746 sqft        $40
# 4    https://www.zillow.com/homedetails/2008-S-Calu...  1,367 sqft       $290
# ..                                                 ...         ...        ...
# 775  https://www.zillow.com/homedetails/11001-S-Sai...  3,685 sqft       $247
# 776  https://www.zillow.com/homedetails/4741-S-Lang...         NaN       $160
# 777  https://www.zillow.com/homedetails/2654-W-Fitc...         NaN       $167
# 778  https://www.zillow.com/homedetails/4110-N-Pont...  3,484 sqft       $287
# 779  https://www.zillow.com/homedetails/4817-W-Polk...  3,101 sqft        $22
#
#     Square Feet         HOA Half bathrooms Date available Pets Laundry  \
# 0           NaN         NaN            NaN            NaN  NaN     NaN
# 1         1,119         NaN            NaN            NaN  NaN     NaN
# 2           850     $204/mo            NaN            NaN  NaN     NaN
# 3         1,500         NaN              1            NaN  NaN     NaN
# 4         2,500  $215/month              1            NaN  NaN     NaN
# ..          ...         ...            ...            ...  ...     ...
# 775       1,518        None            NaN            NaN  NaN     NaN
# 776       2,500  $281/month            NaN            NaN  NaN     NaN
# 777         900     $278/mo            NaN            NaN  NaN     NaN
# 778       1,066         NaN            NaN            NaN  NaN     NaN
# 779       1,119        None            NaN            NaN  NaN     NaN
#
#     Deposit & fees
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 775            NaN
# 776            NaN
# 777            NaN
# 778            NaN
# 779            NaN
#
# [780 rows x 23 columns]

# %%
# data_list
df = pd.DataFrame(data_list)
# df.to_csv('sold_raw.csv', header=True)

# %%
df_full = pd.read_csv('/Users/collinswestnedge/programming/Metis_Online/project_02/clean_data/chicago_full_clean.csv')
df_full.drop(columns=['Unnamed: 0'])
# Out:
#                Type  Year built     Heating  Cooling   Parking  Total Price  \
# 0      Multi Family      1921.0  Forced air     None  2 spaces     279900.0
# 1     Single Family      1924.0         Gas  Central  2 spaces     138970.0
# 2      Multi Family      1930.0  Forced air     None       NaN      99900.0
# 3     Single Family      1898.0         Gas     None   1 space      39900.0
# 4             Condo      1934.0  Forced air     None       NaN     168900.0
# ...             ...         ...         ...      ...       ...          ...
# 1064          Condo      1926.0         NaN     None       NaN     173000.0
# 1065   Multi Family      1924.0       Other     None  3 spaces     625000.0
# 1066          Condo      1987.0  Forced air  Central   1 space     173000.0
# 1067          Condo      1974.0         Gas  Central   1 space     212500.0
# 1068  Single Family      1953.0         Gas  Central  2 spaces     622000.0
#
#                                                Address New construction  \
# 0               5931 S Campbell Ave, Chicago, IL 60629               No
# 1                11117 S Sawyer Ave, Chicago, IL 60655               No
# 2                   7151 S Green St, Chicago, IL 60621               No
# 3                     620 W 60th St, Chicago, IL 60621               No
# 4        5148 N Monitor Ave APT 202, Chicago, IL 60630               No
# ...                                                ...              ...
# 1064         1221 W Lunt Ave APT 2B, Chicago, IL 60626               No
# 1065           4941 N Francisco Ave, Chicago, IL 60625               No
# 1066  3660 N Lake Shore Dr APT 2809, Chicago, IL 60613               No
# 1067     1540 N La Salle Dr APT 303, Chicago, IL 60610               No
# 1068             4583 N Melvina Ave, Chicago, IL 60630               No
#
#       Bedrooms  Bathrooms  Full bathrooms  \
# 0            6        3.0             3.0
# 1            3        1.0             1.0
# 2            6        2.0             2.0
# 3            4        2.0             2.0
# 4            2        1.0             1.0
# ...        ...        ...             ...
# 1064         2        1.0             1.0
# 1065         5        3.0             3.0
# 1066         0        1.0             1.0
# 1067         1        1.0             1.0
# 1068         5        3.0             3.0
#
#                                      neighborhood_stats  \
# 0     Home values in Chicago Lawn have risen 0.6% ()...
# 1     Home values in Mount Greenwood have risen 0.6%...
# 2     Home values in Englewood have risen 0.6% () ov...
# 3     Home values in Englewood have risen 0.6% () ov...
# 4     Home values in Jefferson Park have risen 0.6% ...
# ...                                                 ...
# 1064  Home values in Rogers Park have risen 0.6 % (↑...
# 1065  Home values in Ravenswood have risen 0.6 % (↑)...
# 1066  Home values in Lake View East have risen 0.6 %...
# 1067  Home values in Old Town have risen 0.6 % (↑) o...
# 1068  Home values in Jefferson Park have risen 0.6 %...
#
#                                                     URL     Lot  Square Feet  \
# 0     https://www.zillow.com/homedetails/5931-S-Camp...     NaN          NaN
# 1     https://www.zillow.com/homedetails/11117-S-Saw...  3789.0        988.0
# 2     https://www.zillow.com/homedetails/7151-S-Gree...     NaN          NaN
# 3     https://www.zillow.com/homedetails/620-W-60th-...  3301.0       1498.0
# 4     https://www.zillow.com/homedetails/5148-N-Moni...     NaN       1000.0
# ...                                                 ...     ...          ...
# 1064  https://www.zillow.com/homedetails/1221-W-Lunt...     NaN        900.0
# 1065  https://www.zillow.com/homedetails/4941-N-Fran...     NaN       1500.0
# 1066  https://www.zillow.com/homedetails/3660-N-Lake...     NaN        550.0
# 1067  https://www.zillow.com/homedetails/1540-N-La-S...     NaN          NaN
# 1068  https://www.zillow.com/homedetails/4583-N-Melv...  3920.0       3500.0
#
#         HOA  Half bathrooms    Status
# 0       NaN               0  For Sale
# 1       NaN               0  For Sale
# 2       NaN               0  For Sale
# 3       NaN               0  For Sale
# 4     234.0               0  For Sale
# ...     ...             ...       ...
# 1064  282.0               0      Sold
# 1065    NaN               0      Sold
# 1066  344.0               0      Sold
# 1067  394.0               0      Sold
# 1068    NaN               0      Sold
#
# [1069 rows x 18 columns]
