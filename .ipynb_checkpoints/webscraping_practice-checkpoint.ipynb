# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time, os
import numpy as np
import requests
import re

# %%
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
def get_property_urls(link):
    # omg thank god for some dude on github for this req_header 0 CAPTCHAS i owe you my life
    
    req_headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-US,en;q=0.8',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
    }


    r = requests.get(link, headers=req_headers)
    soup = BeautifulSoup(r.content, 'html.parser')

    table = soup.find('ul', class_='photo-cards photo-cards_wow photo-cards_short')
    li_tags = table.find_all('li')
    properties = [item.find('div', class_='list-card-info')for item in li_tags]

    property_urls = []

    for item in properties:
        if item != None:
            property_extensions = item.find('a')['href']
            property_urls.append(property_extensions)
            
    return property_urls

# %%
def get_property_features(link):
    try:
    
        req_headers = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'en-US,en;q=0.8',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
        }


        r = requests.get(link, headers=req_headers)
        soup = BeautifulSoup(r.content, 'html.parser')
        facts_and_features_table = soup.find('div', class_='ds-home-facts-and-features reso-facts-features sheety-facts-features')


        # this is the code for extracting features our of the home fact list table
        all_features = facts_and_features_table.find_all('li', class_='ds-home-fact-list-item')
        features_list = [item.text.split(':') for item in all_features]
        price = soup.find('div', class_='ds-home-details-chip').find('span', class_='ds-value').text
        features_list.append(['Total Price', price])

        # this is code for extracting number of bedroom/baths from a separate div
        # then formatting it to match our features from the first table and appending
        # to feature list
        beds_baths = soup.find(text='Bedrooms and bathrooms').next_element.text
        beds_baths = re.split('(\d+)',beds_baths.replace('1/2', 'Half'))[:-1]
        bed_baths_formatted = [i+j for i,j in zip(beds_baths[::2], beds_baths[1::2])]


        for item in bed_baths_formatted:
            features_list.append(item.split(':'))

        print(features_list)
        return features_list
    except:
        return None

# %%
# base_url = 'https://www.zillow.com/homes/chicago_rb/'
base_url = 'https://www.zillow.com/homes/AUSTIN_rb/'
first_20_pages_ext = [base_url + str(i) + '_p' for i in range(2,21)]
# as ganesh pointed out im not adding url for first page so im appending it here...
first_20_pages_ext.append(base_url)
first_20_pages_ext
# Out:
# ['https://www.zillow.com/homes/AUSTIN_rb/2_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/3_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/4_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/5_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/6_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/7_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/8_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/9_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/10_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/11_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/12_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/13_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/14_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/15_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/16_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/17_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/18_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/19_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/20_p',
#  'https://www.zillow.com/homes/AUSTIN_rb/']

# %%
all_pages_property_urls = []
for link in first_20_pages_ext:
    all_pages_property_urls.append(get_property_urls(link))

# %%
# so right now i have a list of list and i want to flatten it for convenience
all_urls = np.array(all_pages_property_urls).flatten()
all_urls[:10]
# Out:
# array(['https://www.zillow.com/homedetails/3905-Clawson-Rd-UNIT-9-Austin-TX-78704/306646650_zpid/',
#        'https://www.zillow.com/homedetails/7109-Montana-Norte-Austin-TX-78731/29353074_zpid/',
#        'https://www.zillow.com/homedetails/Austin-TX-78725/2077632063_zpid/',
#        'https://www.zillow.com/homedetails/1007-Rebbeca-Dr-Austin-TX-78758/2077632061_zpid/',
#        'https://www.zillow.com/homedetails/9000-Honeycomb-Dr-Austin-TX-78737/29484794_zpid/',
#        'https://www.zillow.com/homedetails/1901-Glen-Allen-St-APT-1-Austin-TX-78704/60138612_zpid/',
#        'https://www.zillow.com/homedetails/146-Catalina-Ln-Austin-TX-78737/119621504_zpid/',
#        'https://www.zillow.com/homedetails/3705-Ebony-Hollow-Cv-Austin-TX-78739/29514892_zpid/',
#        'https://www.zillow.com/homedetails/6525-Alum-Rock-Cv-Austin-TX-78747/63838081_zpid/',
#        'https://www.zillow.com/homedetails/12723-Acadian-Trl-Austin-TX-78727/29446055_zpid/'],
#       dtype='<U105')

# %%
test = all_urls[0].replace('https://www.zillow.com/homedetails/','').split('/')[0]
test
# Out:
# '3905-Clawson-Rd-UNIT-9-Austin-TX-78704'

# %%
test
# Out:
# '3905-Clawson-Rd-UNIT-9-Austin-TX-78704'

# %%
data_list = []
bum_links = []
for link in all_urls:
    print(link)
    data_raw = get_property_features(link)
    
    if data_raw != None:
        # adding the dict down here so we dont throw an error when something
        # doesnt come up/can have conditions
        data = dict(data_raw)
        data['Address'] = link.replace('https://www.zillow.com/homedetails/','').split('/')[0]
        data['URL'] = link
        data_list.append(data)
    else:
        # creating this so we can see what links didnt work and look into why later
        bum_links.append(link)
# Out:
# https://www.zillow.com/homedetails/3905-Clawson-Rd-UNIT-9-Austin-TX-78704/306646650_zpid/
# [['Type', 'Condo'], ['Year built', '2020'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$120/month'], ['Price/sqft', '$314'], ['Total Price', '$696,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/7109-Montana-Norte-Austin-TX-78731/29353074_zpid/
# [['Type', 'Single Family'], ['Year built', '1972'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.29 Acres'], ['Price/sqft', '$344'], ['Total Price', '$1,150,000'], ['Bedrooms', ' 5'], ['Bathrooms', ' 5'], ['Full bathrooms', ' 5']]
# https://www.zillow.com/homedetails/Austin-TX-78725/2077632063_zpid/
# [['Type', 'Single Family'], ['Year built', '2020'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '8,398 sqft'], ['Price/sqft', '$267'], ['Total Price', '$484,900'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/1007-Rebbeca-Dr-Austin-TX-78758/2077632061_zpid/
# [['Type', 'Single Family'], ['Year built', '1971'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.26 Acres'], ['Price/sqft', '$157'], ['Total Price', '$335,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/9000-Honeycomb-Dr-Austin-TX-78737/29484794_zpid/
# [['Type', 'Single Family'], ['Year built', '1963'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '2.99 acres'], ['Price/sqft', '$290'], ['Total Price', '$660,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/1901-Glen-Allen-St-APT-1-Austin-TX-78704/60138612_zpid/
# [['Type', 'Condo'], ['Year built', '1977'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$270/month'], ['Price/sqft', '$289'], ['Total Price', '$270,000'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/146-Catalina-Ln-Austin-TX-78737/119621504_zpid/
# [['Type', 'Single Family'], ['Year built', '2012'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '5 spaces'], ['Lot', '8,886 sqft'], ['Price/sqft', '$164'], ['Total Price', '$465,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/3705-Ebony-Hollow-Cv-Austin-TX-78739/29514892_zpid/
# [['Type', 'Single Family'], ['Year built', '1994'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$16/month'], ['Lot', '1.12 acres'], ['Price/sqft', '$228'], ['Total Price', '$819,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 5'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 2']]
# https://www.zillow.com/homedetails/6525-Alum-Rock-Cv-Austin-TX-78747/63838081_zpid/
# [['Type', 'Single Family'], ['Year built', '2004'], ['Heating', 'Other, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '9,365 sqft'], ['Price/sqft', '$190'], ['Total Price', '$250,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/12723-Acadian-Trl-Austin-TX-78727/29446055_zpid/
# [['Type', 'Single Family'], ['Year built', '1984'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '7,318 sqft'], ['Price/sqft', '$249'], ['Total Price', '$325,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/14516-Banbridge-Trl-Austin-TX-78717/60335781_zpid/
# [['Type', 'Single Family'], ['Year built', '2002'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$43/month'], ['Lot', '8,929 sqft'], ['Price/sqft', '$175'], ['Total Price', '$389,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/13101-Zen-Gardens-Way-Austin-TX-78732/70352281_zpid/
# [['Type', 'Single Family'], ['Year built', '2013'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$126/month'], ['Lot', '0.76 acres'], ['Price/sqft', '$354'], ['Total Price', '$1,695,000'], ['Bedrooms', ' 5'], ['Bathrooms', ' 5'], ['Full bathrooms', ' 5']]
# https://www.zillow.com/homedetails/1303-Azie-Morton-Rd-5-Austin-TX-78704/119619187_zpid/
# [['Type', 'Condo'], ['Year built', '2011'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$166/mo'], ['Price/sqft', '$426'], ['Total Price', '$710,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/9101-Lantana-Way-Austin-TX-78749/29491668_zpid/
# [['Type', 'Single Family'], ['Year built', '1999'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$17/month'], ['Lot', '7,143 sqft'], ['Price/sqft', '$192'], ['Total Price', '$549,900'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1406-Atterbury-Ln-Austin-TX-78753/29435168_zpid/
# [['Type', 'Single Family'], ['Year built', '1982'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '9,713 sqft'], ['Price/sqft', '$203'], ['Total Price', '$240,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/3204-Beverly-Rd-Austin-TX-78703/29338588_zpid/
# [['Type', 'Single Family'], ['Year built', '1940'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '8,015 sqft'], ['Price/sqft', '$494'], ['Total Price', '$825,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/3504-Clawson-Rd-APT-2-Austin-TX-78704/145656555_zpid/
# [['Type', 'Single Family'], ['Year built', '2015'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '3 spaces'], ['Lot', '0.79 Acres'], ['Price/sqft', '$328'], ['Total Price', '$649,900'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/829-E-Oltorf-St-Austin-TX-78704/29462124_zpid/
# [['Type', 'Condo'], ['Year built', '1967'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$382/mo'], ['Price/sqft', '$256'], ['Total Price', '$399,900'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/7007-Cut-Plains-Trl-Austin-TX-78726/2077633278_zpid/
# [['Type', 'Single Family'], ['Year built', '2016'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$159/month'], ['Lot', '8,276 sqft'], ['Price/sqft', '$205'], ['Total Price', '$530,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/2520-Bluebonnet-Ln-56-Austin-TX-78704/2138213976_zpid/
# [['Type', 'Condo'], ['Year built', '2009'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$310/month'], ['Price/sqft', '$287'], ['Total Price', '$559,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/2305-Broughton-Ct-Austin-TX-78727/29442729_zpid/
# [['Type', 'Single Family'], ['Year built', '1986'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '7,701 sqft'], ['Price/sqft', '$171'], ['Total Price', '$394,900'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/6912-Hansa-Loop-Austin-TX-78739/64647073_zpid/
# [['Type', 'Single Family'], ['Year built', '2003'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$50/month'], ['Lot', '8,799 sqft'], ['Price/sqft', '$211'], ['Total Price', '$689,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/4613-Walsall-Loop-Austin-TX-78749/29499794_zpid/
# [['Type', 'Single Family'], ['Year built', '1997'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$42/month'], ['Lot', '6,969 sqft'], ['Price/sqft', '$228'], ['Total Price', '$400,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/1912-Karen-Ave-Austin-TX-78757/29416961_zpid/
# [['Type', 'Single Family'], ['Year built', '1955'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.25 Acres'], ['Price/sqft', '$383'], ['Total Price', '$699,900'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/7001-Rusty-Fig-Dr-Austin-TX-78750/29358924_zpid/
# [['Type', 'Single Family'], ['Year built', '1983'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '10,149 sqft'], ['Price/sqft', '$254'], ['Total Price', '$769,500'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/14505-Gold-Fish-Pond-Ave-Austin-TX-78728/29449611_zpid/
# [['Type', 'Single Family'], ['Year built', '1983'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '6,926 sqft'], ['Price/sqft', '$181'], ['Total Price', '$297,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/community/pioneer-hill/2077636798_zpid/
# [['Type', 'Single Family'], ['Year built', '2020'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', 'No Data'], ['Price/sqft', '$196'], ['Total Price', '$326,990'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/community/parker-station/2077636801_zpid/
# [['Type', 'Single Family'], ['Year built', 'No Data'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', 'No Data'], ['Price/sqft', '$141'], ['Total Price', '$376,990'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/community/parker-station/2077636799_zpid/
# [['Type', 'Single Family'], ['Year built', 'No Data'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', 'No Data'], ['Price/sqft', '$147'], ['Total Price', '$372,990'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/community/parker-station/2077636802_zpid/
# [['Type', 'Single Family'], ['Year built', '2020'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', 'No Data'], ['Price/sqft', '$138'], ['Total Price', '$377,990'], ['Bedrooms', ' 5'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/community/parker-station/2077636800_zpid/
# [['Type', 'Single Family'], ['Year built', 'No Data'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', 'No Data'], ['Price/sqft', '$147'], ['Total Price', '$371,990'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/6901-Chelsea-Moor-Austin-TX-78759/29369634_zpid/
# [['Type', 'Single Family'], ['Year built', '1982'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '8,537 sqft'], ['Price/sqft', '$229'], ['Total Price', '$499,990'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/300-Bowie-St-APT-3706-Austin-TX-78703/83822255_zpid/
# [['Type', 'Condo'], ['Year built', '2007'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$375/mo'], ['Price/sqft', '$709'], ['Total Price', '$494,700'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1902-Richcreek-Rd-Austin-TX-78757/29420425_zpid/
# [['Type', 'Single Family'], ['Year built', '1954'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '8,407 sqft'], ['Price/sqft', '$432'], ['Total Price', '$515,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/705-N-Bluff-Dr-5-Austin-TX-78745/251031106_zpid/
# [['Type', 'Condo'], ['Year built', '2017'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$150/mo'], ['Price/sqft', '$256'], ['Total Price', '$369,900'], ['Bedrooms', ' 2'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/12906-Coridan-Dr-Austin-TX-78727/29447143_zpid/
# [['Type', 'Single Family'], ['Year built', '1985'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '5,880 sqft'], ['Price/sqft', '$251'], ['Total Price', '$374,900'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/9102-Breeze-Point-Cv-Austin-TX-78759/29363026_zpid/
# [['Type', 'Single Family'], ['Year built', '1980'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '6,446 sqft'], ['Price/sqft', '$247'], ['Total Price', '$559,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/1313-E-52nd-St-APT-104-Austin-TX-78723/305431013_zpid/
# [['Type', 'Condo'], ['Year built', '1965'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['HOA', '$200/mo'], ['Price/sqft', '$289'], ['Total Price', '$195,000'], ['Bedrooms', ' 0'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/community/forest-bluff/2077808915_zpid/
# [['Type', 'Single Family'], ['Year built', '2020'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', 'No Data'], ['Price/sqft', '$130'], ['Total Price', '$281,990'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/9009-Jodie-Ln-Austin-TX-78748/145657035_zpid/
# [['Type', 'Condo'], ['Year built', '2018'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$135/month'], ['Price/sqft', '$147'], ['Total Price', '$424,700'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/405-Wilmes-Dr-Austin-TX-78752/29412486_zpid/
# [['Type', 'Single Family'], ['Year built', '1955'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', 'None'], ['Lot', '6,926 sqft'], ['Price/sqft', '$403'], ['Total Price', '$635,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/2302-Trafalgar-Dr-Austin-TX-78723/29402358_zpid/
# [['Type', 'Single Family'], ['Year built', '1960'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '0.29 acres'], ['Price/sqft', '$342'], ['Total Price', '$382,500'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/12525-Verandah-Ct-Austin-TX-78726/70333917_zpid/
# [['Type', 'Single Family'], ['Year built', '2004'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.69 Acres'], ['Price/sqft', '$247'], ['Total Price', '$875,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/222-West-Ave-2503-Austin-TX-78701/124839381_zpid/
# [['Type', 'Condo'], ['Year built', '2014'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$439/mo'], ['Price/sqft', '$706'], ['Total Price', '$485,000'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/210-Lee-Barton-Dr-UNIT-412-Austin-TX-78704/80095835_zpid/
# [['Type', 'Condo'], ['Year built', '2008'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$441/month'], ['Price/sqft', '$501'], ['Total Price', '$432,000'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/6400-Rapture-Cv-Austin-TX-78749/29481110_zpid/
# [['Type', 'Single Family'], ['Year built', '1983'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '9,321 sqft'], ['Price/sqft', '$280'], ['Total Price', '$535,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/2106-Highgrove-Ter-Austin-TX-78703/29329338_zpid/
# [['Type', 'Single Family'], ['Year built', '2014'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '9,278 sqft'], ['Price/sqft', '$655'], ['Total Price', '$2,350,000'], ['Bedrooms', ' 5'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 4']]
# https://www.zillow.com/homedetails/6728-Vicenza-Dr-Austin-TX-78737/303836218_zpid/
# [['Type', 'Single Family'], ['Year built', '2018'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '6 spaces'], ['HOA', '$58/month'], ['Lot', '6,969 sqft'], ['Price/sqft', '$257'], ['Total Price', '$749,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/7805-Cooper-Ln-104-Austin-TX-78745/241938803_zpid/
# [['Type', 'Condo'], ['Year built', '2016'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$260/mo'], ['Price/sqft', '$225'], ['Total Price', '$275,000'], ['Bedrooms', ' 0'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/4102-Ridgeline-Trl-Austin-TX-78731/29356449_zpid/
# [['Type', 'Townhouse'], ['Year built', '1979'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$140/month'], ['Lot', '3,920 sqft'], ['Price/sqft', '$266'], ['Total Price', '$475,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/15421-Staked-Plains-Loop-Austin-TX-78717/185217426_zpid/
# [['Type', 'Single Family'], ['Year built', '2008'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '8,145 sqft'], ['Price/sqft', '$196'], ['Total Price', '$429,900'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/11809-Cedar-Valley-Cv-Austin-TX-78753/58304645_zpid/
# [['Type', 'Single Family'], ['Year built', '1962'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '0.25 acres'], ['Price/sqft', '$246'], ['Total Price', '$439,900'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/2112-La-Casa-Dr-Austin-TX-78704/2087734081_zpid/
# [['Type', 'Condo'], ['Year built', '2018'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$115/mo'], ['Price/sqft', '$517'], ['Total Price', '$1,098,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/201-Craigmont-Dr-Austin-TX-78745/29494448_zpid/
# [['Type', 'Single Family'], ['Year built', '1973'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Lot', '6,708 sqft'], ['Price/sqft', '$306'], ['Total Price', '$370,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/1702-Foggy-Glen-Cv-Austin-TX-78733/29346888_zpid/
# [['Type', 'Single Family'], ['Year built', '2001'], ['Heating', 'Other, Electric'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '0.48 Acres'], ['Price/sqft', '$401'], ['Total Price', '$991,150'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/9804-Lake-Ridge-Dr-Austin-TX-78733/29343768_zpid/
# [['Type', 'Single Family'], ['Year built', '2015'], ['Heating', 'Forced air, Heat pump'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '0.85 acres'], ['Price/sqft', '$433'], ['Total Price', '$1,250,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 4']]
# https://www.zillow.com/homedetails/41-Waller-St-APT-206-Austin-TX-78702/83819381_zpid/
# [['Type', 'Apartment'], ['Year built', '2007'], ['Heating', 'Forced air'], ['Cooling', 'Other'], ['Parking', '2 spaces'], ['HOA', '$338/month'], ['Price/sqft', '$394'], ['Total Price', '$368,500'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/11031-Watchful-Fox-Dr-Austin-TX-78748/29515246_zpid/
# [['Type', 'Single Family'], ['Year built', '1991'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '7,884 sqft'], ['Price/sqft', '$208'], ['Total Price', '$395,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/11317-Midbury-Ct-Austin-TX-78748/60135620_zpid/
# [['Type', 'Single Family'], ['Year built', '2002'], ['Heating', 'Other, Electric'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '7,230 sqft'], ['Price/sqft', '$130'], ['Total Price', '$330,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/6208-Highland-Hills-Dr-Austin-TX-78731/29349346_zpid/
# [['Type', 'Single Family'], ['Year built', '1966'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '0.27 acres'], ['Price/sqft', '$371'], ['Total Price', '$899,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/1102-Brentwood-St-Austin-TX-78757/29415066_zpid/
# [['Type', 'Single Family'], ['Year built', '1951'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '0.28 Acres'], ['Price/sqft', '$428'], ['Total Price', '$689,900'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/2114-Goodrich-Ave-APT-9-Austin-TX-78704/58312090_zpid/
# [['Type', 'Condo'], ['Year built', '1999'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$130/mo'], ['Price/sqft', '$367'], ['Total Price', '$529,000'], ['Bedrooms', ' 2'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/502-Tillery-St-Austin-TX-78702/29383438_zpid/
# [['Type', 'Single Family'], ['Year built', '1949'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '5,793 sqft'], ['Price/sqft', '$296'], ['Total Price', '$400,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1703-Mohle-Dr-Austin-TX-78703/29337209_zpid/
# [['Type', 'Single Family'], ['Year built', '2013'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '9,365 sqft'], ['Price/sqft', '$668'], ['Total Price', '$2,095,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/community/park-at-51-east-affordable/2077851314_zpid/
# [['Type', 'Single Family'], ['Year built', '2020'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', 'No Data'], ['Price/sqft', '$125'], ['Total Price', '$266,990'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1616-Catalan-Rd-Austin-TX-78748/2092447246_zpid/
# [['Type', 'Townhouse'], ['Year built', '2017'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$185/month'], ['Lot', '3,963 sqft'], ['Price/sqft', '$178'], ['Total Price', '$275,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/2009-Malvern-Hill-Dr-Austin-TX-78745/29497778_zpid/
# [['Type', 'Single Family'], ['Year built', '1978'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '6,969 sqft'], ['Price/sqft', '$286'], ['Total Price', '$539,900'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/3904-Tattershall-Ln-Austin-TX-78727/58306115_zpid/
# [['Type', 'Single Family'], ['Year built', '1981'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '6,708 sqft'], ['Price/sqft', '$295'], ['Total Price', '$415,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/6706-Tulane-Dr-Austin-TX-78723/29407567_zpid/
# [['Type', 'Single Family'], ['Year built', '1961'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '9,713 sqft'], ['Price/sqft', '$322'], ['Total Price', '$375,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/704-W-21st-St-APT-305-Austin-TX-78705/60137076_zpid/
# [['Type', 'Condo'], ['Year built', '1984'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$195/mo'], ['Price/sqft', '$342'], ['Total Price', '$299,000'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/12300-Painted-Bunting-Dr-Austin-TX-78726/29377662_zpid/
# [['Type', 'Single Family'], ['Year built', '1990'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '2.06 acres'], ['Price/sqft', '$265'], ['Total Price', '$740,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/14200-Terisu-Ln-Austin-TX-78728/29446387_zpid/
# [['Type', 'Single Family'], ['Year built', '1985'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '7,274 sqft'], ['Price/sqft', '$180'], ['Total Price', '$330,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/6814-E-Riverside-Dr-UNIT-85-Austin-TX-78741/241937854_zpid/
# [['Type', 'Condo'], ['Year built', '2017'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$250/mo'], ['Price/sqft', '$224'], ['Total Price', '$425,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/228-Archipelago-Trl-Austin-TX-78717/96644247_zpid/
# [['Type', 'Condo'], ['Year built', '2012'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$33/mo'], ['Price/sqft', '$173'], ['Total Price', '$459,995'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/community/vistas-of-austin/2077643985_zpid/
# https://www.zillow.com/homedetails/3702-Apache-Forest-Dr-Austin-TX-78739/29511771_zpid/
# [['Type', 'Single Family'], ['Year built', '1993'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.28 Acres'], ['Price/sqft', '$213'], ['Total Price', '$495,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/7213-Kilday-Cv-Austin-TX-78744/2077644976_zpid/
# [['Type', 'Single Family'], ['Year built', '2019'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '6,316 sqft'], ['Price/sqft', '$175'], ['Total Price', '$345,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/3306-Skylark-Dr-Austin-TX-78757/29422112_zpid/
# [['Type', 'Single Family'], ['Year built', '1962'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '9,147 sqft'], ['Price/sqft', '$414'], ['Total Price', '$720,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/3405-Burliegh-Cv-Austin-TX-78745/29498735_zpid/
# [['Type', 'Single Family'], ['Year built', '1980'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.31 Acres'], ['Price/sqft', '$235'], ['Total Price', '$355,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/7021-Via-Correto-Dr-Austin-TX-78749/70342650_zpid/
# [['Type', 'Single Family'], ['Year built', '2006'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '5 spaces'], ['HOA', '$53/month'], ['Lot', '9,975 sqft'], ['Price/sqft', '$195'], ['Total Price', '$650,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/3405-Burliegh-Cv-Austin-TX-78745/29498735_zpid/
# [['Type', 'Single Family'], ['Year built', '1980'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.31 Acres'], ['Price/sqft', '$235'], ['Total Price', '$355,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/3306-Skylark-Dr-Austin-TX-78757/29422112_zpid/
# [['Type', 'Single Family'], ['Year built', '1962'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '9,147 sqft'], ['Price/sqft', '$414'], ['Total Price', '$720,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/2621-Baxter-Dr-Austin-TX-78745/58314653_zpid/
# [['Type', 'Single Family'], ['Year built', '1972'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '6,795 sqft'], ['Price/sqft', '$340'], ['Total Price', '$449,900'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/5813-Medicine-Creek-Dr-Austin-TX-78735/60136219_zpid/
# [['Type', 'Single Family'], ['Year built', '2002'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '8,755 sqft'], ['Price/sqft', '$228'], ['Total Price', '$695,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1911-Creole-Dr-Austin-TX-78727/29445401_zpid/
# [['Type', 'Single Family'], ['Year built', '1999'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$38/month'], ['Lot', '9,147 sqft'], ['Price/sqft', '$155'], ['Total Price', '$435,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/8800-W-View-Rd-Austin-TX-78737/29481860_zpid/
# [['Type', 'Single Family'], ['Year built', '1977'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '3.62 Acres'], ['Price/sqft', '$542'], ['Total Price', '$1,250,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/7413-Grover-Ave-A-Austin-TX-78757/241935674_zpid/
# [['Type', 'Condo'], ['Year built', '2016'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$75/month'], ['Price/sqft', '$377'], ['Total Price', '$670,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/9451-El-Rey-Blvd-Austin-TX-78737/70328053_zpid/
# [['Type', 'Single Family'], ['Year built', '2008'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '6 spaces'], ['HOA', '$25/month'], ['Lot', '1 acre'], ['Price/sqft', '$242'], ['Total Price', '$849,900'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/3905-Clawson-Rd-10-Austin-TX-78704/306646651_zpid/
# [['Type', 'Condo'], ['Year built', '2020'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$120/month'], ['Price/sqft', '$314'], ['Total Price', '$696,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/171-Saint-Richie-Ln-Austin-TX-78737/111964502_zpid/
# [['Type', 'Single Family'], ['Year built', '2010'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '3 spaces'], ['HOA', '$45/month'], ['Lot', '9,583 sqft'], ['Price/sqft', '$206'], ['Total Price', '$422,900'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/11307-Circle-Bend-Dr-Austin-TX-78758/58302893_zpid/
# [['Type', 'Single Family'], ['Year built', '1969'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', 'Attached Garage'], ['HOA', 'None'], ['Lot', '9,278 sqft'], ['Price/sqft', '$301'], ['Total Price', '$520,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/8106-Appomattox-Dr-Austin-TX-78745/63567410_zpid/
# [['Type', 'Single Family'], ['Year built', '1979'], ['Heating', 'Forced air'], ['Cooling', 'Central, Wall'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '8,755 sqft'], ['Price/sqft', '$270'], ['Total Price', '$485,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/2006-Rabb-Glen-St-1-Austin-TX-78704/2077646167_zpid/
# [['Type', 'Single Family'], ['Year built', '2019'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '10,702 sqft'], ['Price/sqft', '$497'], ['Total Price', '$1,499,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/6003-Shadow-Valley-Cv-Austin-TX-78731/29349229_zpid/
# [['Type', 'Multi Family'], ['Year built', '1971'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Price/sqft', '$236'], ['Total Price', '$700,000'], ['Bedrooms', ' 0']]
# https://www.zillow.com/homedetails/2301-Westway-Cir-Austin-TX-78704/29474793_zpid/
# [['Type', 'Single Family'], ['Year built', '1955'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '10,018 sqft'], ['Price/sqft', '$520'], ['Total Price', '$825,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/11308-Toledo-Dr-Austin-TX-78759/29439274_zpid/
# [['Type', 'Single Family'], ['Year built', '1976'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$40/month'], ['Lot', '9,147 sqft'], ['Price/sqft', '$294'], ['Total Price', '$575,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/12415-Turtleback-Ln-Austin-TX-78727/29442352_zpid/
# [['Type', 'Single Family'], ['Year built', '1982'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '7,013 sqft'], ['Price/sqft', '$269'], ['Total Price', '$425,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/11106-Bending-Bough-Trl-Austin-TX-78758/29433961_zpid/
# [['Type', 'Single Family'], ['Year built', '1978'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '6,534 sqft'], ['Price/sqft', '$283'], ['Total Price', '$425,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/6111-Bridlington-Cir-Austin-TX-78745/58314577_zpid/
# [['Type', 'Single Family'], ['Year built', '1977'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '8,276 sqft'], ['Price/sqft', '$284'], ['Total Price', '$420,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/10300-Morado-Cv-APT-103-Austin-TX-78759/62605133_zpid/
# [['Type', 'Condo'], ['Year built', '2001'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$415/month'], ['Price/sqft', '$217'], ['Total Price', '$360,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/community/bend-south-congress/2077862485_zpid/
# [['Type', 'Single Family'], ['Year built', 'No Data'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', 'No Data'], ['Price/sqft', '$370'], ['Total Price', '$370,000'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/10421-Hess-Dr-Austin-TX-78748/29512831_zpid/
# [['Type', 'Single Family'], ['Year built', '1993'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '5,662 sqft'], ['Price/sqft', '$215'], ['Total Price', '$365,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/2900-Wadsworth-Way-Austin-TX-78748/29511441_zpid/
# [['Type', 'Single Family'], ['Year built', '1985'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '9,583 sqft'], ['Price/sqft', '$216'], ['Total Price', '$325,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/1311-Melissa-Oaks-Ln-Austin-TX-78744/70343500_zpid/
# [['Type', 'Single Family'], ['Year built', '2005'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$66/month'], ['Lot', '10,454 sqft'], ['Price/sqft', '$172'], ['Total Price', '$289,900'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/1615-Strickland-Dr-Austin-TX-78748/70343232_zpid/
# [['Type', 'Single Family'], ['Year built', '2005'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$12/month'], ['Lot', '6,359 sqft'], ['Price/sqft', '$166'], ['Total Price', '$329,900'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/4809-Allison-Cv-Austin-TX-78741/29465503_zpid/
# [['Type', 'Single Family'], ['Year built', '1988'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '8,668 sqft'], ['Price/sqft', '$286'], ['Total Price', '$550,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/5710-Link-Ave-Austin-TX-78752/29411814_zpid/
# [['Type', 'Single Family'], ['Year built', '1951'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '6,969 sqft'], ['Price/sqft', '$337'], ['Total Price', '$350,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/700-Winflo-Dr-Austin-TX-78703/29327437_zpid/
# [['Type', 'Single Family'], ['Year built', '1951'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '3 spaces'], ['HOA', 'None'], ['Lot', '6,534 sqft'], ['Price/sqft', '$681'], ['Total Price', '$950,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/4610-Englewood-Dr-Austin-TX-78745/29480314_zpid/
# [['Type', 'Single Family'], ['Year built', '1959'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '7,753 sqft'], ['Price/sqft', '$454'], ['Total Price', '$424,900'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/5508-Kings-Hwy-Austin-TX-78745/29485213_zpid/
# [['Type', 'Single Family'], ['Year built', '1966'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '9,936 sqft'], ['Price/sqft', '$365'], ['Total Price', '$429,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/4309-Shoal-Creek-Blvd-Austin-TX-78756/29406032_zpid/
# [['Type', 'Single Family'], ['Year built', '1998'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '7,448 sqft'], ['Price/sqft', '$446'], ['Total Price', '$925,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1610-Tun-Tavern-Trl-Austin-TX-78754/2077647820_zpid/
# [['Type', 'Condo'], ['Year built', '2020'], ['Heating', 'Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$245/month'], ['Price/sqft', '$175'], ['Total Price', '$284,158'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1612-Tun-Tavern-Trl-Austin-TX-78754/2077647821_zpid/
# [['Type', 'Condo'], ['Year built', '2020'], ['Heating', 'Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$245/mo'], ['Price/sqft', '$165'], ['Total Price', '$296,356'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/2220-Webberville-Rd-213-Austin-TX-78702/2077647824_zpid/
# [['Type', 'Condo'], ['Year built', '2020'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$194/mo'], ['Price/sqft', '$439'], ['Total Price', '$340,000'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/3312-Tavistock-Dr-Austin-TX-78748/70332555_zpid/
# [['Type', 'Single Family'], ['Year built', '2007'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '6,272 sqft'], ['Price/sqft', '$200'], ['Total Price', '$405,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1411-Canon-Yeomans-Trl-Austin-TX-78748/29514155_zpid/
# [['Type', 'Single Family'], ['Year built', '1998'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$17/month'], ['Lot', '6,272 sqft'], ['Price/sqft', '$186'], ['Total Price', '$270,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/6732-Marble-Creek-Loop-Austin-TX-78747/64894449_zpid/
# [['Type', 'Single Family'], ['Year built', '2004'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$21/month'], ['Lot', '8,189 sqft'], ['Price/sqft', '$130'], ['Total Price', '$275,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/221-Egret-Ln-Austin-TX-78737/2077648821_zpid/
# [['Type', 'Single Family'], ['Year built', '2020'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '3 spaces'], ['HOA', '$85/month'], ['Lot', 'No Data'], ['Price/sqft', '$221'], ['Total Price', '$753,900'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/12416-Sky-Harbor-Dr-Del-Valle-TX-78617/80100763_zpid/
# [['Type', 'Single Family'], ['Year built', '2007'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '4,965 sqft'], ['Price/sqft', '$140'], ['Total Price', '$215,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/10220-Copper-Ridge-Cv-Austin-TX-78747/120900166_zpid/
# [['Type', 'Single Family'], ['Year built', '2012'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '5,183 sqft'], ['Price/sqft', '$156'], ['Total Price', '$295,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/10612-Tollesboro-Cv-Austin-TX-78739/70334994_zpid/
# [['Type', 'Single Family'], ['Year built', '2006'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$55/month'], ['Lot', '10,410 sqft'], ['Price/sqft', '$217'], ['Total Price', '$599,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/9308-Bentley-Garner-Ln-Austin-TX-78748/119630620_zpid/
# [['Type', 'Single Family'], ['Year built', '2014'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$50/month'], ['Lot', '5,662 sqft'], ['Price/sqft', '$199'], ['Total Price', '$470,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/2018-W-Rundberg-Ln-APT-13D-Austin-TX-78758/83819835_zpid/
# [['Type', 'Townhouse'], ['Year built', '1984'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$298/month'], ['Lot', '2,003 sqft'], ['Price/sqft', '$199'], ['Total Price', '$179,900'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 1'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/608-E-41st-St-Austin-TX-78751/29400608_zpid/
# [['Type', 'Single Family'], ['Year built', '1933'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', 'None'], ['Lot', '5,096 sqft'], ['Price/sqft', '$432'], ['Total Price', '$995,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/3300-Denver-Ave-Austin-TX-78723/29392437_zpid/
# [['Type', 'Condo'], ['Year built', '2020'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$100/month'], ['Price/sqft', '$380'], ['Total Price', '$655,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/122-Laurel-Ln-Austin-TX-78705/29397296_zpid/
# [['Type', 'Single Family'], ['Year built', '1928'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '5,488 sqft'], ['Price/sqft', '$626'], ['Total Price', '$1,025,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/8912-Mariscal-Canyon-Dr-Austin-TX-78759/29363170_zpid/
# [['Type', 'Townhouse'], ['Year built', '1985'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$360/month'], ['Lot', '3,702 sqft'], ['Price/sqft', '$231'], ['Total Price', '$469,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/110-Empire-Ct-Austin-TX-78737/84137545_zpid/
# [['Type', 'Single Family'], ['Year built', '2007'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '3 spaces'], ['Lot', '0.40 Acres'], ['Price/sqft', '$156'], ['Total Price', '$650,000'], ['Bedrooms', ' 5'], ['Bathrooms', ' 5'], ['Full bathrooms', ' 4'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/2713-Zaragosa-St-Austin-TX-78702/124844842_zpid/
# ...
# https://www.zillow.com/community/highpointe-80ft-lots/2079968709_zpid/
# [['Type', 'Single Family'], ['Year built', 'No Data'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '3 spaces'], ['Lot', 'No Data'], ['Price/sqft', '$165'], ['Total Price', '$616,990'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/community/highpointe-80ft-lots/2082357199_zpid/
# [['Type', 'Single Family'], ['Year built', 'No Data'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '3 spaces'], ['Lot', 'No Data'], ['Price/sqft', '$190'], ['Total Price', '$566,990'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/5827-Westslope-Dr-Austin-TX-78731/29348323_zpid/
# [['Type', 'Single Family'], ['Year built', '1992'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', 'Attached Garage'], ['HOA', '$49/month'], ['Lot', '9,835 sqft'], ['Price/sqft', '$369'], ['Total Price', '$1,475,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/8307-Williamson-Creek-Dr-Austin-TX-78736/29478194_zpid/
# [['Type', 'Single Family'], ['Year built', '2015'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', 'Attached Garage'], ['Lot', '0.31 acres'], ['Price/sqft', '$237'], ['Total Price', '$525,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1115-Winifred-Dr-Austin-TX-78748/2078241356_zpid/
# [['Type', 'Single Family'], ['Year built', '2020'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '4,573 sqft'], ['Price/sqft', '$197'], ['Total Price', '$399,790'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/48-E-East-Ave-3209-Austin-TX-78701/2077624971_zpid/
# [['Type', 'Condo'], ['Year built', '2020'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$638/month'], ['Price/sqft', '$856'], ['Total Price', '$841,000'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/1202-Valdez-St-Austin-TX-78741/29463419_zpid/
# [['Type', 'Single Family'], ['Year built', '1948'], ['Heating', 'Electric, Gas'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '5,837 sqft'], ['Price/sqft', '$297'], ['Total Price', '$329,500'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/2305-Barton-Creek-Blvd-UNIT-24-Austin-TX-78735/29329522_zpid/
# [['Type', 'Single Family'], ['Year built', '1997'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.50 Acres'], ['Price/sqft', '$451'], ['Total Price', '$1,700,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/501-West-Ave-1002-Austin-TX-78701/306645079_zpid/
# [['Type', 'Condo'], ['Year built', '2018'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$477/month'], ['Price/sqft', '$768'], ['Total Price', '$649,900'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/3109-Walnut-Ave-2-Austin-TX-78722/2077624975_zpid/
# https://www.zillow.com/homedetails/12019-Bobcat-Trl-Austin-TX-78750/29567207_zpid/
# [['Type', 'Single Family'], ['Year built', '1982'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '7,840 sqft'], ['Price/sqft', '$176'], ['Total Price', '$325,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/11631-Rydalwater-Ln-Austin-TX-78754/29424434_zpid/
# [['Type', 'Single Family'], ['Year built', '1993'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$40/month'], ['Lot', '8,712 sqft'], ['Price/sqft', '$105'], ['Total Price', '$379,900'], ['Bedrooms', ' 5'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/7405-Loganberry-Dr-Austin-TX-78745/29502696_zpid/
# [['Type', 'Single Family'], ['Year built', '1976'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '7,143 sqft'], ['Price/sqft', '$276'], ['Total Price', '$330,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/9711-Dallum-Dr-Austin-TX-78753/29425483_zpid/
# [['Type', 'Single Family'], ['Year built', '1969'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '3 spaces'], ['Lot', '8,494 sqft'], ['Price/sqft', '$250'], ['Total Price', '$299,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/6917-Vail-Ridge-St-Austin-TX-78744/145652938_zpid/
# [['Type', 'Single Family'], ['Year built', '2015'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '6,534 sqft'], ['Price/sqft', '$229'], ['Total Price', '$299,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/800-Embassy-Dr-APT-334-Austin-TX-78702/305425819_zpid/
# [['Type', 'Condo'], ['Year built', '2018'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$670/month'], ['Price/sqft', '$441'], ['Total Price', '$485,000'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/6208-Walnut-Hills-Dr-Austin-TX-78723/29404205_zpid/
# [['Type', 'Single Family'], ['Year built', '1954'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.26 Acres'], ['Price/sqft', '$250'], ['Total Price', '$319,500'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/5806-N-Hampton-Dr-Austin-TX-78723/29404163_zpid/
# [['Type', 'Single Family'], ['Year built', '1963'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '9,975 sqft'], ['Price/sqft', '$275'], ['Total Price', '$550,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/2700-Ware-Rd-Austin-TX-78741/29464530_zpid/
# [['Type', 'Single Family'], ['Year built', '1997'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '3 spaces'], ['HOA', 'None'], ['Lot', '0.33 acres'], ['Price/sqft', '$420'], ['Total Price', '$425,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/2617-Market-Garden-Ln-Austin-TX-78745/29499056_zpid/
# [['Type', 'Single Family'], ['Year built', '1983'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '7,448 sqft'], ['Price/sqft', '$369'], ['Total Price', '$495,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/14946-Doria-Dr-Austin-TX-78728/29451597_zpid/
# [['Type', 'Single Family'], ['Year built', '1998'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '7,379 sqft'], ['Price/sqft', '$162'], ['Total Price', '$375,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/610-Upson-St-Austin-TX-78703/29329392_zpid/
# [['Type', 'Single Family'], ['Year built', '1982'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '5 spaces'], ['HOA', 'None'], ['Lot', '6,490 sqft'], ['Price/sqft', '$301'], ['Total Price', '$1,250,000'], ['Bedrooms', ' 8'], ['Bathrooms', ' 5'], ['Full bathrooms', ' 5']]
# https://www.zillow.com/homedetails/7303-Daugherty-St-Austin-TX-78757/29420233_zpid/
# [['Type', 'Single Family'], ['Year built', '1962'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '8,829 sqft'], ['Price/sqft', '$326'], ['Total Price', '$625,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/10512-Oak-View-Dr-Austin-TX-78759/29370084_zpid/
# [['Type', 'Single Family'], ['Year built', '1994'], ['Heating', 'Other, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '9,844 sqft'], ['Price/sqft', '$222'], ['Total Price', '$710,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1900-Barton-Springs-Rd-UNIT-3004-Austin-TX-78704/251029035_zpid/
# [['Type', 'Condo'], ['Year built', '2013'], ['Heating', 'Forced air'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['HOA', '$225/month'], ['Price/sqft', '$561'], ['Total Price', '$379,900'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/2407-Mccullough-St-Austin-TX-78703/29337412_zpid/
# [['Type', 'Single Family'], ['Year built', '1951'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '0.6 acres'], ['Price/sqft', '$597'], ['Total Price', '$1,995,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/9420-Zyle-Rd-Austin-TX-78737/58315442_zpid/
# [['Type', 'Single Family'], ['Year built', '1999'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '1.47 Acres'], ['Price/sqft', '$256'], ['Total Price', '$599,900'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1206-Hidden-Hill-Cir-Austin-TX-78745/29497505_zpid/
# [['Type', 'Single Family'], ['Year built', '1974'], ['Heating', 'Heat pump, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '7,187 sqft'], ['Price/sqft', '$276'], ['Total Price', '$320,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/10300-Horace-Dr-Austin-TX-78753/29429315_zpid/
# [['Type', 'Single Family'], ['Year built', '1968'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '6 spaces'], ['HOA', 'None'], ['Lot', '0.38 acres'], ['Price/sqft', '$248'], ['Total Price', '$485,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/4627-Credo-Ln-164-Austin-TX-78725/2077629586_zpid/
# [['Type', 'Condo'], ['Year built', '2011'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$40/mo'], ['Price/sqft', '$195'], ['Total Price', '$215,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/11505-Firethorn-Ct-Austin-TX-78732/83823733_zpid/
# [['Type', 'Single Family'], ['Year built', '2006'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$179/month'], ['Lot', '0.61 acres'], ['Price/sqft', '$245'], ['Total Price', '$1,125,000'], ['Bedrooms', ' 6'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 4']]
# https://www.zillow.com/homedetails/8211-Nicola-Trl-Austin-TX-78745/89546561_zpid/
# [['Type', 'Single Family'], ['Year built', '2013'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '5,706 sqft'], ['Price/sqft', '$221'], ['Total Price', '$399,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/6813-Serlio-Dr-Austin-TX-78739/121656139_zpid/
# [['Type', 'Single Family'], ['Year built', '2014'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$50/month'], ['Lot', '7,797 sqft'], ['Price/sqft', '$203'], ['Total Price', '$610,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/10701-Beard-Ave-Austin-TX-78748/70332698_zpid/
# [['Type', 'Single Family'], ['Year built', '2005'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$38/month'], ['Lot', '6,403 sqft'], ['Price/sqft', '$198'], ['Total Price', '$385,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/904-West-Ave-APT-201-Austin-TX-78701/110539391_zpid/
# [['Type', 'Condo'], ['Year built', '1966'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$341/month'], ['Price/sqft', '$589'], ['Total Price', '$525,000'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/5309-William-Holland-Ave-5-Austin-TX-78756/125915180_zpid/
# [['Type', 'Condo'], ['Year built', '2014'], ['Heating', 'None, Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$175/mo'], ['Price/sqft', '$272'], ['Total Price', '$550,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/13110-Greybull-Trl-Austin-TX-78729/29575399_zpid/
# [['Type', 'Single Family'], ['Year built', '1986'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '9,888 sqft'], ['Price/sqft', '$244'], ['Total Price', '$350,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/7113-Scenic-Brook-Dr-Austin-TX-78736/29479335_zpid/
# [['Type', 'Single Family'], ['Year built', '1972'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.34 Acres'], ['Price/sqft', '$288'], ['Total Price', '$390,000'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/1223-Winnie-Dr-Austin-TX-78748/2079180204_zpid/
# [['Type', 'Single Family'], ['Year built', '2020'], ['Heating', 'Forced air, Electric, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '5,135 sqft'], ['Price/sqft', '$183'], ['Total Price', '$394,090'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1']]
# https://www.zillow.com/homedetails/1109-Winifred-Dr-Austin-TX-78748/2077632060_zpid/
# [['Type', 'Single Family'], ['Year built', '2020'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['HOA', '$88/month'], ['Lot', '4,356 sqft'], ['Price/sqft', '$163'], ['Total Price', '$407,755'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3']]
# https://www.zillow.com/homedetails/1901-Glen-Allen-St-APT-1-Austin-TX-78704/60138612_zpid/
# [['Type', 'Condo'], ['Year built', '1977'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$270/month'], ['Price/sqft', '$289'], ['Total Price', '$270,000'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]
# https://www.zillow.com/homedetails/9000-Honeycomb-Dr-Austin-TX-78737/29484794_zpid/
# [['Type', 'Single Family'], ['Year built', '1963'], ['Heating', 'Forced air, Electric'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '2.99 Acres'], ['Price/sqft', '$290'], ['Total Price', '$660,000'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2']]
# https://www.zillow.com/homedetails/14422-Ridgetop-Ter-Austin-TX-78732/29366915_zpid/
# [['Type', 'Single Family'], ['Year built', '1984'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', 'None'], ['Lot', '0.3 acres'], ['Price/sqft', '$373'], ['Total Price', '$399,999'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1']]

# %%
# data_list
# df = pd.DataFrame(data_list)
# df.to_csv('austin_data.csv', header=True)

# %%
df.head(3)
# Out:
#             Type Year built                    Heating  Cooling   Parking  \
# 0          Condo       2020                 Forced air  Central  4 spaces
# 1  Single Family       1972  Forced air, Electric, Gas  Central  2 spaces
# 2  Single Family       2020                 Forced air  Central  4 spaces
#
#           HOA Price/sqft Total Price Bedrooms Bathrooms Full bathrooms  \
# 0  $120/month       $314    $696,000        3         3              2
# 1         NaN       $344  $1,150,000        5         5              5
# 2        None       $267    $484,900        3         2              2
#
#   Half bathrooms                                 Address  \
# 0              1  3905-Clawson-Rd-UNIT-9-Austin-TX-78704
# 1            NaN      7109-Montana-Norte-Austin-TX-78731
# 2            NaN                         Austin-TX-78725
#
#                                                  URL         Lot
# 0  https://www.zillow.com/homedetails/3905-Clawso...         NaN
# 1  https://www.zillow.com/homedetails/7109-Montan...  0.29 Acres
# 2  https://www.zillow.com/homedetails/Austin-TX-7...  8,398 sqft

# %%
len(bum_links)
# Out:
# 22

# %%
# df.drop(columns=['Date available', 'Pets', 'Laundry',  'Deposit & fees'], inplace=True)
# commenting this out for austin data but need it for chicago data

# %%
austin = pd.read_csv('austin_data.csv')
chicago = pd.read_csv('zillow_data.csv')

austin['City'] = 'Austin'
chicago['City'] = 'Chicago'

chicago.drop(columns=['Date available', 'Pets', 'Laundry',  'Deposit & fees'], inplace=True)

# %%
set(chicago.columns.to_list()) - set(austin.columns.to_list())
# Out:
# set()

# %%
austin_chicago = pd.concat([chicago, austin]).drop(columns=['Unnamed: 0']).reset_index()
austin_chicago.drop(columns=['index'], inplace=True)

# %%
df = austin_chicago

# %%
df.replace(to_replace=['None', 'No Data'], value=np.nan, inplace=True)

# %%
df['Price/sqft'] = df['Price/sqft'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)

# %%
df['Total Price'] = df['Total Price'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)

# %%
df['HOA'] = df['Total Price'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)

# %%
df['Bedrooms'] = df['Bedrooms'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)

# %%
df['Bathrooms'] = df['Bathrooms'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)

# %%
# df['Parking'] = df['Parking'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)

# %%
# will have to think about how to encode this...
df.Parking.unique()
# Out:
# array(['1 space', '3 spaces', nan, '2 spaces', '5 spaces', '6 spaces',
#        '4 spaces', '9 spaces', '42 spaces', 'Detached Garage',
#        'Attached Garage', '8 spaces', '7 spaces', '82 spaces',
#        'Off street, Attached Garage', 'Carport', 'Off street',
#        'Carport, Detached Garage', '45 spaces',
#        'Carport, Attached Garage', 'Off street, Detached Garage'],
#       dtype=object)

# %%
df['Full bathrooms'] = df['Full bathrooms'].apply(lambda x: int(x) if isinstance(x, str) else x)

# %%
def acres_to_sqft(x):
    if isinstance(x, list):
        if 'acres' in x:
            sqft = float(x[0]) * 43560
            return round(sqft, 2)
        else:
            return float(x[0].replace(',',''))
    else:
        return x

# %%
# making all string units lowercase because of Acres and acres discrepancy 
df['Lot'] = df['Lot'].apply(lambda x: x.lower() if isinstance(x, str) else x)

# %%
df['Lot Temp'] = df['Lot'].str.split(' ')
df['Lot'] = df['Lot Temp'].apply(acres_to_sqft)

# %%
df.Lot.to_frame()
# Out:
#            Lot
# 0          NaN
# 1          NaN
# 2          NaN
# 3       4960.0
# 4          NaN
# ...        ...
# 1554    5135.0
# 1555    4356.0
# 1556       NaN
# 1557  130244.4
# 1558   13068.0
#
# [1559 rows x 1 columns]

# %%
# lot info is sometimes in acres so we'll have to account for that before running this

# df['Lot'] = df['Lot'].apply(lambda x: float(re.sub("[^0-9]", "", x)) if isinstance(x, str) else x)

# %%
df['Half bathrooms'].fillna(0, inplace=True)
df['Half bathrooms'] = df['Half bathrooms'].astype(int)

# %%
df['Year built'] = df['Year built'].apply(lambda x: int(x) if isinstance(x, str) else x)

# %%
df['Cooling'] = df.Cooling.replace('Refrigerator', 'Refrigeration')

# %%
df.Cooling.fillna('None', inplace=True)

# %%
df['sqft'] = df['Total Price'] / df['Price/sqft']

# %%
# df.to_csv('austin_chicago_clean.csv')

# %% [markdown]
# ### ok so now we have cleaned data for austin and chicago dfs now we can encode

# %%
chicago_only = df[df['City'] == 'Austin']

# %%
object_df = chicago_only.select_dtypes(include=['object'])
object_df.head(3)
# Out:
#               Type                    Heating  Cooling   Parking  \
# 781          Condo                 Forced air  Central  4 spaces
# 782  Single Family  Forced air, Electric, Gas  Central  2 spaces
# 783  Single Family                 Forced air  Central  4 spaces
#
#                                     Address  \
# 781  3905-Clawson-Rd-UNIT-9-Austin-TX-78704
# 782      7109-Montana-Norte-Austin-TX-78731
# 783                         Austin-TX-78725
#
#                                                    URL    City       Lot Temp
# 781  https://www.zillow.com/homedetails/3905-Clawso...  Austin            NaN
# 782  https://www.zillow.com/homedetails/7109-Montan...  Austin  [0.29, acres]
# 783  https://www.zillow.com/homedetails/Austin-TX-7...  Austin  [8,398, sqft]

# %%
test = pd.get_dummies(object_df[['Type', 'Cooling', 'City']], drop_first=True)
test
# Out:
#       Type_Condo  Type_Mobile / Manufactured  Type_Multi Family  \
# 781            1                           0                  0
# 782            0                           0                  0
# 783            0                           0                  0
# 784            0                           0                  0
# 785            0                           0                  0
# ...          ...                         ...                ...
# 1554           0                           0                  0
# 1555           0                           0                  0
# 1556           1                           0                  0
# 1557           0                           0                  0
# 1558           0                           0                  0
#
#       Type_Multiple Occupancy  Type_Single Family  Type_Townhouse  \
# 781                         0                   0               0
# 782                         0                   1               0
# 783                         0                   1               0
# 784                         0                   1               0
# 785                         0                   1               0
# ...                       ...                 ...             ...
# 1554                        0                   1               0
# 1555                        0                   1               0
# 1556                        0                   0               0
# 1557                        0                   1               0
# 1558                        0                   1               0
#
#       Cooling_Central, Evaporative  Cooling_Central, Wall  \
# 781                              0                      0
# 782                              0                      0
# 783                              0                      0
# 784                              0                      0
# 785                              0                      0
# ...                            ...                    ...
# 1554                             0                      0
# 1555                             0                      0
# 1556                             0                      0
# 1557                             0                      0
# 1558                             0                      0
#
#       Cooling_Evaporative  Cooling_None  Cooling_Other  Cooling_Wall
# 781                     0             0              0             0
# 782                     0             0              0             0
# 783                     0             0              0             0
# 784                     0             0              0             0
# 785                     0             0              0             0
# ...                   ...           ...            ...           ...
# 1554                    0             0              0             0
# 1555                    0             0              0             0
# 1556                    0             0              0             0
# 1557                    0             0              0             0
# 1558                    0             0              0             0
#
# [778 rows x 12 columns]

# %%
continous_df = chicago_only.select_dtypes(include=['float64', 'int64'])

# %%
clean_df = continous_df.join(test)
correlations = clean_df.corr()['Total Price'].to_frame()

# %%
correlations.sort_values(by=['Total Price'], ascending=False)
# Out:
#                               Total Price
# Total Price                      1.000000
# HOA                              1.000000
# Price/sqft                       0.722124
# sqft                             0.583526
# Full bathrooms                   0.509812
# Bathrooms                        0.464463
# Bedrooms                         0.261117
# Cooling_Central, Evaporative     0.182061
# Half bathrooms                   0.104388
# Cooling_Evaporative              0.075220
# Type_Multiple Occupancy          0.018943
# Type_Condo                       0.017476
# Cooling_Wall                     0.006747
# Year built                       0.003822
# Cooling_Central, Wall            0.003077
# Type_Single Family               0.001920
# Type_Multi Family                0.000349
# Lot                             -0.007003
# Cooling_Other                   -0.022921
# Type_Mobile / Manufactured      -0.024400
# Type_Townhouse                  -0.048061
# Cooling_None                    -0.164123

# %%
# import seaborn as sns
# sns.pairplot(continous_df)

# %%
# chicago = pd.read_csv('zillow_clean.csv')
# austin = pd.read_csv('zillow_austin_clean.csv')

# %%
# set(austin.columns.to_list()) - set(chicago.columns.to_list())

# %%
# # def get_property_features(link):
# #     try:
# r = requests.get('https://www.zillow.com/homedetails/460-W-Huron-St-Chicago-IL-60654/70427044_zpid/', headers=req_headers)
# soup = BeautifulSoup(r.content, 'html.parser')
# facts_and_features_table = soup.find('div', class_='ds-home-facts-and-features reso-facts-features sheety-facts-features')


# # this is the code for extracting features our of the home fact list table
# all_features = facts_and_features_table.find_all('li', class_='ds-home-fact-list-item')
# features_list = [item.text.split(':') for item in all_features]
# price = soup.find('div', class_='ds-home-details-chip').find('span', class_='ds-value').text
# features_list.append(['Total Price', price])

# # this is code for extracting number of bedroom/baths from a separate div
# # then formatting it to match our features from the first table and appending
# # to feature list

# beds_baths = soup.find(text='Bedrooms and bathrooms').next_element.text
# beds_baths = re.split('(\d+)',beds_baths.replace('1/2', 'Half'))[:-1]
# bed_baths_formatted = [i+j for i,j in zip(beds_baths[::2], beds_baths[1::2])]

# for item in bed_baths_formatted:
#     features_list.append(item.split(':'))

# %%
# features_list

# %%
# soup.find(text='Bedrooms: ').next_element.next_element
# soup.find(text='Bathrooms: ').next_element.next_element
# # soup.find(text='Bathrooms: ').next_element.next_element
# re.split('(\d+)','Bedrooms: 4Bathrooms: 3Full bathrooms: 3')
# # bed_baths_div = soup.find('div', class_='sc-pdKru hHHZLq')
# # # for item in a:
# # # #     print(item.text)
# # #     print(item)
# bed_baths = [item.text + ' ' for item in bed_baths_div]
# bed_baths = re.split('(\d+)', a[1])[:-1]
# bed_baths_formatted = [i+j for i,j in zip(test[::2], test[1::2])]
# bed_baths_formatted
# for item in bed_baths_div: 
#     print(re.split('(\d+)', item.text))
# # a.find_all('ul')

# %%
pd.read_csv('austin_chicago_clean.csv').head(10).drop(columns=['Unnamed: 0'])
# Out:
#             Type  Year built          Heating        Cooling   Parking  \
# 0          Condo      1891.0  Forced air, Gas        Central   1 space
# 1          Condo      1915.0  Forced air, Gas        Central   1 space
# 2          Condo      1991.0       Forced air        Central   1 space
# 3  Single Family      1944.0              Gas           None  3 spaces
# 4          Condo      1964.0       Forced air        Central   1 space
# 5          Condo      1921.0  Other, Electric  Refrigeration   1 space
# 6          Condo      2007.0  Forced air, Gas        Central   1 space
# 7          Condo      1948.0        Baseboard           None       NaN
# 8  Single Family      1916.0       Forced air        Central  2 spaces
# 9  Single Family      1962.0       Forced air        Central  2 spaces
#
#         HOA  Price/sqft  Total Price  Bedrooms  Bathrooms  Full bathrooms  \
# 0  399700.0       282.0     399700.0         2        2.0             2.0
# 1  319900.0       213.0     319900.0         2        2.0             2.0
# 2  300000.0       387.0     300000.0         1        1.0             1.0
# 3  160000.0       123.0     160000.0         2        1.0             1.0
# 4  429900.0       331.0     429900.0         2        2.0             2.0
# 5  272000.0         NaN     272000.0         1        1.0             1.0
# 6  579000.0       483.0     579000.0         2        2.0             2.0
# 7  220000.0       314.0     220000.0         1        1.0             1.0
# 8  500000.0       278.0     500000.0         5        3.0             3.0
# 9  240000.0       231.0     240000.0         3        1.0             1.0
#
#                                       Address  \
# 0   2511-W-Moffat-St-APT-110-Chicago-IL-60647
# 1    1116-W-Pratt-Blvd-APT-3-Chicago-IL-60626
# 2  440-N-Mcclurg-Ct-APT-1015-Chicago-IL-60611
# 3         11035-S-Pulaski-Rd-Chicago-IL-60655
# 4  222-E-Pearson-St-APT-1701-Chicago-IL-60611
# 5      60-E-Scott-St-APT-403-Chicago-IL-60610
# 6      2741-N-Bosworth-Ave-3-Chicago-IL-60614
# 7    1750-N-Wells-St-APT-202-Chicago-IL-60614
# 8          5240-W-Cuyler-Ave-Chicago-IL-60641
# 9             3433-W-54th-St-Chicago-IL-60632
#
#                                                  URL     Lot  Half bathrooms  \
# 0  https://www.zillow.com/homedetails/2511-W-Moff...     NaN               0
# 1  https://www.zillow.com/homedetails/1116-W-Prat...     NaN               0
# 2  https://www.zillow.com/homedetails/440-N-Mcclu...     NaN               0
# 3  https://www.zillow.com/homedetails/11035-S-Pul...  4960.0               0
# 4  https://www.zillow.com/homedetails/222-E-Pears...     NaN               0
# 5  https://www.zillow.com/homedetails/60-E-Scott-...     NaN               0
# 6  https://www.zillow.com/homedetails/2741-N-Bosw...     NaN               0
# 7  https://www.zillow.com/homedetails/1750-N-Well...     NaN               0
# 8  https://www.zillow.com/homedetails/5240-W-Cuyl...  3750.0               0
# 9  https://www.zillow.com/homedetails/3433-W-54th...  3136.0               0
#
#       City           Lot Temp
# 0  Chicago                NaN
# 1  Chicago                NaN
# 2  Chicago                NaN
# 3  Chicago  ['4,960', 'sqft']
# 4  Chicago                NaN
# 5  Chicago                NaN
# 6  Chicago                NaN
# 7  Chicago                NaN
# 8  Chicago  ['3,750', 'sqft']
# 9  Chicago  ['3,136', 'sqft']
