# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time, os
import numpy as np
import requests
import re
import random

# %%
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
def get_property_urls(link):
    # omg thank god for some dude on github for this req_header 0 CAPTCHAS i owe you my life
    
    req_headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-US,en;q=0.8',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
    }


    r = requests.get(link, headers=req_headers)
    soup = BeautifulSoup(r.content, 'html.parser')

    table = soup.find('ul', class_='photo-cards photo-cards_wow photo-cards_short')
    li_tags = table.find_all('li')
    properties = [item.find('div', class_='list-card-info')for item in li_tags]

    property_urls = []

    for item in properties:
        if item != None:
            property_extensions = item.find('a')['href']
            property_urls.append(property_extensions)
            
    return property_urls

# %%
def get_property_features(link):
    
    """
    Description: Grab all features from a listings URL (HOMES FOR SALE)
    Parameters: Link to listing (str)
    Return: all features from that properties url (dict)
    """
    
    try:
    
        req_headers = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'en-US,en;q=0.8',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
        }

        r = requests.get(link, headers=req_headers)
        soup = BeautifulSoup(r.content, 'html.parser')
        facts_and_features_table = soup.find('div', class_='ds-home-facts-and-features reso-facts-features sheety-facts-features')

        # this is the code for extracting features our of the home fact list table
        # creating a features list variable that we will append each scraped feature to
        # I'm deciding to do this so we can pull all the data in a particular table 
        # all at once and just use their entries for our column names
        
        all_features = facts_and_features_table.find_all('li', class_='ds-home-fact-list-item')
        features_list = [item.text.split(':') for item in all_features]
        address = soup.find('h1', class_='ds-address-container').text.replace(',\xa0', ', ')
        price = soup.find('div', class_='ds-home-details-chip').find('span', class_='ds-value').text
        summary_info = soup.find_all('span', class_='ds-bed-bath-living-area')

        # getting the third element in summnary info which is square feet and then splitting/
        # reversing it so its formatted as ['Square Feet', '728'] and not ['728', 'square feet']
        for item in summary_info:
            if 'sqft' in item.text.lower() or 'square feet' in item.text.lower():
                sqft = item.text.split(" ", 1)[::-1]
            else:
                sqft = np.nan

        # trying neighborhood stats in new way if this doesnt work uncomment code above
        if soup.find(text = 'Neighborhood stats')!=None:
            neighborhood_stats_formatted = soup.find(text = 'Neighborhood stats').next_element.get_text()
        else:
            neighborhood_stats_formatted = np.nan

        # finding if building was recently constructed or renovated from construction details
        # table 
        construction_details = soup.find_all('span', class_='Text-aiai24-0 cZksOw')
        for item in construction_details:
            if 'new construction' in item.text.lower():
                construction = item.text.split(':')

        features_list.append(['Total Price', price])
        features_list.append(['Address', address])
        features_list.append(sqft)
        features_list.append(construction)

        # this is code for extracting number of bedroom/baths from a separate div
        # then formatting it to match our features from the first table and appending
        # to feature list
        beds_baths = soup.find(text='Bedrooms and bathrooms').next_element.text
        beds_baths = re.split('(\d+)',beds_baths.replace('1/2', 'Half'))[:-1]
        bed_baths_formatted = [i+j for i,j in zip(beds_baths[::2], beds_baths[1::2])]

        for item in bed_baths_formatted:
            features_list.append(item.split(':'))

        features_list.append(['neighborhood_stats', neighborhood_stats_formatted])
        features_list.append(['URL', link])
        
        print(features_list)
        return dict(features_list)
    except:
        return None

# %%
def get_property_features_sold(link):
    
    """
    Description: Grab all features from a listings URL (HOMES SOLD)
    Parameters: Link to listing (str)
    Return: all features from that properties url (dict)
    """
        
    try:
    
        req_headers = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'en-US,en;q=0.8',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
        }


        r = requests.get(link, headers=req_headers)
        soup = BeautifulSoup(r.content, 'html.parser')
        facts_and_features_table = soup.find('div', class_='ds-home-facts-and-features reso-facts-features sheety-facts-features')


        # this is the code for extracting features our of the home fact list table
        all_features = facts_and_features_table.find_all('li', class_='ds-home-fact-list-item')
        features_list = [item.text.split(':') for item in all_features]
        address = soup.find('h1', class_='ds-address-container').text.replace(',\xa0', ', ')
        price = soup.find('span', class_='sc-pscky hEQFyS ds-status-details').get_text().lower().split(':')
        
        # so zillow has homes sold filter but people flip properties very quickly i guess
        # anyway we dont want to grab duplicates homes from when we looked at only for sale homes
        # so im creating this condition to make sure the status bar for the home says "Sold"
        
        if 'sold' in price:

            summary_info = soup.find_all('span', class_='ds-bed-bath-living-area')

            # getting the third element in summnary info which is square feet and then splitting/
            # reversing it so its formatted as ['Square Feet', '728'] and not ['728', 'square feet']
            for item in summary_info:
                if 'sqft' in item.text.lower() or 'square feet' in item.text.lower():
                    sqft = item.text.split(" ", 1)[::-1]
                else:
                    sqft = np.nan

            # getting all text out of neighborhoods stats about market trends 
            neighborhood_stats_formatted = soup.find(text = 'Neighborhood stats').next_element.get_text()

            # finding if building was recently constructed or renovated from construction details
            construction_details = soup.find_all('span', class_='Text-aiai24-0 cZksOw')
            for item in construction_details:
                if 'new construction' in item.text.lower():
                    construction = item.text.split(':')

            features_list.append(['Total Price', price[1]])
            features_list.append(['Address', address])
            features_list.append(sqft)
            features_list.append(construction)

            # this is code for extracting number of bedroom/baths from a separate div
            # then formatting it to match our features from the first table and appending
            # to feature list
            beds_baths = soup.find(text='Bedrooms and bathrooms').next_element.text
            beds_baths = re.split('(\d+)',beds_baths.replace('1/2', 'Half'))[:-1]
            bed_baths_formatted = [i+j for i,j in zip(beds_baths[::2], beds_baths[1::2])]

            for item in bed_baths_formatted:
                features_list.append(item.split(':'))

            features_list.append(['neighborhood_stats', neighborhood_stats_formatted])
            features_list.append(['URL', link])

            print(features_list)
            return dict(features_list)
        else:
            # if the status isnt listed as sold just skip this property
            # we dont want to wind up with a bunch of rentals that we cant scrape
            # or duplicates of properties we already scraped when filtering by
            # homes for sale
            pass
    except:
        return None

# %%
def generate_page_urls(location, num_pages, sold=False):
    """
    Description: get urls for first 20 pages for a location
    Parameter 1: location (str): e.g. 'chicago-il'
    Parameter 2: status (str): 'sold' or 'for_sale'
    
    Return: first 20 page urls (list)
    """
    
    if sold:
        base_url = 'https://www.zillow.com/{}/sold/'.format(location)
    else:
        base_url = 'https://www.zillow.com/homes/{}/'.format(location)
    
    first_20_pages_ext = [base_url + str(i) + '_p' for i in range(2,num_pages+1)]
    # as ganesh pointed out im not adding url for first page so im appending it here...
    first_20_pages_ext.append(base_url)
    return first_20_pages_ext

# %%
def get_all_property_urls(first_20_pages_ext):
    
    """
    Description: Get all the property urls for each page on Zillow
    Parameters: first 20 pages of urls (list)
    Return: urls for every property on each of the 20 pages
    """
    
    all_pages_property_urls = []
    for link in first_20_pages_ext:
        all_pages_property_urls.append(get_property_urls(link))

    # so right now i have a list of list and i want to flatten it for convenience
#     all_urls = all_pages_property_urls
    all_urls = [item for sublist in all_pages_property_urls for item in sublist]
    return all_urls

# %%
# cicero-il, oak-lawn-il salt-lake-city-ut  park-city-ut_ park-city-utah_rb, salt-lake-city-utah_rb pg 12
first_20_pages_ext = generate_page_urls('salt-lake-city-utah_rb', sold=False, num_pages=12)
all_urls = get_all_property_urls(first_20_pages_ext)

# %%
all_urls[:10]
# Out:
# ['https://www.zillow.com/homedetails/2349-E-Logan-Cir-Salt-Lake-City-UT-84108/2077556051_zpid/',
#  'https://www.zillow.com/homedetails/2599-S-700-E-Salt-Lake-City-UT-84106/2079223956_zpid/',
#  'https://www.zillow.com/homedetails/20-W-Layton-Ave-Salt-Lake-City-UT-84115/2102697252_zpid/',
#  'https://www.zillow.com/homedetails/1576-E-Yale-Ave-Salt-Lake-City-UT-84105/12761029_zpid/',
#  'https://www.zillow.com/homedetails/415-E-600-S-Salt-Lake-City-UT-84111/12755895_zpid/',
#  'https://www.zillow.com/homedetails/427-E-Sego-Ave-Salt-Lake-City-UT-84111/12755942_zpid/',
#  'https://www.zillow.com/homedetails/48-W-300-S-APT-406N-Salt-Lake-City-UT-84101/2081196880_zpid/',
#  'https://www.zillow.com/homedetails/1762-N-Earnshaw-Ln-Salt-Lake-City-UT-84116/12709412_zpid/',
#  'https://www.zillow.com/homedetails/373-E-700-S-Salt-Lake-City-UT-84111/12756412_zpid/',
#  'https://www.zillow.com/homedetails/166-S-1200-E-Salt-Lake-City-UT-84102/12753961_zpid/']

# %%
########################## testing area ##############################

# %%
# req_headers = {
#     'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
#     'accept-encoding': 'gzip, deflate, br',
#     'accept-language': 'en-US,en;q=0.8',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
# }

# link = 'https://www.zillow.com/homedetails/7701-N-Westhills-Trl-Park-City-UT-84098/68854701_zpid/'
# r = requests.get(link, headers=req_headers)
# soup = BeautifulSoup(r.content, 'html.parser')
# facts_and_features_table = soup.find('div', class_='ds-home-facts-and-features reso-facts-features sheety-facts-features')

# # this is the code for extracting features our of the home fact list table
# # creating a features list variable that we will append each scraped feature to
# # I'm deciding to do this so we can pull all the data in a particular table 
# # all at once and just use their entries for our column names

# all_features = facts_and_features_table.find_all('li', class_='ds-home-fact-list-item')
# features_list = [item.text.split(':') for item in all_features]
# address = soup.find('h1', class_='ds-address-container').text.replace(',\xa0', ', ')
# price = soup.find('div', class_='ds-home-details-chip').find('span', class_='ds-value').text
# summary_info = soup.find_all('span', class_='ds-bed-bath-living-area')

# # getting the third element in summnary info which is square feet and then splitting/
# # reversing it so its formatted as ['Square Feet', '728'] and not ['728', 'square feet']
# for item in summary_info:
#     if 'sqft' in item.text.lower() or 'square feet' in item.text.lower():
#         sqft = item.text.split(" ", 1)[::-1]
#     else:
#         sqft = np.nan

# # trying neighborhood stats in new way if this doesnt work uncomment code above
# if soup.find(text = 'Neighborhood stats')!=None:
#     neighborhood_stats_formatted = soup.find(text = 'Neighborhood stats').next_element.get_text()
# else:
#     neighborhood_stats_formatted = np.nan
# # finding if building was recently constructed or renovated from construction details
# # table 
# construction_details = soup.find_all('span', class_='Text-aiai24-0 cZksOw')
# for item in construction_details:
#     if 'new construction' in item.text.lower():
#         construction = item.text.split(':')

# features_list.append(['Total Price', price])
# features_list.append(['Address', address])
# features_list.append(sqft)
# features_list.append(construction)

# # this is code for extracting number of bedroom/baths from a separate div
# # then formatting it to match our features from the first table and appending
# # to feature list
# beds_baths = soup.find(text='Bedrooms and bathrooms').next_element.text
# beds_baths = re.split('(\d+)',beds_baths.replace('1/2', 'Half'))[:-1]
# bed_baths_formatted = [i+j for i,j in zip(beds_baths[::2], beds_baths[1::2])]

# for item in bed_baths_formatted:
#     features_list.append(item.split(':'))

# features_list.append(['neighborhood_stats', neighborhood_stats_formatted])
# features_list.append(['URL', link])

# print(features_list)

# %%
########################## testing end ##############################

# %%
# so this is where we are iterating over all the property links and calling our
# functions to scrape details from each url and return a dictionary of values
# also tracking when and on which links our functions failed to sucessfully scrape data
# so far bum links is usually only about 20 out of 800 so I'll live

data_list = []
bum_links = []
for link in all_urls:
    print(link)
    
    # change this to get property_features_sold if you want home info on properties
    # with the sold status... 
    data_raw = get_property_features(link)
    if data_raw != None:
        data_list.append(data_raw)
    else:
        # creating this so we can see what links didnt work and look into why later
        bum_links.append(link)
# Out:
# https://www.zillow.com/homedetails/2349-E-Logan-Cir-Salt-Lake-City-UT-84108/2077556051_zpid/
# [['Type', 'Single Family'], ['Year built', '1951'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '0.28 Acres'], ['Price/sqft', '$191'], ['Total Price', '$725,000'], ['Address', '2349 E Logan Cir, Salt Lake City, UT 84108'], ['Square Feet', '3,796'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Bonneville Hills have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Bonneville Hills will rise 4.5% (↑) in the next year.This home is valued 10.4% higher (↑) than the median home in Bonneville Hills.The median Zestimate® for this neighborhood is $656,656.'], ['URL', 'https://www.zillow.com/homedetails/2349-E-Logan-Cir-Salt-Lake-City-UT-84108/2077556051_zpid/']]
# https://www.zillow.com/homedetails/2599-S-700-E-Salt-Lake-City-UT-84106/2079223956_zpid/
# [['Type', 'Townhouse'], ['Year built', '2020'], ['Heating', 'Gas'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '435 sqft'], ['Price/sqft', '$294'], ['Total Price', '$535,000'], ['Address', '2599 S 700 E, Salt Lake City, UT 84106'], ['Square Feet', '1,817'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will increase 4.5% (↑) in the next year.This home is valued 14.3% higher (↑) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/2599-S-700-E-Salt-Lake-City-UT-84106/2079223956_zpid/']]
# https://www.zillow.com/homedetails/20-W-Layton-Ave-Salt-Lake-City-UT-84115/2102697252_zpid/
# [['Type', 'Single Family'], ['Year built', '1924'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '3 spaces'], ['Lot', '4,791 sqft'], ['Price/sqft', '$203'], ['Total Price', '$325,000'], ['Address', '20 W Layton Ave, Salt Lake City, UT 84115'], ['Square Feet', '1,599'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', "Home values in 84115 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in People's Freeway will rise 6.3% (↑) in the next year.This home is valued 0.3% higher (↑) than the median home in People's Freeway.The median Zestimate® for this neighborhood is $324,148."], ['URL', 'https://www.zillow.com/homedetails/20-W-Layton-Ave-Salt-Lake-City-UT-84115/2102697252_zpid/']]
# https://www.zillow.com/homedetails/1576-E-Yale-Ave-Salt-Lake-City-UT-84105/12761029_zpid/
# [['Type', 'Single Family'], ['Year built', '1926'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Lot', '9,583 sqft'], ['Price/sqft', '$456'], ['Total Price', '$1,500,000'], ['Address', '1576 E Yale Ave, Salt Lake City, UT 84105'], ['Square Feet', '3,293'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Yalecrest have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Yalecrest will increase 2.4% (↑) in the next year.This home is valued 93.8% higher (↑) than the median home in Yalecrest.The median Zestimate® for this neighborhood is $773,837.'], ['URL', 'https://www.zillow.com/homedetails/1576-E-Yale-Ave-Salt-Lake-City-UT-84105/12761029_zpid/']]
# https://www.zillow.com/homedetails/415-E-600-S-Salt-Lake-City-UT-84111/12755895_zpid/
# [['Type', 'Single Family'], ['Year built', '1907'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '4,791 sqft'], ['Price/sqft', '$330'], ['Total Price', '$375,000'], ['Address', '415 E 600 S, Salt Lake City, UT 84111'], ['Square Feet', '1,136'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Salt Lake City have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in Central City will rise 5.3% (↑) in the next year.This home is valued 10.7% lower (↓) than the median home in Central City.The median Zestimate® for this neighborhood is $419,987.'], ['URL', 'https://www.zillow.com/homedetails/415-E-600-S-Salt-Lake-City-UT-84111/12755895_zpid/']]
# https://www.zillow.com/homedetails/427-E-Sego-Ave-Salt-Lake-City-UT-84111/12755942_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1899'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Price/sqft', '$275'], ['Total Price', '$368,000'], ['Address', '427 E Sego Ave, Salt Lake City, UT 84111'], ['Square Feet', '1,340'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Salt Lake City have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in Central City will increase 5.3% (↑) in the next year.This home is valued 12.4% lower (↓) than the median home in Central City.The median Zestimate® for this neighborhood is $419,987.'], ['URL', 'https://www.zillow.com/homedetails/427-E-Sego-Ave-Salt-Lake-City-UT-84111/12755942_zpid/']]
# https://www.zillow.com/homedetails/48-W-300-S-APT-406N-Salt-Lake-City-UT-84101/2081196880_zpid/
# [['Type', 'Condo'], ['Year built', '1983'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['HOA', '$51,376/mo'], ['Price/sqft', '$249'], ['Total Price', '$375,000'], ['Address', '48 W 300 S APT 406N, Salt Lake City, UT 84101'], ['Square Feet', '1,509'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Downtown Salt Lake City have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Downtown will decrease 0.3% (↓) in the next year.This home is valued 8.5% lower (↓) than the median home in Downtown.The median Zestimate® for this neighborhood is $409,706.'], ['URL', 'https://www.zillow.com/homedetails/48-W-300-S-APT-406N-Salt-Lake-City-UT-84101/2081196880_zpid/']]
# https://www.zillow.com/homedetails/1762-N-Earnshaw-Ln-Salt-Lake-City-UT-84116/12709412_zpid/
# [['Type', 'Single Family'], ['Year built', '1997'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '7,840 sqft'], ['Price/sqft', '$199'], ['Total Price', '$389,900'], ['Address', '1762 N Earnshaw Ln, Salt Lake City, UT 84116'], ['Square Feet', '1,959'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Rose Park have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Rose Park will rise 8% (↑) in the next year.This home is valued 26.3% higher (↑) than the median home in Rose Park.The median Zestimate® for this neighborhood is $308,680.'], ['URL', 'https://www.zillow.com/homedetails/1762-N-Earnshaw-Ln-Salt-Lake-City-UT-84116/12709412_zpid/']]
# https://www.zillow.com/homedetails/373-E-700-S-Salt-Lake-City-UT-84111/12756412_zpid/
# [['Type', 'Single Family'], ['Year built', '1926'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '3,920 sqft'], ['Price/sqft', '$229'], ['Total Price', '$574,900'], ['Address', '373 E 700 S, Salt Lake City, UT 84111'], ['Square Feet', '2,508'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Salt Lake City have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in Central City will increase 5.3% (↑) in the next year.This home is valued 36.9% higher (↑) than the median home in Central City.The median Zestimate® for this neighborhood is $419,987.'], ['URL', 'https://www.zillow.com/homedetails/373-E-700-S-Salt-Lake-City-UT-84111/12756412_zpid/']]
# https://www.zillow.com/homedetails/166-S-1200-E-Salt-Lake-City-UT-84102/12753961_zpid/
# [['Type', 'Single Family'], ['Year built', '1904'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '3,484 sqft'], ['Price/sqft', '$305'], ['Total Price', '$640,000'], ['Address', '166 S 1200 E, Salt Lake City, UT 84102'], ['Square Feet', '2,096'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in East Central have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Central will increase 4.1% (↑) in the next year.This home is valued 34.7% higher (↑) than the median home in East Central.The median Zestimate® for this neighborhood is $475,000.'], ['URL', 'https://www.zillow.com/homedetails/166-S-1200-E-Salt-Lake-City-UT-84102/12753961_zpid/']]
# https://www.zillow.com/homedetails/8-E-Hillside-Ave-APT-405-Salt-Lake-City-UT-84103/2102051976_zpid/
# [['Type', 'Condo'], ['Year built', '1962'], ['Heating', 'Radiant'], ['Cooling', 'Refrigerator, Central'], ['Parking', '1 space'], ['HOA', '$336/mo'], ['Price/sqft', '$318'], ['Total Price', '$279,000'], ['Address', '8 E Hillside Ave APT 405, Salt Lake City, UT 84103'], ['Square Feet', '878'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Capitol Hill have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Capitol Hill will increase 5.8% (↑) in the next year.This home is valued 35.8% lower (↓) than the median home in Capitol Hill.The median Zestimate® for this neighborhood is $434,472.'], ['URL', 'https://www.zillow.com/homedetails/8-E-Hillside-Ave-APT-405-Salt-Lake-City-UT-84103/2102051976_zpid/']]
# https://www.zillow.com/homedetails/1135-N-Twickenham-Dr-Salt-Lake-City-UT-84103/83816452_zpid/
# [['Type', 'Single Family'], ['Year built', '2006'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '3 spaces'], ['Lot', '0.57 Acres'], ['Price/sqft', '$217'], ['Total Price', '$1,325,000'], ['Address', '1135 N Twickenham Dr, Salt Lake City, UT 84103'], ['Square Feet', '6,105'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Capitol Hill have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Capitol Hill will rise 5.8% (↑) in the next year.This home is valued 205% higher (↑) than the median home in Capitol Hill.The median Zestimate® for this neighborhood is $434,472.'], ['URL', 'https://www.zillow.com/homedetails/1135-N-Twickenham-Dr-Salt-Lake-City-UT-84103/83816452_zpid/']]
# https://www.zillow.com/homedetails/668-S-Park-St-Salt-Lake-City-UT-84102/12756868_zpid/
# [['Type', 'Single Family'], ['Year built', '1904'], ['Heating', 'Forced air'], ['Cooling', 'None'], ['Parking', 'No Data'], ['Lot', '2,178 sqft'], ['Price/sqft', '$296'], ['Total Price', '$360,000'], ['Address', '668 S Park St, Salt Lake City, UT 84102'], ['Square Feet', '1,216'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84102 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Central City will rise 5.3% (↑) in the next year.This home is valued 15.8% lower (↓) than the median home in Central City.The median Zestimate® for this neighborhood is $427,693.'], ['URL', 'https://www.zillow.com/homedetails/668-S-Park-St-Salt-Lake-City-UT-84102/12756868_zpid/']]
# https://www.zillow.com/homedetails/381-E-Westminster-Ave-South-Salt-Lake-UT-84115/12773192_zpid/
# [['Type', 'Single Family'], ['Year built', '1924'], ['Heating', 'Forced air'], ['Cooling', 'None'], ['Parking', 'No Data'], ['Lot', '3,484 sqft'], ['Price/sqft', '$333'], ['Total Price', '$385,000'], ['Address', '381 E Westminster Ave, South Salt Lake, UT 84115'], ['Square Feet', '1,155'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Liberty Wells have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Liberty Wells will rise 5.9% (↑) in the next year.This home is valued 0.7% higher (↑) than the median home in Liberty Wells.The median Zestimate® for this neighborhood is $382,242.'], ['URL', 'https://www.zillow.com/homedetails/381-E-Westminster-Ave-South-Salt-Lake-UT-84115/12773192_zpid/']]
# https://www.zillow.com/homedetails/2284-S-1900-E-Salt-Lake-City-UT-84106/12776878_zpid/
# [['Type', 'Single Family'], ['Year built', '1952'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '6,969 sqft'], ['Price/sqft', '$280'], ['Total Price', '$475,000'], ['Address', '2284 S 1900 E, Salt Lake City, UT 84106'], ['Square Feet', '1,698'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will increase 4.5% (↑) in the next year.This home is valued 1.5% higher (↑) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/2284-S-1900-E-Salt-Lake-City-UT-84106/12776878_zpid/']]
# https://www.zillow.com/homedetails/908-E-South-Temp-APT-4E-Salt-Lake-City-UT-84102/2077577260_zpid/
# [['Type', 'Condo'], ['Year built', '1982'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['HOA', '$588/mo'], ['Price/sqft', '$310'], ['Total Price', '$895,000'], ['Address', '908 E South Temp APT 4E, Salt Lake City, UT 84102'], ['Square Feet', '2,891'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in East Central have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Central will rise 4.1% (↑) in the next year.This home is valued 88.4% higher (↑) than the median home in East Central.The median Zestimate® for this neighborhood is $475,000.'], ['URL', 'https://www.zillow.com/homedetails/908-E-South-Temp-APT-4E-Salt-Lake-City-UT-84102/2077577260_zpid/']]
# https://www.zillow.com/homedetails/450-N-Chicago-St-W-Salt-Lake-City-UT-84116/2077580244_zpid/
# [['Type', 'Single Family'], ['Year built', '1941'], ['Heating', 'Forced air, Gas'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Lot', '7,405 sqft'], ['Price/sqft', '$238'], ['Total Price', '$375,000'], ['Address', '450 N Chicago St W, Salt Lake City, UT 84116'], ['Square Feet', '1,575'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Fairpark have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Fairpark will increase 11.1% (↑) in the next year.This home is valued 26.4% higher (↑) than the median home in Fairpark.The median Zestimate® for this neighborhood is $296,684.'], ['URL', 'https://www.zillow.com/homedetails/450-N-Chicago-St-W-Salt-Lake-City-UT-84116/2077580244_zpid/']]
# https://www.zillow.com/homedetails/861-N-Catherine-St-Salt-Lake-City-UT-84116/12713061_zpid/
# [['Type', 'Single Family'], ['Year built', '1952'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '7,840 sqft'], ['Price/sqft', '$212'], ['Total Price', '$399,900'], ['Address', '861 N Catherine St, Salt Lake City, UT 84116'], ['Square Feet', '1,887'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Rose Park have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Rose Park will rise 8% (↑) in the next year.This home is valued 29.6% higher (↑) than the median home in Rose Park.The median Zestimate® for this neighborhood is $308,680.'], ['URL', 'https://www.zillow.com/homedetails/861-N-Catherine-St-Salt-Lake-City-UT-84116/12713061_zpid/']]
# https://www.zillow.com/homedetails/308-E-Herbert-Ave-Salt-Lake-City-UT-84111/12757534_zpid/
# [['Type', 'Single Family'], ['Year built', '1919'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '3,920 sqft'], ['Price/sqft', '$276'], ['Total Price', '$635,000'], ['Address', '308 E Herbert Ave, Salt Lake City, UT 84111'], ['Square Feet', '2,300'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Central City-Liberty Wells have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Central City-Liberty Wells will rise 7% (↑) in the next year.This home is valued 69.1% higher (↑) than the median home in Central City-Liberty Wells.The median Zestimate® for this neighborhood is $375,558.'], ['URL', 'https://www.zillow.com/homedetails/308-E-Herbert-Ave-Salt-Lake-City-UT-84111/12757534_zpid/']]
# https://www.zillow.com/homedetails/981-S-Mcclelland-St-E-Salt-Lake-City-UT-84105/2077585138_zpid/
# [['Type', 'Single Family'], ['Year built', '1926'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '6,534 sqft'], ['Price/sqft', '$627'], ['Total Price', '$489,900'], ['Address', '981 S Mcclelland St E, Salt Lake City, UT 84105'], ['Square Feet', '781'], ['New construction', ' Yes'], ['Bedrooms', ' 0'], ['Bathrooms', ' 0'], ['neighborhood_stats', 'Home values in East Central have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Central will rise 4.1% (↑) in the next year.This home is valued 3.1% higher (↑) than the median home in East Central.The median Zestimate® for this neighborhood is $475,000.'], ['URL', 'https://www.zillow.com/homedetails/981-S-Mcclelland-St-E-Salt-Lake-City-UT-84105/2077585138_zpid/']]
# https://www.zillow.com/homedetails/233-N-Chicago-St-Salt-Lake-City-UT-84116/12715525_zpid/
# [['Type', 'Single Family'], ['Year built', '1900'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '0.79 Acres'], ['Price/sqft', '$531'], ['Total Price', '$649,900'], ['Address', '233 N Chicago St, Salt Lake City, UT 84116'], ['Square Feet', '1,224'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Fairpark have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Fairpark will increase 11.1% (↑) in the next year.This home is valued 119.1% higher (↑) than the median home in Fairpark.The median Zestimate® for this neighborhood is $296,684.'], ['URL', 'https://www.zillow.com/homedetails/233-N-Chicago-St-Salt-Lake-City-UT-84116/12715525_zpid/']]
# https://www.zillow.com/homedetails/379-N-G-St-E-Salt-Lake-City-UT-84103/2077596441_zpid/
# [['Type', 'Single Family'], ['Year built', '1909'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '4,791 sqft'], ['Price/sqft', '$281'], ['Total Price', '$899,000'], ['Address', '379 N G St E, Salt Lake City, UT 84103'], ['Square Feet', '3,201'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Greater Avenues have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Greater Avenues will increase 3.1% (↑) in the next year.This home is valued 51.1% higher (↑) than the median home in Greater Avenues.The median Zestimate® for this neighborhood is $594,926.'], ['URL', 'https://www.zillow.com/homedetails/379-N-G-St-E-Salt-Lake-City-UT-84103/2077596441_zpid/']]
# https://www.zillow.com/homedetails/851-E-1300-S-Salt-Lake-City-UT-84105/12759591_zpid/
# [['Type', 'Single Family'], ['Year built', '1906'], ['Heating', 'Forced air, Gas'], ['Cooling', 'None'], ['Parking', '1 space'], ['Lot', '7,840 sqft'], ['Price/sqft', '$188'], ['Total Price', '$599,900'], ['Address', '851 E 1300 S, Salt Lake City, UT 84105'], ['Square Feet', '3,183'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 4'], ['neighborhood_stats', 'Home values in East Central have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Central will rise 4.1% (↑) in the next year.This home is valued 26.3% higher (↑) than the median home in East Central.The median Zestimate® for this neighborhood is $475,000.'], ['URL', 'https://www.zillow.com/homedetails/851-E-1300-S-Salt-Lake-City-UT-84105/12759591_zpid/']]
# https://www.zillow.com/homedetails/525-S-900-E-APT-B3-Salt-Lake-City-UT-84102/52834710_zpid/
# [['Type', 'Condo'], ['Year built', '1994'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$231/mo'], ['Price/sqft', '$303'], ['Total Price', '$319,000'], ['Address', '525 S 900 E APT B3, Salt Lake City, UT 84102'], ['Square Feet', '1,054'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in East Central have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Central will increase 4.1% (↑) in the next year.This home is valued 32.8% lower (↓) than the median home in East Central.The median Zestimate® for this neighborhood is $475,000.'], ['URL', 'https://www.zillow.com/homedetails/525-S-900-E-APT-B3-Salt-Lake-City-UT-84102/52834710_zpid/']]
# https://www.zillow.com/homedetails/241-N-Vine-St-604-Salt-Lake-City-UT-84103/2077613746_zpid/
# [['Type', 'Condo'], ['Year built', '1976'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['HOA', '$383/mo'], ['Price/sqft', '$279'], ['Total Price', '$299,900'], ['Address', '241 N Vine St #604, Salt Lake City, UT 84103'], ['Square Feet', '1,075'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Capitol Hill have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Capitol Hill will increase 5.8% (↑) in the next year.This home is valued 31% lower (↓) than the median home in Capitol Hill.The median Zestimate® for this neighborhood is $434,472.'], ['URL', 'https://www.zillow.com/homedetails/241-N-Vine-St-604-Salt-Lake-City-UT-84103/2077613746_zpid/']]
# https://www.zillow.com/homedetails/1265-N-Garnette-St-Salt-Lake-City-UT-84116/12712112_zpid/
# [['Type', 'Single Family'], ['Year built', '1956'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '6,534 sqft'], ['Price/sqft', '$286'], ['Total Price', '$339,000'], ['Address', '1265 N Garnette St, Salt Lake City, UT 84116'], ['Square Feet', '1,187'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Rose Park have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Rose Park will increase 8% (↑) in the next year.This home is valued 9.8% higher (↑) than the median home in Rose Park.The median Zestimate® for this neighborhood is $308,680.'], ['URL', 'https://www.zillow.com/homedetails/1265-N-Garnette-St-Salt-Lake-City-UT-84116/12712112_zpid/']]
# https://www.zillow.com/homedetails/48-W-300-S-908-N-Salt-Lake-City-UT-84101/2077620011_zpid/
# [['Type', 'Condo'], ['Year built', '1983'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['HOA', '$505/mo'], ['Price/sqft', '$325'], ['Total Price', '$458,800'], ['Address', '48 W 300 S #908-N, Salt Lake City, UT 84101'], ['Square Feet', '1,410'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Downtown Salt Lake City have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Downtown will decrease 0.3% (↓) in the next year.This home is valued 12% higher (↑) than the median home in Downtown.The median Zestimate® for this neighborhood is $409,706.'], ['URL', 'https://www.zillow.com/homedetails/48-W-300-S-908-N-Salt-Lake-City-UT-84101/2077620011_zpid/']]
# https://www.zillow.com/homedetails/676-E-Markea-Ave-S-4-Salt-Lake-City-UT-84102/2077621952_zpid/
# [['Type', 'Townhouse'], ['Year built', '2011'], ['Heating', 'Forced air, Gas'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Lot', '871 sqft'], ['Price/sqft', '$268'], ['Total Price', '$549,000'], ['Address', '676 E Markea Ave S #4, Salt Lake City, UT 84102'], ['Square Feet', '2,052'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84102 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Central City will increase 5.3% (↑) in the next year.This home is valued 28.4% higher (↑) than the median home in Central City.The median Zestimate® for this neighborhood is $427,693.'], ['URL', 'https://www.zillow.com/homedetails/676-E-Markea-Ave-S-4-Salt-Lake-City-UT-84102/2077621952_zpid/']]
# https://www.zillow.com/homedetails/16-So-800-West-Salt-Lake-City-UT-84104/2088743291_zpid/
# https://www.zillow.com/homedetails/1534-S-1100-E-Salt-Lake-City-UT-84105/2077623029_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1907'], ['Heating', 'Forced air'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Price/sqft', '$265'], ['Total Price', '$625,000'], ['Address', '1534 S 1100 E, Salt Lake City, UT 84105'], ['Square Feet', '2,356'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in East Central have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Central will increase 4.1% (↑) in the next year.This home is valued 31.6% higher (↑) than the median home in East Central.The median Zestimate® for this neighborhood is $475,000.'], ['URL', 'https://www.zillow.com/homedetails/1534-S-1100-E-Salt-Lake-City-UT-84105/2077623029_zpid/']]
# https://www.zillow.com/homedetails/1310-E-Downington-Ave-A-Salt-Lake-City-UT-84105/2077623041_zpid/
# [['Type', 'Townhouse'], ['Year built', '2020'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '5,227 sqft'], ['Price/sqft', '$390'], ['Total Price', '$1,264,900'], ['Address', '1310 E Downington Ave #A, Salt Lake City, UT 84105'], ['Square Feet', '3,242'], ['New construction', ' Yes'], ['Bedrooms', ' 4'], ['Bathrooms', ' 5'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will rise 4.5% (↑) in the next year.This home is valued 170.2% higher (↑) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/1310-E-Downington-Ave-A-Salt-Lake-City-UT-84105/2077623041_zpid/']]
# https://www.zillow.com/homedetails/872-S-800-W-Salt-Lake-City-UT-84104/12738840_zpid/
# [['Type', 'Single Family'], ['Year built', '1911'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Lot', '4,791 sqft'], ['Price/sqft', '$265'], ['Total Price', '$289,900'], ['Address', '872 S 800 W, Salt Lake City, UT 84104'], ['Square Feet', '1,092'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Glendale have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Glendale will rise 7.8% (↑) in the next year.This home is valued 5.3% higher (↑) than the median home in Glendale.The median Zestimate® for this neighborhood is $275,245.'], ['URL', 'https://www.zillow.com/homedetails/872-S-800-W-Salt-Lake-City-UT-84104/12738840_zpid/']]
# https://www.zillow.com/homedetails/408-E-1300-S-Salt-Lake-City-UT-84115/2077623751_zpid/
# [['Type', 'Single Family'], ['Year built', '1924'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '4 spaces'], ['Lot', '4,791 sqft'], ['Price/sqft', '$221'], ['Total Price', '$359,900'], ['Address', '408 E 1300 S, Salt Lake City, UT 84115'], ['Square Feet', '1,626'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Liberty Wells have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Liberty Wells will increase 5.9% (↑) in the next year.This home is valued 5.8% lower (↓) than the median home in Liberty Wells.The median Zestimate® for this neighborhood is $382,242.'], ['URL', 'https://www.zillow.com/homedetails/408-E-1300-S-Salt-Lake-City-UT-84115/2077623751_zpid/']]
# https://www.zillow.com/homedetails/915-S-Park-Row-St-Salt-Lake-City-UT-84105/12760613_zpid/
# [['Type', 'Single Family'], ['Year built', '1921'], ['Heating', 'Forced air, Gas'], ['Cooling', 'None'], ['Parking', 'No Data'], ['Lot', '5,227 sqft'], ['Price/sqft', '$265'], ['Total Price', '$799,900'], ['Address', '915 S Park Row St, Salt Lake City, UT 84105'], ['Square Feet', '3,024'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Yalecrest have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Yalecrest will increase 2.4% (↑) in the next year.This home is valued 3.4% higher (↑) than the median home in Yalecrest.The median Zestimate® for this neighborhood is $773,837.'], ['URL', 'https://www.zillow.com/homedetails/915-S-Park-Row-St-Salt-Lake-City-UT-84105/12760613_zpid/']]
# https://www.zillow.com/homedetails/650-N-800-W-Salt-Lake-City-UT-84116/2077626031_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1983'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '12 spaces'], ['Price/sqft', '$200'], ['Total Price', '$2,320,000'], ['Address', '650 N 800 W, Salt Lake City, UT 84116'], ['Square Feet', '11,616'], ['New construction', ' No'], ['Bedrooms', ' 24'], ['Bathrooms', ' 24'], ['neighborhood_stats', 'Home values in Rose Park have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Rose Park will rise 8% (↑) in the next year.This home is valued 651.6% higher (↑) than the median home in Rose Park.The median Zestimate® for this neighborhood is $308,680.'], ['URL', 'https://www.zillow.com/homedetails/650-N-800-W-Salt-Lake-City-UT-84116/2077626031_zpid/']]
# https://www.zillow.com/homedetails/556-S-1200-E-Salt-Lake-City-UT-84102/12755286_zpid/
# [['Type', 'Single Family'], ['Year built', '1911'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '1 space'], ['Lot', '5,227 sqft'], ['Price/sqft', '$196'], ['Total Price', '$535,000'], ['Address', '556 S 1200 E, Salt Lake City, UT 84102'], ['Square Feet', '2,724'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in East Central have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Central will increase 4.1% (↑) in the next year.This home is valued 12.6% higher (↑) than the median home in East Central.The median Zestimate® for this neighborhood is $475,000.'], ['URL', 'https://www.zillow.com/homedetails/556-S-1200-E-Salt-Lake-City-UT-84102/12755286_zpid/']]
# https://www.zillow.com/homedetails/1367-S-Edison-St-Salt-Lake-City-UT-84115/12771277_zpid/
# [['Type', 'Single Family'], ['Year built', '1941'], ['Heating', 'Forced air, Gas'], ['Cooling', 'None'], ['Parking', '1 space'], ['Lot', '6,098 sqft'], ['Price/sqft', '$316'], ['Total Price', '$360,000'], ['Address', '1367 S Edison St, Salt Lake City, UT 84115'], ['Square Feet', '1,138'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Liberty Wells have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Liberty Wells will rise 5.9% (↑) in the next year.This home is valued 5.8% lower (↓) than the median home in Liberty Wells.The median Zestimate® for this neighborhood is $382,242.'], ['URL', 'https://www.zillow.com/homedetails/1367-S-Edison-St-Salt-Lake-City-UT-84115/12771277_zpid/']]
# https://www.zillow.com/homedetails/517-N-Westcapitol-St-Salt-Lake-City-UT-84103/12716259_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1951'], ['Heating', 'Heat pump'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Price/sqft', '$185'], ['Total Price', '$800,000'], ['Address', '517 N Westcapitol St, Salt Lake City, UT 84103'], ['Square Feet', '4,331'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 4'], ['neighborhood_stats', 'Home values in Capitol Hill have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Capitol Hill will increase 5.8% (↑) in the next year.This home is valued 84.1% higher (↑) than the median home in Capitol Hill.The median Zestimate® for this neighborhood is $434,472.'], ['URL', 'https://www.zillow.com/homedetails/517-N-Westcapitol-St-Salt-Lake-City-UT-84103/12716259_zpid/']]
# https://www.zillow.com/homedetails/346-Pierpont-Ave-W109-Salt-Lake-City-UT-84101/2077638065_zpid/
# [['Type', 'Condo'], ['Year built', '1904'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['HOA', '$131/mo'], ['Price/sqft', '$423'], ['Total Price', '$310,000'], ['Address', '346 Pierpont Ave #W109, Salt Lake City, UT 84101'], ['Square Feet', '732'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Downtown Salt Lake City have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Downtown will fall 0.3% (↓) in the next year.This home is valued 24.3% lower (↓) than the median home in Downtown.The median Zestimate® for this neighborhood is $409,706.'], ['URL', 'https://www.zillow.com/homedetails/346-Pierpont-Ave-W109-Salt-Lake-City-UT-84101/2077638065_zpid/']]
# https://www.zillow.com/homedetails/88-S-900-E-SUITE-304-Salt-Lake-City-UT-84102/111693366_zpid/
# [['Type', 'Condo'], ['Year built', '2008'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$332/mo'], ['Price/sqft', '$392'], ['Total Price', '$759,000'], ['Address', '88 S 900 E SUITE 304, Salt Lake City, UT 84102'], ['Square Feet', '1,936'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in East Central have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Central will increase 4.1% (↑) in the next year.This home is valued 59.8% higher (↑) than the median home in East Central.The median Zestimate® for this neighborhood is $475,000.'], ['URL', 'https://www.zillow.com/homedetails/88-S-900-E-SUITE-304-Salt-Lake-City-UT-84102/111693366_zpid/']]
# https://www.zillow.com/homedetails/275-N-Vine-St-Salt-Lake-City-UT-84103/12716639_zpid/
# [['Type', 'Townhouse'], ['Year built', '2020'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '2,178 sqft'], ['Price/sqft', '$421'], ['Total Price', '$1,275,000'], ['Address', '275 N Vine St, Salt Lake City, UT 84103'], ['Square Feet', '3,027'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Capitol Hill have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Capitol Hill will rise 5.8% (↑) in the next year.This home is valued 193.5% higher (↑) than the median home in Capitol Hill.The median Zestimate® for this neighborhood is $434,472.'], ['URL', 'https://www.zillow.com/homedetails/275-N-Vine-St-Salt-Lake-City-UT-84103/12716639_zpid/']]
# https://www.zillow.com/homedetails/1519-E-Military-Way-Salt-Lake-City-UT-84103/12722115_zpid/
# [['Type', 'Single Family'], ['Year built', '1984'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.36 Acres'], ['Price/sqft', '$340'], ['Total Price', '$2,300,000'], ['Address', '1519 E Military Way, Salt Lake City, UT 84103'], ['Square Feet', '6,768'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 5'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Greater Avenues have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Greater Avenues will increase 3.1% (↑) in the next year.This home is valued 286.6% higher (↑) than the median home in Greater Avenues.The median Zestimate® for this neighborhood is $594,926.'], ['URL', 'https://www.zillow.com/homedetails/1519-E-Military-Way-Salt-Lake-City-UT-84103/12722115_zpid/']]
# https://www.zillow.com/homedetails/265-N-Vine-St-APT-7-Salt-Lake-City-UT-84103/2077643919_zpid/
# [['Type', 'Condo'], ['Year built', '1965'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Price/sqft', '$305'], ['Total Price', '$240,900'], ['Address', '265 N Vine St APT 7, Salt Lake City, UT 84103'], ['Square Feet', '790'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Capitol Hill have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Capitol Hill will increase 5.8% (↑) in the next year.This home is valued 44.6% lower (↓) than the median home in Capitol Hill.The median Zestimate® for this neighborhood is $434,472.'], ['URL', 'https://www.zillow.com/homedetails/265-N-Vine-St-APT-7-Salt-Lake-City-UT-84103/2077643919_zpid/']]
# https://www.zillow.com/homedetails/315-W-700-N-APT-2-Salt-Lake-City-UT-84103/67701319_zpid/
# [['Type', 'Condo'], ['Year built', '2003'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$165/mo'], ['Price/sqft', '$225'], ['Total Price', '$259,000'], ['Address', '315 W 700 N APT 2, Salt Lake City, UT 84103'], ['Square Feet', '1,150'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Capitol Hill have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Capitol Hill will rise 5.8% (↑) in the next year.This home is valued 40.4% lower (↓) than the median home in Capitol Hill.The median Zestimate® for this neighborhood is $434,472.'], ['URL', 'https://www.zillow.com/homedetails/315-W-700-N-APT-2-Salt-Lake-City-UT-84103/67701319_zpid/']]
# https://www.zillow.com/homedetails/2522-S-1700-E-Salt-Lake-City-UT-84106/12777868_zpid/
# [['Type', 'Single Family'], ['Year built', '1942'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '6,098 sqft'], ['Price/sqft', '$259'], ['Total Price', '$450,000'], ['Address', '2522 S 1700 E, Salt Lake City, UT 84106'], ['Square Feet', '1,740'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will increase 4.5% (↑) in the next year.This home is valued 3.9% lower (↓) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/2522-S-1700-E-Salt-Lake-City-UT-84106/12777868_zpid/']]
# https://www.zillow.com/homedetails/416-E-8th-Ave-N-Salt-Lake-City-UT-84103/2077648980_zpid/
# [['Type', 'Single Family'], ['Year built', '1999'], ['Heating', 'Forced air'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Lot', '3,484 sqft'], ['Price/sqft', '$230'], ['Total Price', '$799,900'], ['Address', '416 E 8th Ave N, Salt Lake City, UT 84103'], ['Square Feet', '3,483'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Greater Avenues have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Greater Avenues will rise 3.1% (↑) in the next year.This home is valued 34.5% higher (↑) than the median home in Greater Avenues.The median Zestimate® for this neighborhood is $594,926.'], ['URL', 'https://www.zillow.com/homedetails/416-E-8th-Ave-N-Salt-Lake-City-UT-84103/2077648980_zpid/']]
# https://www.zillow.com/homedetails/1855-E-Laird-Ave-S-Salt-Lake-City-UT-84108/2077656748_zpid/
# [['Type', 'Single Family'], ['Year built', '1951'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Lot', '8,712 sqft'], ['Price/sqft', '$300'], ['Total Price', '$899,000'], ['Address', '1855 E Laird Ave S, Salt Lake City, UT 84108'], ['Square Feet', '2,994'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Yalecrest have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Yalecrest will rise 2.4% (↑) in the next year.This home is valued 16.2% higher (↑) than the median home in Yalecrest.The median Zestimate® for this neighborhood is $773,837.'], ['URL', 'https://www.zillow.com/homedetails/1855-E-Laird-Ave-S-Salt-Lake-City-UT-84108/2077656748_zpid/']]
# https://www.zillow.com/homedetails/1035-E-South-Temple-Salt-Lake-City-UT-84102/63234605_zpid/
# [['Type', 'Condo'], ['Year built', '2003'], ['Heating', 'Other, Electric'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$500/mo'], ['Price/sqft', '$294'], ['Total Price', '$850,000'], ['Address', '1035 E South Temple, Salt Lake City, UT 84102'], ['Square Feet', '2,896'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Greater Avenues have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Greater Avenues will increase 3.1% (↑) in the next year.This home is valued 42.9% higher (↑) than the median home in Greater Avenues.The median Zestimate® for this neighborhood is $594,926.'], ['URL', 'https://www.zillow.com/homedetails/1035-E-South-Temple-Salt-Lake-City-UT-84102/63234605_zpid/']]
# https://www.zillow.com/homedetails/318-E-Stanton-Ave-Salt-Lake-City-UT-84111/12755861_zpid/
# [['Type', 'Single Family'], ['Year built', '1908'], ['Heating', 'Other, Other'], ['Cooling', 'None'], ['Parking', 'No Data'], ['Lot', '2,178 sqft'], ['Price/sqft', '$460'], ['Total Price', '$400,000'], ['Address', '318 E Stanton Ave, Salt Lake City, UT 84111'], ['Square Feet', '870'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Salt Lake City have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in Central City will rise 5.3% (↑) in the next year.This home is valued 4.8% lower (↓) than the median home in Central City.The median Zestimate® for this neighborhood is $419,987.'], ['URL', 'https://www.zillow.com/homedetails/318-E-Stanton-Ave-Salt-Lake-City-UT-84111/12755861_zpid/']]
# https://www.zillow.com/homedetails/1348-E-Laird-Ave-S-Salt-Lake-City-UT-84105/2077660825_zpid/
# [['Type', 'Single Family'], ['Year built', '1927'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '6,098 sqft'], ['Price/sqft', '$293'], ['Total Price', '$989,900'], ['Address', '1348 E Laird Ave S, Salt Lake City, UT 84105'], ['Square Feet', '3,382'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Yalecrest have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Yalecrest will rise 2.4% (↑) in the next year.This home is valued 27.9% higher (↑) than the median home in Yalecrest.The median Zestimate® for this neighborhood is $773,837.'], ['URL', 'https://www.zillow.com/homedetails/1348-E-Laird-Ave-S-Salt-Lake-City-UT-84105/2077660825_zpid/']]
# https://www.zillow.com/homedetails/723-E-Downington-Ave-Salt-Lake-City-UT-84105/12770302_zpid/
# [['Type', 'Single Family'], ['Year built', '1924'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '1 space'], ['Lot', '2,178 sqft'], ['Price/sqft', '$299'], ['Total Price', '$339,500'], ['Address', '723 E Downington Ave, Salt Lake City, UT 84105'], ['Square Feet', '1,135'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will increase 4.5% (↑) in the next year.This home is valued 27.5% lower (↓) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/723-E-Downington-Ave-Salt-Lake-City-UT-84105/12770302_zpid/']]
# https://www.zillow.com/homedetails/143-E-First-North-Ave-404-Salt-Lake-City-UT-84103/2077666736_zpid/
# [['Type', 'Condo'], ['Year built', '1966'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['HOA', '$215/mo'], ['Price/sqft', '$392'], ['Total Price', '$297,500'], ['Address', '143 E First North Ave #404, Salt Lake City, UT 84103'], ['Square Feet', '758'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Greater Avenues have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Greater Avenues will rise 3.1% (↑) in the next year.This home is valued 50% lower (↓) than the median home in Greater Avenues.The median Zestimate® for this neighborhood is $594,926.'], ['URL', 'https://www.zillow.com/homedetails/143-E-First-North-Ave-404-Salt-Lake-City-UT-84103/2077666736_zpid/']]
# https://www.zillow.com/homedetails/45-W-South-Temp-S-204-Salt-Lake-City-UT-84101/2077672947_zpid/
# [['Type', 'Condo'], ['Year built', '2010'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['HOA', '$557/mo'], ['Price/sqft', '$501'], ['Total Price', '$675,000'], ['Address', '45 W South Temp S #204, Salt Lake City, UT 84101'], ['Square Feet', '1,348'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Downtown Salt Lake City have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Downtown will decrease 0.3% (↓) in the next year.This home is valued 64.8% higher (↑) than the median home in Downtown.The median Zestimate® for this neighborhood is $409,706.'], ['URL', 'https://www.zillow.com/homedetails/45-W-South-Temp-S-204-Salt-Lake-City-UT-84101/2077672947_zpid/']]
# https://www.zillow.com/homedetails/328-W-200-S-APT-307-Salt-Lake-City-UT-84101/83813629_zpid/
# ...
# https://www.zillow.com/homedetails/Salt-Lake-City-UT-84103/97745428_zpid/
# https://www.zillow.com/homedetails/Salt-Lake-City-UT-84103/2078248818_zpid/
# https://www.zillow.com/homedetails/908-E-South-Temp-APT-6W-Salt-Lake-City-UT-84102/2077548005_zpid/
# [['Type', 'Condo'], ['Year built', '1982'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['HOA', '$588/mo'], ['Price/sqft', '$259'], ['Total Price', '$750,000'], ['Address', '908 E South Temp APT 6W, Salt Lake City, UT 84102'], ['Square Feet', '2,891'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in East Central have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Central will increase 4.1% (↑) in the next year.This home is valued 57.9% higher (↑) than the median home in East Central.The median Zestimate® for this neighborhood is $475,000.'], ['URL', 'https://www.zillow.com/homedetails/908-E-South-Temp-APT-6W-Salt-Lake-City-UT-84102/2077548005_zpid/']]
# https://www.zillow.com/homedetails/20-N-P-St-E-Salt-Lake-City-UT-84103/2080509523_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '1901'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['Price/sqft', '$404'], ['Total Price', '$450,000'], ['Address', '20 N P St E, Salt Lake City, UT 84103'], ['Square Feet', '1,113'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Greater Avenues have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Greater Avenues will rise 3.1% (↑) in the next year.This home is valued 24.4% lower (↓) than the median home in Greater Avenues.The median Zestimate® for this neighborhood is $594,926.'], ['URL', 'https://www.zillow.com/homedetails/20-N-P-St-E-Salt-Lake-City-UT-84103/2080509523_zpid/']]
# https://www.zillow.com/homedetails/744-E-Emerson-Ave-Salt-Lake-City-UT-84105/12769004_zpid/
# [['Type', 'Single Family'], ['Year built', '1916'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Lot', '4,356 sqft'], ['Price/sqft', '$281'], ['Total Price', '$650,000'], ['Address', '744 E Emerson Ave, Salt Lake City, UT 84105'], ['Square Feet', '2,312'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in East Central have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Central will rise 4.1% (↑) in the next year.This home is valued 36.8% higher (↑) than the median home in East Central.The median Zestimate® for this neighborhood is $475,000.'], ['URL', 'https://www.zillow.com/homedetails/744-E-Emerson-Ave-Salt-Lake-City-UT-84105/12769004_zpid/']]
# https://www.zillow.com/homedetails/20-N-P-St-E-Salt-Lake-City-UT-84103/2077548677_zpid/
# [['Type', 'Single Family'], ['Year built', '1901'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['Lot', '3,484 sqft'], ['Price/sqft', '$404'], ['Total Price', '$450,000'], ['Address', '20 N P St E, Salt Lake City, UT 84103'], ['Square Feet', '1,113'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Greater Avenues have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Greater Avenues will increase 3.1% (↑) in the next year.This home is valued 24.4% lower (↓) than the median home in Greater Avenues.The median Zestimate® for this neighborhood is $594,926.'], ['URL', 'https://www.zillow.com/homedetails/20-N-P-St-E-Salt-Lake-City-UT-84103/2077548677_zpid/']]
# https://www.zillow.com/homedetails/3070-E-Kennedy-Dr-Salt-Lake-City-UT-84108/2091181092_zpid/
# https://www.zillow.com/homedetails/2770-S-Sonnet-Dr-Salt-Lake-City-UT-84106/2077548882_zpid/
# [['Type', 'Single Family'], ['Year built', '1960'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '0.26 Acres'], ['Price/sqft', '$199'], ['Total Price', '$619,900'], ['Address', '2770 S Sonnet Dr, Salt Lake City, UT 84106'], ['Square Feet', '3,118'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will increase 4.5% (↑) in the next year.This home is valued 32.4% higher (↑) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/2770-S-Sonnet-Dr-Salt-Lake-City-UT-84106/2077548882_zpid/']]
# https://www.zillow.com/homedetails/1093-S-Denver-St-Salt-Lake-City-UT-84111/12757920_zpid/
# [['Type', 'Single Family'], ['Year built', '1920'], ['Heating', 'Other, Gas'], ['Cooling', 'Evaporative'], ['Parking', '2 spaces'], ['Lot', '6,534 sqft'], ['Price/sqft', '$226'], ['Total Price', '$470,000'], ['Address', '1093 S Denver St, Salt Lake City, UT 84111'], ['Square Feet', '2,080'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Central City-Liberty Wells have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Central City-Liberty Wells will rise 7% (↑) in the next year.This home is valued 25.1% higher (↑) than the median home in Central City-Liberty Wells.The median Zestimate® for this neighborhood is $375,558.'], ['URL', 'https://www.zillow.com/homedetails/1093-S-Denver-St-Salt-Lake-City-UT-84111/12757920_zpid/']]
# https://www.zillow.com/homedetails/1341-W-700-S-Salt-Lake-City-UT-84104/2077549286_zpid/
# https://www.zillow.com/homedetails/1932-E-Herbert-Ave-Salt-Lake-City-UT-84108/12761827_zpid/
# [['Type', 'Single Family'], ['Year built', '1940'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '6,969 sqft'], ['Price/sqft', '$375'], ['Total Price', '$795,000'], ['Address', '1932 E Herbert Ave, Salt Lake City, UT 84108'], ['Square Feet', '2,122'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Bonneville Hills have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Bonneville Hills will rise 4.5% (↑) in the next year.This home is valued 21.1% higher (↑) than the median home in Bonneville Hills.The median Zestimate® for this neighborhood is $656,656.'], ['URL', 'https://www.zillow.com/homedetails/1932-E-Herbert-Ave-Salt-Lake-City-UT-84108/12761827_zpid/']]
# https://www.zillow.com/homedetails/1842-E-Sunnyside-Ave-Salt-Lake-City-UT-84108/12760702_zpid/
# [['Type', 'Single Family'], ['Year built', '1940'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '6,969 sqft'], ['Price/sqft', '$260'], ['Total Price', '$535,000'], ['Address', '1842 E Sunnyside Ave, Salt Lake City, UT 84108'], ['Square Feet', '2,054'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Yalecrest have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Yalecrest will increase 2.4% (↑) in the next year.This home is valued 30.9% lower (↓) than the median home in Yalecrest.The median Zestimate® for this neighborhood is $773,837.'], ['URL', 'https://www.zillow.com/homedetails/1842-E-Sunnyside-Ave-Salt-Lake-City-UT-84108/12760702_zpid/']]
# https://www.zillow.com/homedetails/786-N-Sonata-St-Salt-Lake-City-UT-84116/12711104_zpid/
# [['Type', 'Single Family'], ['Year built', '1949'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Other'], ['Parking', '1 space'], ['Lot', '6,098 sqft'], ['Price/sqft', '$230'], ['Total Price', '$309,000'], ['Address', '786 N Sonata St, Salt Lake City, UT 84116'], ['Square Feet', '1,344'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Rose Park have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Rose Park will increase 8% (↑) in the next year.This home is valued 0.1% higher (↑) than the median home in Rose Park.The median Zestimate® for this neighborhood is $308,680.'], ['URL', 'https://www.zillow.com/homedetails/786-N-Sonata-St-Salt-Lake-City-UT-84116/12711104_zpid/']]
# https://www.zillow.com/homedetails/720-E-5th-Ave-APT-10-Salt-Lake-City-UT-84103/2077549612_zpid/
# [['Type', 'Condo'], ['Year built', '1969'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['HOA', '$275/mo'], ['Price/sqft', '$400'], ['Total Price', '$284,900'], ['Address', '720 E 5th Ave APT 10, Salt Lake City, UT 84103'], ['Square Feet', '712'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Greater Avenues have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Greater Avenues will rise 3.1% (↑) in the next year.This home is valued 52.1% lower (↓) than the median home in Greater Avenues.The median Zestimate® for this neighborhood is $594,926.'], ['URL', 'https://www.zillow.com/homedetails/720-E-5th-Ave-APT-10-Salt-Lake-City-UT-84103/2077549612_zpid/']]
# https://www.zillow.com/homedetails/2687-S-Hartford-St-Salt-Lake-City-UT-84106/12777756_zpid/
# [['Type', 'Single Family'], ['Year built', '1948'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '1 space'], ['Lot', '6,534 sqft'], ['Price/sqft', '$302'], ['Total Price', '$549,999'], ['Address', '2687 S Hartford St, Salt Lake City, UT 84106'], ['Square Feet', '1,820'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will increase 4.5% (↑) in the next year.This home is valued 17.5% higher (↑) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/2687-S-Hartford-St-Salt-Lake-City-UT-84106/12777756_zpid/']]
# https://www.zillow.com/homedetails/1335-W-700-S-Salt-Lake-City-UT-84104/2077552975_zpid/
# https://www.zillow.com/homedetails/1740-E-Blaine-Ave-Salt-Lake-City-UT-84108/2077553395_zpid/
# [['Type', 'Single Family'], ['Year built', '1950'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['Lot', '7,840 sqft'], ['Price/sqft', '$365'], ['Total Price', '$649,000'], ['Address', '1740 E Blaine Ave, Salt Lake City, UT 84108'], ['Square Feet', '1,776'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will rise 4.5% (↑) in the next year.This home is valued 38.6% higher (↑) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/1740-E-Blaine-Ave-Salt-Lake-City-UT-84108/2077553395_zpid/']]
# https://www.zillow.com/homedetails/1875-E-900-S-Salt-Lake-City-UT-84108/12760717_zpid/
# [['Type', 'Single Family'], ['Year built', '1940'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '6,534 sqft'], ['Price/sqft', '$299'], ['Total Price', '$619,000'], ['Address', '1875 E 900 S, Salt Lake City, UT 84108'], ['Square Feet', '2,068'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Yalecrest have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Yalecrest will increase 2.4% (↑) in the next year.This home is valued 20% lower (↓) than the median home in Yalecrest.The median Zestimate® for this neighborhood is $773,837.'], ['URL', 'https://www.zillow.com/homedetails/1875-E-900-S-Salt-Lake-City-UT-84108/12760717_zpid/']]
# https://www.zillow.com/homedetails/225-W-Montrose-Ave-Salt-Lake-City-UT-84101/305057119_zpid/
# [['Type', 'Single Family'], ['Year built', '1912'], ['Heating', 'No Data'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '6,098 sqft'], ['Price/sqft', '$461'], ['Total Price', '$449,000'], ['Address', '225 W Montrose Ave, Salt Lake City, UT 84101'], ['Square Feet', '973'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 23'], ['/4'], [' bathrooms', ' 2'], ['neighborhood_stats', "Home values in 84101 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in People's Freeway will rise 2.8% (↑) in the next year.This home is valued 18.6% higher (↑) than the median home in People's Freeway.The median Zestimate® for this neighborhood is $378,725."], ['URL', 'https://www.zillow.com/homedetails/225-W-Montrose-Ave-Salt-Lake-City-UT-84101/305057119_zpid/']]
# https://www.zillow.com/homedetails/1506-S-2100-E-Salt-Lake-City-UT-84108/12764372_zpid/
# [['Type', 'Single Family'], ['Year built', '1946'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Lot', '6,098 sqft'], ['Price/sqft', '$206'], ['Total Price', '$459,000'], ['Address', '1506 S 2100 E, Salt Lake City, UT 84108'], ['Square Feet', '2,224'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Bonneville Hills have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Bonneville Hills will rise 4.5% (↑) in the next year.This home is valued 30.1% lower (↓) than the median home in Bonneville Hills.The median Zestimate® for this neighborhood is $656,656.'], ['URL', 'https://www.zillow.com/homedetails/1506-S-2100-E-Salt-Lake-City-UT-84108/12764372_zpid/']]
# https://www.zillow.com/homedetails/138-E-Harvard-Ave-Salt-Lake-City-UT-84111/12757401_zpid/
# [['Type', 'Single Family'], ['Year built', '1922'], ['Heating', 'Other, Gas'], ['Cooling', 'Refrigerator, Evaporative'], ['Parking', '2 spaces'], ['Lot', '3,049 sqft'], ['Price/sqft', '$281'], ['Total Price', '$335,000'], ['Address', '138 E Harvard Ave, Salt Lake City, UT 84111'], ['Square Feet', '1,192'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Central City-Liberty Wells have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Central City-Liberty Wells will increase 7% (↑) in the next year.This home is valued 10.8% lower (↓) than the median home in Central City-Liberty Wells.The median Zestimate® for this neighborhood is $375,558.'], ['URL', 'https://www.zillow.com/homedetails/138-E-Harvard-Ave-Salt-Lake-City-UT-84111/12757401_zpid/']]
# https://www.zillow.com/homedetails/1799-S-Wasatch-Dr-Salt-Lake-City-UT-84108/12764099_zpid/
# [['Type', 'Single Family'], ['Year built', '1986'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '8,276 sqft'], ['Price/sqft', '$281'], ['Total Price', '$950,000'], ['Address', '1799 S Wasatch Dr, Salt Lake City, UT 84108'], ['Square Feet', '3,376'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 2'], ['neighborhood_stats', 'Home values in East Bench have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Bench will rise 4.6% (↑) in the next year.This home is valued 20.3% higher (↑) than the median home in East Bench.The median Zestimate® for this neighborhood is $789,856.'], ['URL', 'https://www.zillow.com/homedetails/1799-S-Wasatch-Dr-Salt-Lake-City-UT-84108/12764099_zpid/']]

# %%
# pd.DataFrame(data_list)
# Out:
#               Type Year built          Heating  Cooling   Parking  \
# 0    Single Family       1968  Forced air, Gas  Central  2 spaces
# 1    Single Family       1999  Forced air, Gas  Central  3 spaces
# 2            Condo       1989       Forced air  Central   1 space
# 3    Single Family       1915              Gas  No Data   1 space
# 4    Single Family       1986          No Data  No Data  2 spaces
# ..             ...        ...              ...      ...       ...
# 372  Single Family       1921        Baseboard  Central   1 space
# 373      Townhouse       2020          No Data  No Data  2 spaces
# 374  Single Family       2020          No Data  No Data  2 spaces
# 375  Single Family       2020       Forced air  Central  3 spaces
# 376  Single Family       2016              Gas  Central  3 spaces
#
#              Lot Price/sqft Total Price  \
# 0    10,018 sqft       $191    $470,000
# 1     0.29 Acres       $160    $529,900
# 2            NaN       $187    $214,500
# 3    10,018 sqft       $626    $349,900
# 4     0.35 Acres       $217    $739,900
# ..           ...        ...         ...
# 372   8,372 sqft       $222    $599,900
# 373      No Data       $226    $494,588
# 374      No Data       $160    $540,990
# 375      No Data       $305    $901,168
# 376   0.28 Acres       $188    $649,500
#
#                                                Address Square Feet  \
# 0        928 Royal Blackheath Ct, Naperville, IL 60563       2,464
# 1                1452 Chelsea Ln, Naperville, IL 60565       3,305
# 2           1292 Rhodes Ln #1292, Naperville, IL 60540       1,149
# 3           1131 N Washington St, Naperville, IL 60563         559
# 4                512 Braemar Ave, Naperville, IL 60563       3,406
# ..                                                 ...         ...
# 372            215 S Columbia St, Naperville, IL 60540       2,702
# 373  Buildable plan: Metro, Columbia Park Townes, N...         NaN
# 374  Buildable plan: Castleton, Wagner Farms, Naper...         NaN
# 375  Buildable plan: The Abbey, DJK Custom Homes of...         NaN
# 376            1503 Alderleaf Ct, Naperville, IL 60563       3,459
#
#     New construction Bedrooms Bathrooms Full bathrooms Half bathrooms  \
# 0                 No        4         3              2              1
# 1                 No        4         4              3              1
# 2                 No        2         2              2            NaN
# 3                 No        1         1              1            NaN
# 4                 No        5         5              4              1
# ..               ...      ...       ...            ...            ...
# 372               No        4         4              4            NaN
# 373              Yes        3         3              2              1
# 374              Yes        4         3              2              1
# 375              Yes        4         3              2              1
# 376               No        4         3              2              1
#
#                                     neighborhood_stats  \
# 0    Home values in 60563 have risen 1.0 % (↑) over...
# 1    Home values in 60565 have risen 1.0 % (↑) over...
# 2    Home values in 60540 have risen 1.0 % (↑) over...
# 3    Home values in 60563 have risen 1.0 % (↑) over...
# 4    Home values in 60563 have risen 1.0 % (↑) over...
# ..                                                 ...
# 372  Home values in 60540 have risen 1.0 % (↑) over...
# 373  Home values in 60563 have risen 1.0 % (↑) over...
# 374  Home values in 60564 have risen 1.0 % (↑) over...
# 375  Home values in 60540 have risen 1.0 % (↑) over...
# 376  Home values in 60563 have risen 1.0 % (↑) over...
#
#                                                    URL         HOA   sqft
# 0    https://www.zillow.com/homedetails/928-Royal-B...         NaN    NaN
# 1    https://www.zillow.com/homedetails/1452-Chelse...         NaN    NaN
# 2    https://www.zillow.com/homedetails/1292-Rhodes...  $238/month    NaN
# 3    https://www.zillow.com/homedetails/1131-N-Wash...         NaN    NaN
# 4    https://www.zillow.com/homedetails/512-Braemar...         NaN    NaN
# ..                                                 ...         ...    ...
# 372  https://www.zillow.com/homedetails/215-S-Colum...         NaN    NaN
# 373  https://www.zillow.com/community/columbia-park...         NaN  2,185
# 374  https://www.zillow.com/community/wagner-farms/...         NaN  3,391
# 375  https://www.zillow.com/community/djk-custom-ho...         NaN  2,959
# 376  https://www.zillow.com/homedetails/1503-Alderl...         NaN    NaN
#
# [377 rows x 19 columns]

# %%
# data_list
df = pd.DataFrame(data_list)
# df.to_csv('sold_raw.csv', header=True)
df
# Out:
#                    Type Year built          Heating  \
# 0             Townhouse       2020              Gas
# 1         Single Family       1924          No Data
# 2         Single Family       1907       Forced air
# 3    Multiple Occupancy       1899            Other
# 4                 Condo       1983          No Data
# ..                  ...        ...              ...
# 227       Single Family       1949  Forced air, Gas
# 228               Condo       1969          No Data
# 229       Single Family       1940  Forced air, Gas
# 230       Single Family       1946            Other
# 231       Single Family       1922       Other, Gas
#
#                        Cooling   Parking         Lot Price/sqft Total Price  \
# 0                      No Data  2 spaces    435 sqft       $294    $535,000
# 1                      No Data  3 spaces  4,791 sqft       $203    $325,000
# 2                      Central   No Data  4,791 sqft       $330    $375,000
# 3                      Central   No Data         NaN       $275    $368,000
# 4                      No Data   1 space         NaN       $249    $375,000
# ..                         ...       ...         ...        ...         ...
# 227                      Other   1 space  6,098 sqft       $230    $309,000
# 228                    No Data   1 space         NaN       $400    $284,900
# 229                    Central  2 spaces  6,534 sqft       $299    $619,000
# 230                    Central   1 space  6,098 sqft       $206    $459,000
# 231  Refrigerator, Evaporative  2 spaces  3,049 sqft       $281    $335,000
#
#                                             Address Square Feet  \
# 0            2599 S 700 E, Salt Lake City, UT 84106       1,817
# 1         20 W Layton Ave, Salt Lake City, UT 84115       1,599
# 2             415 E 600 S, Salt Lake City, UT 84111       1,136
# 3          427 E Sego Ave, Salt Lake City, UT 84111       1,340
# 4     48 W 300 S APT 406N, Salt Lake City, UT 84101       1,509
# ..                                              ...         ...
# 227       786 N Sonata St, Salt Lake City, UT 84116       1,344
# 228  720 E 5th Ave APT 10, Salt Lake City, UT 84103         712
# 229          1875 E 900 S, Salt Lake City, UT 84108       2,068
# 230         1506 S 2100 E, Salt Lake City, UT 84108       2,224
# 231     138 E Harvard Ave, Salt Lake City, UT 84111       1,192
#
#     New construction Bedrooms Bathrooms Full bathrooms Half bathrooms  \
# 0                 No        3         3              2              1
# 1                 No        2         1              1            NaN
# 2                 No        2         1              1            NaN
# 3                 No        2         2            NaN            NaN
# 4                 No        2         2              2            NaN
# ..               ...      ...       ...            ...            ...
# 227               No        2         1              1            NaN
# 228               No        2         1              1            NaN
# 229               No        3         2              2            NaN
# 230               No        3         1              1            NaN
# 231               No        2         1              1            NaN
#
#                                     neighborhood_stats  \
# 0    Home values in Sugar House have risen 5.3 % (↑...
# 1    Home values in 84115 have risen 5.3 % (↑) over...
# 2    Home values in Salt Lake City have risen 4.7 %...
# 3    Home values in Salt Lake City have risen 4.7 %...
# 4    Home values in Downtown Salt Lake City have ri...
# ..                                                 ...
# 227  Home values in Rose Park have risen 5.3 % (↑) ...
# 228  Home values in Greater Avenues have risen 5.3 ...
# 229  Home values in Yalecrest have risen 5.3 % (↑) ...
# 230  Home values in Bonneville Hills have risen 5.3...
# 231  Home values in Central City-Liberty Wells have...
#
#                                                    URL         HOA
# 0    https://www.zillow.com/homedetails/2599-S-700-...         NaN
# 1    https://www.zillow.com/homedetails/20-W-Layton...         NaN
# 2    https://www.zillow.com/homedetails/415-E-600-S...         NaN
# 3    https://www.zillow.com/homedetails/427-E-Sego-...         NaN
# 4    https://www.zillow.com/homedetails/48-W-300-S-...  $51,376/mo
# ..                                                 ...         ...
# 227  https://www.zillow.com/homedetails/786-N-Sonat...         NaN
# 228  https://www.zillow.com/homedetails/720-E-5th-A...     $275/mo
# 229  https://www.zillow.com/homedetails/1875-E-900-...         NaN
# 230  https://www.zillow.com/homedetails/1506-S-2100...         NaN
# 231  https://www.zillow.com/homedetails/138-E-Harva...         NaN
#
# [232 rows x 18 columns]

# %%
df.drop(columns=['sqft'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-84870fed7cdc> in <module>
# ----> 1 df.drop(columns=['sqft'], inplace=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4165             level=level,
#    4166             inplace=inplace,
# -> 4167             errors=errors,
#    4168         )
#    4169
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3910                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3911             else:
# -> 3912                 new_axis = axis.drop(labels, errors=errors)
#    3913             result = self.reindex(**{axis_name: new_axis})
#    3914
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5274         if mask.any():
#    5275             if errors != "ignore":
# -> 5276                 raise KeyError(f"{labels[mask]} not found in axis")
#    5277             indexer = indexer[~mask]
#    5278         return self.delete(indexer)
#
# KeyError: "['sqft'] not found in axis"

# %%
df.columns.to_list()
# Out:
# ['Type',
#  'Year built',
#  'Heating',
#  'Cooling',
#  'Parking',
#  'Lot',
#  'Price/sqft',
#  'Total Price',
#  'Address',
#  'Square Feet',
#  'New construction',
#  'Bedrooms',
#  'Bathrooms',
#  'Full bathrooms',
#  'Half bathrooms',
#  'neighborhood_stats',
#  'URL',
#  'HOA']

# %%
df.Address
# Out:
# 0              2599 S 700 E, Salt Lake City, UT 84106
# 1           20 W Layton Ave, Salt Lake City, UT 84115
# 2               415 E 600 S, Salt Lake City, UT 84111
# 3            427 E Sego Ave, Salt Lake City, UT 84111
# 4       48 W 300 S APT 406N, Salt Lake City, UT 84101
#                             ...
# 227         786 N Sonata St, Salt Lake City, UT 84116
# 228    720 E 5th Ave APT 10, Salt Lake City, UT 84103
# 229            1875 E 900 S, Salt Lake City, UT 84108
# 230           1506 S 2100 E, Salt Lake City, UT 84108
# 231       138 E Harvard Ave, Salt Lake City, UT 84111
# Name: Address, Length: 232, dtype: object

# %%
df.to_csv('salt_lake_raw.csv')
