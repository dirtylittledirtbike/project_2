# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time, os
import numpy as np
import requests
import re
import random

# %%
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
def get_property_urls(link):
    # omg thank god for some dude on github for this req_header 0 CAPTCHAS i owe you my life
    
    req_headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-US,en;q=0.8',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
    }


    r = requests.get(link, headers=req_headers)
    soup = BeautifulSoup(r.content, 'html.parser')

    table = soup.find('ul', class_='photo-cards photo-cards_wow photo-cards_short')
    li_tags = table.find_all('li')
    properties = [item.find('div', class_='list-card-info')for item in li_tags]

    property_urls = []

    for item in properties:
        if item != None:
            property_extensions = item.find('a')['href']
            property_urls.append(property_extensions)
            
    return property_urls

# %%
def get_property_features(link):
    
    """
    Description: Grab all features from a listings URL (HOMES FOR SALE)
    Parameters: Link to listing (str)
    Return: all features from that properties url (dict)
    """
    
    try:
    
        req_headers = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'en-US,en;q=0.8',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
        }

        r = requests.get(link, headers=req_headers)
        soup = BeautifulSoup(r.content, 'html.parser')
        facts_and_features_table = soup.find('div', class_='ds-home-facts-and-features reso-facts-features sheety-facts-features')

        # this is the code for extracting features our of the home fact list table
        # creating a features list variable that we will append each scraped feature to
        # I'm deciding to do this so we can pull all the data in a particular table 
        # all at once and just use their entries for our column names
        
        all_features = facts_and_features_table.find_all('li', class_='ds-home-fact-list-item')
        features_list = [item.text.split(':') for item in all_features]
        address = soup.find('h1', class_='ds-address-container').text.replace(',\xa0', ', ')
        price = soup.find('div', class_='ds-home-details-chip').find('span', class_='ds-value').text
        summary_info = soup.find_all('span', class_='ds-bed-bath-living-area')

        # getting the third element in summnary info which is square feet and then splitting/
        # reversing it so its formatted as ['Square Feet', '728'] and not ['728', 'square feet']
        for item in summary_info:
            if 'sqft' in item.text.lower() or 'square feet' in item.text.lower():
                sqft = item.text.split(" ", 1)[::-1]
            else:
                sqft = np.nan

        # trying neighborhood stats in new way if this doesnt work uncomment code above
        if soup.find(text = 'Neighborhood stats')!=None:
            neighborhood_stats_formatted = soup.find(text = 'Neighborhood stats').next_element.get_text()
        else:
            neighborhood_stats_formatted = np.nan

        # finding if building was recently constructed or renovated from construction details
        # table 
        construction_details = soup.find_all('span', class_='Text-aiai24-0 cZksOw')
        for item in construction_details:
            if 'new construction' in item.text.lower():
                construction = item.text.split(':')

        features_list.append(['Total Price', price])
        features_list.append(['Address', address])
        features_list.append(sqft)
        features_list.append(construction)

        # this is code for extracting number of bedroom/baths from a separate div
        # then formatting it to match our features from the first table and appending
        # to feature list
        beds_baths = soup.find(text='Bedrooms and bathrooms').next_element.text
        beds_baths = re.split('(\d+)',beds_baths.replace('1/2', 'Half'))[:-1]
        bed_baths_formatted = [i+j for i,j in zip(beds_baths[::2], beds_baths[1::2])]

        for item in bed_baths_formatted:
            features_list.append(item.split(':'))

        features_list.append(['neighborhood_stats', neighborhood_stats_formatted])
        features_list.append(['URL', link])
        
        print(features_list)
        return dict(features_list)
    except:
        return None

# %%
def get_property_features_sold(link):
    
    """
    Description: Grab all features from a listings URL (HOMES SOLD)
    Parameters: Link to listing (str)
    Return: all features from that properties url (dict)
    """
        
    try:
    
        req_headers = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'en-US,en;q=0.8',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
        }


        r = requests.get(link, headers=req_headers)
        soup = BeautifulSoup(r.content, 'html.parser')
        facts_and_features_table = soup.find('div', class_='ds-home-facts-and-features reso-facts-features sheety-facts-features')


        # this is the code for extracting features our of the home fact list table
        all_features = facts_and_features_table.find_all('li', class_='ds-home-fact-list-item')
        features_list = [item.text.split(':') for item in all_features]
        address = soup.find('h1', class_='ds-address-container').text.replace(',\xa0', ', ')
        price = soup.find('span', class_='sc-pscky hEQFyS ds-status-details').get_text().lower().split(':')
        
        # so zillow has homes sold filter but people flip properties very quickly i guess
        # anyway we dont want to grab duplicates homes from when we looked at only for sale homes
        # so im creating this condition to make sure the status bar for the home says "Sold"
        
        if 'sold' in price:

            summary_info = soup.find_all('span', class_='ds-bed-bath-living-area')

            # getting the third element in summnary info which is square feet and then splitting/
            # reversing it so its formatted as ['Square Feet', '728'] and not ['728', 'square feet']
            for item in summary_info:
                if 'sqft' in item.text.lower() or 'square feet' in item.text.lower():
                    sqft = item.text.split(" ", 1)[::-1]
                else:
                    sqft = np.nan

            # getting all text out of neighborhoods stats about market trends 
            neighborhood_stats_formatted = soup.find(text = 'Neighborhood stats').next_element.get_text()

            # finding if building was recently constructed or renovated from construction details
            construction_details = soup.find_all('span', class_='Text-aiai24-0 cZksOw')
            for item in construction_details:
                if 'new construction' in item.text.lower():
                    construction = item.text.split(':')

            features_list.append(['Total Price', price[1]])
            features_list.append(['Address', address])
            features_list.append(sqft)
            features_list.append(construction)

            # this is code for extracting number of bedroom/baths from a separate div
            # then formatting it to match our features from the first table and appending
            # to feature list
            beds_baths = soup.find(text='Bedrooms and bathrooms').next_element.text
            beds_baths = re.split('(\d+)',beds_baths.replace('1/2', 'Half'))[:-1]
            bed_baths_formatted = [i+j for i,j in zip(beds_baths[::2], beds_baths[1::2])]

            for item in bed_baths_formatted:
                features_list.append(item.split(':'))

            features_list.append(['neighborhood_stats', neighborhood_stats_formatted])
            features_list.append(['URL', link])

            print(features_list)
            return dict(features_list)
        else:
            # if the status isnt listed as sold just skip this property
            # we dont want to wind up with a bunch of rentals that we cant scrape
            # or duplicates of properties we already scraped when filtering by
            # homes for sale
            pass
    except:
        return None

# %%
def generate_page_urls(location, num_pages, sold=False):
    """
    Description: get urls for first 20 pages for a location
    Parameter 1: location (str): e.g. 'chicago-il'
    Parameter 2: status (str): 'sold' or 'for_sale'
    
    Return: first 20 page urls (list)
    """
    
    if sold:
        base_url = 'https://www.zillow.com/{}/sold/'.format(location)
    else:
        base_url = 'https://www.zillow.com/homes/{}/'.format(location)
    
    first_20_pages_ext = [base_url + str(i) + '_p' for i in range(2,num_pages+1)]
    # as ganesh pointed out im not adding url for first page so im appending it here...
    first_20_pages_ext.append(base_url)
    return first_20_pages_ext

# %%
def get_all_property_urls(first_20_pages_ext):
    
    """
    Description: Get all the property urls for each page on Zillow
    Parameters: first 20 pages of urls (list)
    Return: urls for every property on each of the 20 pages
    """
    
    all_pages_property_urls = []
    for link in first_20_pages_ext:
        all_pages_property_urls.append(get_property_urls(link))

    # so right now i have a list of list and i want to flatten it for convenience
#     all_urls = all_pages_property_urls
    all_urls = [item for sublist in all_pages_property_urls for item in sublist]
    return all_urls

# %%
# cicero-il, oak-lawn-il salt-lake-city-ut  park-city-ut_ park-city-utah_rb, salt-lake-city-utah_rb pg 12
# first_20_pages_ext = generate_page_urls('salt-lake-city-utah_rb', sold=False, num_pages=12)
# all_urls = get_all_property_urls(first_20_pages_ext)

# %%
# this was for scraping salt lake city properties
base_url = 'https://www.zillow.com/homes/for_sale/{}_p/?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A{}%7D%2C%22mapBounds%22%3A%7B%22west%22%3A-112.10312421096398%2C%22east%22%3A-111.6753440595968%2C%22south%22%3A40.40958924644605%2C%22north%22%3A40.766255803886914%7D%2C%22mapZoom%22%3A11%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%7D%2C%22isListVisible%22%3Atrue%7D'

first_20_pages_ext = []
for i in range(2,21):
    base_url = 'https://www.zillow.com/homes/for_sale/{}_p/?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A{}%7D%2C%22mapBounds%22%3A%7B%22west%22%3A-112.10312421096398%2C%22east%22%3A-111.6753440595968%2C%22south%22%3A40.40958924644605%2C%22north%22%3A40.766255803886914%7D%2C%22mapZoom%22%3A11%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%7D%2C%22isListVisible%22%3Atrue%7D'.format(i, i)
    first_20_pages_ext.append(base_url)

first_20_pages_ext.append('https://www.zillow.com/homes/for_sale/?searchQueryState=%7B%22usersSearchTerm%22%3Anull%2C%22mapBounds%22%3A%7B%22west%22%3A-112.10312421096398%2C%22east%22%3A-111.6753440595968%2C%22south%22%3A40.409589246446025%2C%22north%22%3A40.766255803886885%7D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A11%7D')
all_urls = get_all_property_urls(first_20_pages_ext)

# %%
len(all_urls)
# Out:
# 800

# %%
########################## testing area ##############################

# %%
# req_headers = {
#     'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
#     'accept-encoding': 'gzip, deflate, br',
#     'accept-language': 'en-US,en;q=0.8',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
# }

# link = 'https://www.zillow.com/homedetails/7701-N-Westhills-Trl-Park-City-UT-84098/68854701_zpid/'
# r = requests.get(link, headers=req_headers)
# soup = BeautifulSoup(r.content, 'html.parser')
# facts_and_features_table = soup.find('div', class_='ds-home-facts-and-features reso-facts-features sheety-facts-features')

# # this is the code for extracting features our of the home fact list table
# # creating a features list variable that we will append each scraped feature to
# # I'm deciding to do this so we can pull all the data in a particular table 
# # all at once and just use their entries for our column names

# all_features = facts_and_features_table.find_all('li', class_='ds-home-fact-list-item')
# features_list = [item.text.split(':') for item in all_features]
# address = soup.find('h1', class_='ds-address-container').text.replace(',\xa0', ', ')
# price = soup.find('div', class_='ds-home-details-chip').find('span', class_='ds-value').text
# summary_info = soup.find_all('span', class_='ds-bed-bath-living-area')

# # getting the third element in summnary info which is square feet and then splitting/
# # reversing it so its formatted as ['Square Feet', '728'] and not ['728', 'square feet']
# for item in summary_info:
#     if 'sqft' in item.text.lower() or 'square feet' in item.text.lower():
#         sqft = item.text.split(" ", 1)[::-1]
#     else:
#         sqft = np.nan

# # trying neighborhood stats in new way if this doesnt work uncomment code above
# if soup.find(text = 'Neighborhood stats')!=None:
#     neighborhood_stats_formatted = soup.find(text = 'Neighborhood stats').next_element.get_text()
# else:
#     neighborhood_stats_formatted = np.nan
# # finding if building was recently constructed or renovated from construction details
# # table 
# construction_details = soup.find_all('span', class_='Text-aiai24-0 cZksOw')
# for item in construction_details:
#     if 'new construction' in item.text.lower():
#         construction = item.text.split(':')

# features_list.append(['Total Price', price])
# features_list.append(['Address', address])
# features_list.append(sqft)
# features_list.append(construction)

# # this is code for extracting number of bedroom/baths from a separate div
# # then formatting it to match our features from the first table and appending
# # to feature list
# beds_baths = soup.find(text='Bedrooms and bathrooms').next_element.text
# beds_baths = re.split('(\d+)',beds_baths.replace('1/2', 'Half'))[:-1]
# bed_baths_formatted = [i+j for i,j in zip(beds_baths[::2], beds_baths[1::2])]

# for item in bed_baths_formatted:
#     features_list.append(item.split(':'))

# features_list.append(['neighborhood_stats', neighborhood_stats_formatted])
# features_list.append(['URL', link])

# print(features_list)

# %%
########################## testing end ##############################

# %%
# so this is where we are iterating over all the property links and calling our
# functions to scrape details from each url and return a dictionary of values
# also tracking when and on which links our functions failed to sucessfully scrape data
# so far bum links is usually only about 20 out of 800 so I'll live

data_list = []
bum_links = []
for link in all_urls:
    print(link)
    
    # change this to get property_features_sold if you want home info on properties
    # with the sold status... 
    data_raw = get_property_features(link)
    if data_raw != None:
        data_list.append(data_raw)
    else:
        # creating this so we can see what links didnt work and look into why later
        bum_links.append(link)
# Out:
# https://www.zillow.com/homedetails/1508-W-Elm-Hill-Cir-Taylorsville-UT-84123/12837489_zpid/
# [['Type', 'Single Family'], ['Year built', '1977'], ['Heating', 'Other'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '0.29 Acres'], ['Price/sqft', '$173'], ['Total Price', '$525,000'], ['Address', '1508 W Elm Hill Cir, Taylorsville, UT 84123'], ['Square Feet', '3,029'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84123 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84123 will increase 6% (↑) in the next year.This home is valued 46.9% higher (↑) than the median home in 84123.The median Zestimate® for this neighborhood is $357,346.'], ['URL', 'https://www.zillow.com/homedetails/1508-W-Elm-Hill-Cir-Taylorsville-UT-84123/12837489_zpid/']]
# https://www.zillow.com/homedetails/513-W-Aspen-Peak-Dr-South-Jordan-UT-84095/69225888_zpid/
# [['Type', 'Single Family'], ['Year built', '2011'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '5,227 sqft'], ['Price/sqft', '$196'], ['Total Price', '$598,900'], ['Address', '513 W Aspen Peak Dr, South Jordan, UT 84095'], ['Square Feet', '3,062'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in 84095 have risen 3.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84095 will increase 3.7% (↑) in the next year.This home is valued 15.1% higher (↑) than the median home in 84095.The median Zestimate® for this neighborhood is $520,177.'], ['URL', 'https://www.zillow.com/homedetails/513-W-Aspen-Peak-Dr-South-Jordan-UT-84095/69225888_zpid/']]
# https://www.zillow.com/homedetails/485-E-Henry-Day-Ct-Draper-UT-84020/12937659_zpid/
# [['Type', 'Single Family'], ['Year built', '1997'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '6,534 sqft'], ['Price/sqft', '$166'], ['Total Price', '$476,500'], ['Address', '485 E Henry Day Ct, Draper, UT 84020'], ['Square Feet', '2,873'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/485-E-Henry-Day-Ct-Draper-UT-84020/12937659_zpid/']]
# https://www.zillow.com/homedetails/250-S-Main-St-1-Alpine-UT-84004/2077536899_zpid/
# [['Type', 'Townhouse'], ['Year built', 'No Data'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '1,742 sqft'], ['Price/sqft', '$251'], ['Total Price', '$814,900'], ['Address', '250 S Main St #1, Alpine, UT 84004'], ['Square Feet', '3,248'], ['New construction', ' Yes'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/250-S-Main-St-1-Alpine-UT-84004/2077536899_zpid/']]
# https://www.zillow.com/homedetails/250-S-Main-St-25-Alpine-UT-84004/2077536901_zpid/
# [['Type', 'Townhouse'], ['Year built', 'No Data'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '1,742 sqft'], ['Price/sqft', '$266'], ['Total Price', '$864,900'], ['Address', '250 S Main St #25, Alpine, UT 84004'], ['Square Feet', '3,248'], ['New construction', ' Yes'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/250-S-Main-St-25-Alpine-UT-84004/2077536901_zpid/']]
# https://www.zillow.com/homedetails/250-S-Main-St-24-Alpine-UT-84004/2077536898_zpid/
# [['Type', 'Townhouse'], ['Year built', 'No Data'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '1,742 sqft'], ['Price/sqft', '$205'], ['Total Price', '$999,900'], ['Address', '250 S Main St #24, Alpine, UT 84004'], ['Square Feet', '4,889'], ['New construction', ' Yes'], ['Bedrooms', ' 3'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/250-S-Main-St-24-Alpine-UT-84004/2077536898_zpid/']]
# https://www.zillow.com/homedetails/250-S-Main-St-2-Alpine-UT-84004/2077536897_zpid/
# [['Type', 'Townhouse'], ['Year built', 'No Data'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '1,742 sqft'], ['Price/sqft', '$194'], ['Total Price', '$949,900'], ['Address', '250 S Main St #2, Alpine, UT 84004'], ['Square Feet', '4,889'], ['New construction', ' Yes'], ['Bedrooms', ' 3'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/250-S-Main-St-2-Alpine-UT-84004/2077536897_zpid/']]
# https://www.zillow.com/homedetails/4498-W-3060-S-West-Valley-UT-84120/12745888_zpid/
# [['Type', 'Townhouse'], ['Year built', '1996'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '1,306 sqft'], ['Price/sqft', '$183'], ['Total Price', '$220,000'], ['Address', '4498 W 3060 S, West Valley, UT 84120'], ['Square Feet', '1,200'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84120 have risen 5.8\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84120 will increase 5.7% (↑) in the next year.This home is valued 28.1% lower (↓) than the median home in 84120.The median Zestimate® for this neighborhood is $306,114.'], ['URL', 'https://www.zillow.com/homedetails/4498-W-3060-S-West-Valley-UT-84120/12745888_zpid/']]
# https://www.zillow.com/homedetails/3298-E-Antler-Way-S-Salt-Lake-City-UT-84121/2077537464_zpid/
# [['Type', 'Single Family'], ['Year built', '1976'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '3 spaces'], ['Lot', '0.33 Acres'], ['Price/sqft', '$277'], ['Total Price', '$515,000'], ['Address', '3298 E Antler Way S, Salt Lake City, UT 84121'], ['Square Feet', '1,860'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/3298-E-Antler-Way-S-Salt-Lake-City-UT-84121/2077537464_zpid/']]
# https://www.zillow.com/homedetails/9949-S-Electra-Ln-Sandy-UT-84094/12916027_zpid/
# [['Type', 'Single Family'], ['Year built', '1985'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central, Evaporative'], ['Parking', '2 spaces'], ['Lot', '9,147 sqft'], ['Price/sqft', '$182'], ['Total Price', '$435,000'], ['Address', '9949 S Electra Ln, Sandy, UT 84094'], ['Square Feet', '2,393'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84094 have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84094 will rise 4.4% (↑) in the next year.This home is valued 18.4% higher (↑) than the median home in 84094.The median Zestimate® for this neighborhood is $367,478.'], ['URL', 'https://www.zillow.com/homedetails/9949-S-Electra-Ln-Sandy-UT-84094/12916027_zpid/']]
# https://www.zillow.com/homedetails/4787-W-Arno-Ct-West-Jordan-UT-84084/12834102_zpid/
# [['Type', 'Townhouse'], ['Year built', '1999'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Lot', '435 sqft'], ['Price/sqft', '$183'], ['Total Price', '$264,900'], ['Address', '4787 W Arno Ct, West Jordan, UT 84084'], ['Square Feet', '1,450'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84084 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84084 will rise 5.5% (↑) in the next year.This home is valued 22.6% lower (↓) than the median home in 84084.The median Zestimate® for this neighborhood is $342,321.'], ['URL', 'https://www.zillow.com/homedetails/4787-W-Arno-Ct-West-Jordan-UT-84084/12834102_zpid/']]
# https://www.zillow.com/homedetails/6481-S-Fernbrook-Dr-Taylorsville-UT-84129/12834746_zpid/
# [['Type', 'Single Family'], ['Year built', '1984'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '6,969 sqft'], ['Price/sqft', '$205'], ['Total Price', '$349,900'], ['Address', '6481 S Fernbrook Dr, Taylorsville, UT 84129'], ['Square Feet', '1,704'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84129 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84129 will rise 5.7% (↑) in the next year.This home is valued 7.2% higher (↑) than the median home in 84129.The median Zestimate® for this neighborhood is $326,516.'], ['URL', 'https://www.zillow.com/homedetails/6481-S-Fernbrook-Dr-Taylorsville-UT-84129/12834746_zpid/']]
# https://www.zillow.com/homedetails/4956-S-5415-W-Salt-Lake-City-UT-84118/12800481_zpid/
# [['Type', 'Single Family'], ['Year built', '1981'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '1 space'], ['Lot', '6,098 sqft'], ['Price/sqft', '$178'], ['Total Price', '$320,000'], ['Address', '4956 S 5415 W, Salt Lake City, UT 84118'], ['Square Feet', '1,800'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84118 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84118 will rise 5.2% (↑) in the next year.This home is valued 9.9% higher (↑) than the median home in 84118.The median Zestimate® for this neighborhood is $291,158.'], ['URL', 'https://www.zillow.com/homedetails/4956-S-5415-W-Salt-Lake-City-UT-84118/12800481_zpid/']]
# https://www.zillow.com/homedetails/2960-S-Putnam-Dr-West-Valley-UT-84128/12724152_zpid/
# [['Type', 'Single Family'], ['Year built', '1986'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '6,969 sqft'], ['Price/sqft', '$243'], ['Total Price', '$330,000'], ['Address', '2960 S Putnam Dr, West Valley, UT 84128'], ['Square Feet', '1,360'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84128 have risen 5.8\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84128 will rise 6.4% (↑) in the next year.This home is valued 2.2% higher (↑) than the median home in 84128.The median Zestimate® for this neighborhood is $322,819.'], ['URL', 'https://www.zillow.com/homedetails/2960-S-Putnam-Dr-West-Valley-UT-84128/12724152_zpid/']]
# https://www.zillow.com/homedetails/8585-S-Top-Of-The-World-Cir-Cottonwood-Heights-UT-84121/12888304_zpid/
# [['Type', 'Single Family'], ['Year built', '1971'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '0.29 Acres'], ['Price/sqft', '$261'], ['Total Price', '$675,000'], ['Address', '8585 S Top Of The World Cir, Cottonwood Heights, UT 84121'], ['Square Feet', '2,589'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/8585-S-Top-Of-The-World-Cir-Cottonwood-Heights-UT-84121/12888304_zpid/']]
# https://www.zillow.com/homedetails/350-S-200-E-UNIT-703-Salt-Lake-City-UT-84111/89425648_zpid/
# [['Type', 'Condo'], ['Year built', '2008'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['HOA', '$385/mo'], ['Price/sqft', '$432'], ['Total Price', '$439,900'], ['Address', '350 S 200 E UNIT 703, Salt Lake City, UT 84111'], ['Square Feet', '1,018'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Salt Lake City have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in Central City will increase 5.3% (↑) in the next year.This home is valued 4.7% higher (↑) than the median home in Central City.The median Zestimate® for this neighborhood is $419,987.'], ['URL', 'https://www.zillow.com/homedetails/350-S-200-E-UNIT-703-Salt-Lake-City-UT-84111/89425648_zpid/']]
# https://www.zillow.com/homedetails/5388-W-5150-S-Salt-Lake-City-UT-84118/12801151_zpid/
# [['Type', 'Single Family'], ['Year built', '1976'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.27 Acres'], ['Price/sqft', '$175'], ['Total Price', '$340,000'], ['Address', '5388 W 5150 S, Salt Lake City, UT 84118'], ['Square Feet', '1,938'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84118 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84118 will rise 5.2% (↑) in the next year.This home is valued 16.8% higher (↑) than the median home in 84118.The median Zestimate® for this neighborhood is $291,158.'], ['URL', 'https://www.zillow.com/homedetails/5388-W-5150-S-Salt-Lake-City-UT-84118/12801151_zpid/']]
# https://www.zillow.com/homedetails/12882-S-Kale-Ln-Riverton-UT-84065/72626459_zpid/
# [['Type', 'Single Family'], ['Year built', '2006'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '3 spaces'], ['Lot', '0.33 Acres'], ['Price/sqft', '$106'], ['Total Price', '$655,000'], ['Address', '12882 S Kale Ln, Riverton, UT 84065'], ['Square Feet', '6,160'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Riverton have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84065 will rise 4.1% (↑) in the next year.This home is valued 52.2% higher (↑) than the median home in 84065.The median Zestimate® for this neighborhood is $430,414.'], ['URL', 'https://www.zillow.com/homedetails/12882-S-Kale-Ln-Riverton-UT-84065/72626459_zpid/']]
# https://www.zillow.com/homedetails/10261-S-Locksley-Rd-Sandy-UT-84092/12920743_zpid/
# [['Type', 'Single Family'], ['Year built', '1984'], ['Heating', 'Other'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '8,276 sqft'], ['Price/sqft', '$245'], ['Total Price', '$429,000'], ['Address', '10261 S Locksley Rd, Sandy, UT 84092'], ['Square Feet', '1,752'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84092 have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84092 will rise 4.4% (↑) in the next year.This home is valued 22.3% lower (↓) than the median home in 84092.The median Zestimate® for this neighborhood is $552,092.'], ['URL', 'https://www.zillow.com/homedetails/10261-S-Locksley-Rd-Sandy-UT-84092/12920743_zpid/']]
# https://www.zillow.com/homedetails/5555-W-Poacher-Cir-Salt-Lake-City-UT-84118/12802114_zpid/
# [['Type', 'Single Family'], ['Year built', '1979'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '6,969 sqft'], ['Price/sqft', '$192'], ['Total Price', '$319,900'], ['Address', '5555 W Poacher Cir, Salt Lake City, UT 84118'], ['Square Feet', '1,670'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84118 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84118 will increase 5.2% (↑) in the next year.This home is valued 9.9% higher (↑) than the median home in 84118.The median Zestimate® for this neighborhood is $291,158.'], ['URL', 'https://www.zillow.com/homedetails/5555-W-Poacher-Cir-Salt-Lake-City-UT-84118/12802114_zpid/']]
# https://www.zillow.com/homedetails/4358-S-5780-W-West-Valley-City-UT-84128/12799839_zpid/
# [['Type', 'Single Family'], ['Year built', '1988'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '6,969 sqft'], ['Price/sqft', '$161'], ['Total Price', '$389,900'], ['Address', '4358 S 5780 W, West Valley City, UT 84128'], ['Square Feet', '2,416'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84128 have risen 5.8\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84128 will increase 6.4% (↑) in the next year.This home is valued 20.8% higher (↑) than the median home in 84128.The median Zestimate® for this neighborhood is $322,819.'], ['URL', 'https://www.zillow.com/homedetails/4358-S-5780-W-West-Valley-City-UT-84128/12799839_zpid/']]
# https://www.zillow.com/homedetails/4327-W-5570-S-Salt-Lake-City-UT-84118/12831878_zpid/
# [['Type', 'Single Family'], ['Year built', '1950'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '6,969 sqft'], ['Price/sqft', '$239'], ['Total Price', '$259,000'], ['Address', '4327 W 5570 S, Salt Lake City, UT 84118'], ['Square Feet', '1,082'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84118 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Hoffman Heights will increase 5.2% (↑) in the next year.This home is valued 11% lower (↓) than the median home in Hoffman Heights.The median Zestimate® for this neighborhood is $291,158.'], ['URL', 'https://www.zillow.com/homedetails/4327-W-5570-S-Salt-Lake-City-UT-84118/12831878_zpid/']]
# https://www.zillow.com/homedetails/6146-S-Verness-Cv-Holladay-UT-84121/61169752_zpid/
# [['Type', 'Single Family'], ['Year built', '2007'], ['Heating', 'Forced air, Other, Gas'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '0.60 Acres'], ['Price/sqft', '$273'], ['Total Price', '$2,998,000'], ['Address', '6146 S Verness Cv, Holladay, UT 84121'], ['Square Feet', '11,000'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 10'], ['Full bathrooms', ' 6'], ['Half bathrooms', ' 4'], ['neighborhood_stats', 'Home values in Holladay have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84121 will increase 3.5% (↑) in the next year.This home is valued 430.3% higher (↑) than the median home in 84121.The median Zestimate® for this neighborhood is $565,370.'], ['URL', 'https://www.zillow.com/homedetails/6146-S-Verness-Cv-Holladay-UT-84121/61169752_zpid/']]
# https://www.zillow.com/homedetails/2969-S-Elizabeth-St-Salt-Lake-City-UT-84106/2077538800_zpid/
# [['Type', 'Single Family'], ['Year built', '1915'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['Lot', '6,534 sqft'], ['Price/sqft', '$165'], ['Total Price', '$529,000'], ['Address', '2969 S Elizabeth St, Salt Lake City, UT 84106'], ['Square Feet', '3,211'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will increase 4.5% (↑) in the next year.This home is valued 13% higher (↑) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/2969-S-Elizabeth-St-Salt-Lake-City-UT-84106/2077538800_zpid/']]
# https://www.zillow.com/homedetails/1174-E-3300-S-APT-314-Millcreek-UT-84106/65730051_zpid/
# [['Type', 'Condo'], ['Year built', '2003'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$226/mo'], ['Price/sqft', '$232'], ['Total Price', '$260,000'], ['Address', '1174 E 3300 S APT 314, Millcreek, UT 84106'], ['Square Feet', '1,121'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84106 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84106 will rise 4.4% (↑) in the next year.This home is valued 37.9% lower (↓) than the median home in 84106.The median Zestimate® for this neighborhood is $418,741.'], ['URL', 'https://www.zillow.com/homedetails/1174-E-3300-S-APT-314-Millcreek-UT-84106/65730051_zpid/']]
# https://www.zillow.com/homedetails/10217-S-Dimple-Ln-Sandy-UT-84092/2077539581_zpid/
# [['Type', 'Single Family'], ['Year built', '2005'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '4 spaces'], ['Lot', '0.71 Acres'], ['Price/sqft', '$172'], ['Total Price', '$850,000'], ['Address', '10217 S Dimple Ln, Sandy, UT 84092'], ['Square Feet', '4,943'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84092 have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84092 will increase 4.4% (↑) in the next year.This home is valued 54% higher (↑) than the median home in 84092.The median Zestimate® for this neighborhood is $552,092.'], ['URL', 'https://www.zillow.com/homedetails/10217-S-Dimple-Ln-Sandy-UT-84092/2077539581_zpid/']]
# https://www.zillow.com/homedetails/495-E-Creekside-Cir-APT-B-Salt-Lake-City-UT-84107/2077539579_zpid/
# [['Type', 'Condo'], ['Year built', '1970'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['HOA', '$168/mo'], ['Price/sqft', '$235'], ['Total Price', '$194,000'], ['Address', '495 E Creekside Cir APT B, Salt Lake City, UT 84107'], ['Square Feet', '826'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84107 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84107 will rise 6% (↑) in the next year.This home is valued 44.6% lower (↓) than the median home in 84107.The median Zestimate® for this neighborhood is $349,940.'], ['URL', 'https://www.zillow.com/homedetails/495-E-Creekside-Cir-APT-B-Salt-Lake-City-UT-84107/2077539579_zpid/']]
# https://www.zillow.com/homedetails/3318-W-Crestfield-Dr-West-Valley-UT-84119/12814746_zpid/
# [['Type', 'Single Family'], ['Year built', '1969'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '1 space'], ['Lot', '9,583 sqft'], ['Price/sqft', '$155'], ['Total Price', '$365,000'], ['Address', '3318 W Crestfield Dr, West Valley, UT 84119'], ['Square Feet', '2,352'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in 84119 have risen 5.8\u200a% (↑) over the past 12 months.Zillow predicts the home values in Blue Haven will increase 5.9% (↑) in the next year.This home is valued 24.3% higher (↑) than the median home in Blue Haven.The median Zestimate® for this neighborhood is $293,648.'], ['URL', 'https://www.zillow.com/homedetails/3318-W-Crestfield-Dr-West-Valley-UT-84119/12814746_zpid/']]
# https://www.zillow.com/homedetails/11069-S-Topview-Rd-South-Jordan-UT-84009/83813611_zpid/
# [['Type', 'Townhouse'], ['Year built', '2007'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '3,920 sqft'], ['Price/sqft', '$150'], ['Total Price', '$320,000'], ['Address', '11069 S Topview Rd, South Jordan, UT 84009'], ['Square Feet', '2,139'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84009 have risen 3.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84009 will increase 3.6% (↑) in the next year.This home is valued 25.4% lower (↓) than the median home in 84009.The median Zestimate® for this neighborhood is $428,858.'], ['URL', 'https://www.zillow.com/homedetails/11069-S-Topview-Rd-South-Jordan-UT-84009/83813611_zpid/']]
# https://www.zillow.com/community/toll-brothers-at-rosecrest-noria-collection/2078783544_zpid/
# [['Total Price', '$472,995'], ['Address', 'Lot #0171, Toll Brothers at Rosecrest - Noria Collection, Herriman, UT 84096'], ['sqft', '1,766'], ['New construction', ' Yes'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84096 have risen 3.4\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84096 will rise 3.6% (↑) in the next year.This home is valued 8% higher (↑) than the median home in 84096.The median Zestimate® for this neighborhood is $437,903.'], ['URL', 'https://www.zillow.com/community/toll-brothers-at-rosecrest-noria-collection/2078783544_zpid/']]
# https://www.zillow.com/homedetails/1494-S-1000-W-Salt-Lake-City-UT-84104/12740905_zpid/
# [['Type', 'Single Family'], ['Year built', '1875'], ['Heating', 'Other, Electric, Gas, Wood / Pellet'], ['Cooling', 'Geothermal'], ['Parking', 'No Data'], ['Lot', '1.16 Acres'], ['Price/sqft', '$4,017'], ['Total Price', '$9,400,000'], ['Address', '1494 S 1000 W, Salt Lake City, UT 84104'], ['Square Feet', '2,340'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Glendale have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Glendale will increase 7.8% (↑) in the next year.This home is valued 3315.1% higher (↑) than the median home in Glendale.The median Zestimate® for this neighborhood is $275,245.'], ['URL', 'https://www.zillow.com/homedetails/1494-S-1000-W-Salt-Lake-City-UT-84104/12740905_zpid/']]
# https://www.zillow.com/homedetails/2220-E-Murray-Holladay-Rd-APT-108-Holladay-UT-84117/12860547_zpid/
# [['Type', 'Condo'], ['Year built', '1964'], ['Heating', 'Heat pump, Other'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$220/mo'], ['Price/sqft', '$246'], ['Total Price', '$180,000'], ['Address', '2220 E Murray Holladay Rd APT 108, Holladay, UT 84117'], ['Square Feet', '731'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84117 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84117 will rise 3.4% (↑) in the next year.This home is valued 62.1% lower (↓) than the median home in 84117.The median Zestimate® for this neighborhood is $474,747.'], ['URL', 'https://www.zillow.com/homedetails/2220-E-Murray-Holladay-Rd-APT-108-Holladay-UT-84117/12860547_zpid/']]
# https://www.zillow.com/homedetails/8553-S-100-E-Sandy-UT-84070/12881733_zpid/
# [['Type', 'Single Family'], ['Year built', '1913'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '0.25 Acres'], ['Price/sqft', '$355'], ['Total Price', '$349,000'], ['Address', '8553 S 100 E, Sandy, UT 84070'], ['Square Feet', '984'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84070 have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84070 will rise 5.3% (↑) in the next year.This home is valued 1.7% lower (↓) than the median home in 84070.The median Zestimate® for this neighborhood is $355,188.'], ['URL', 'https://www.zillow.com/homedetails/8553-S-100-E-Sandy-UT-84070/12881733_zpid/']]
# https://www.zillow.com/homedetails/9858-S-Iverness-Cir-South-Jordan-UT-84009/12895161_zpid/
# [['Type', 'Single Family'], ['Year built', '1977'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.28 Acres'], ['Price/sqft', '$157'], ['Total Price', '$425,000'], ['Address', '9858 S Iverness Cir, South Jordan, UT 84009'], ['Square Feet', '2,703'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84009 have risen 3.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84009 will increase 3.6% (↑) in the next year.This home is valued 0.9% lower (↓) than the median home in 84009.The median Zestimate® for this neighborhood is $428,858.'], ['URL', 'https://www.zillow.com/homedetails/9858-S-Iverness-Cir-South-Jordan-UT-84009/12895161_zpid/']]
# https://www.zillow.com/homedetails/8770-W-3150-S-Magna-UT-84044/12727023_zpid/
# [['Type', 'Single Family'], ['Year built', '1952'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '7,840 sqft'], ['Price/sqft', '$163'], ['Total Price', '$315,000'], ['Address', '8770 W 3150 S, Magna, UT 84044'], ['Square Feet', '1,928'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84044 have risen 5.6\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84044 will increase 5.5% (↑) in the next year.This home is valued 11.9% higher (↑) than the median home in 84044.The median Zestimate® for this neighborhood is $281,589.'], ['URL', 'https://www.zillow.com/homedetails/8770-W-3150-S-Magna-UT-84044/12727023_zpid/']]
# https://www.zillow.com/homedetails/378-E-Harrison-Ave-Salt-Lake-City-UT-84115/12771623_zpid/
# [['Type', 'Single Family'], ['Year built', '1916'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Lot', '4,356 sqft'], ['Price/sqft', '$277'], ['Total Price', '$350,000'], ['Address', '378 E Harrison Ave, Salt Lake City, UT 84115'], ['Square Feet', '1,264'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Liberty Wells have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Liberty Wells will increase 5.9% (↑) in the next year.This home is valued 8.4% lower (↓) than the median home in Liberty Wells.The median Zestimate® for this neighborhood is $382,242.'], ['URL', 'https://www.zillow.com/homedetails/378-E-Harrison-Ave-Salt-Lake-City-UT-84115/12771623_zpid/']]
# https://www.zillow.com/homedetails/3136-S-2900-E-Salt-Lake-City-UT-84109/12780978_zpid/
# [['Type', 'Single Family'], ['Year built', '1949'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central, Evaporative'], ['Parking', '3 spaces'], ['Lot', '10,018 sqft'], ['Price/sqft', '$174'], ['Total Price', '$799,900'], ['Address', '3136 S 2900 E, Salt Lake City, UT 84109'], ['Square Feet', '4,594'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in Canyon Rim have risen 3.8\u200a% (↑) over the past 12 months.Zillow predicts the home values in Canyon Rim will increase 2.3% (↑) in the next year.This home is valued 66.1% higher (↑) than the median home in Canyon Rim.The median Zestimate® for this neighborhood is $481,438.'], ['URL', 'https://www.zillow.com/homedetails/3136-S-2900-E-Salt-Lake-City-UT-84109/12780978_zpid/']]
# https://www.zillow.com/homedetails/2807-S-Chadwick-St-E-Salt-Lake-City-UT-84106/2077541570_zpid/
# [['Type', 'Single Family'], ['Year built', '1922'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '1 space'], ['Lot', '7,405 sqft'], ['Price/sqft', '$350'], ['Total Price', '$565,000'], ['Address', '2807 S Chadwick St E, Salt Lake City, UT 84106'], ['Square Feet', '1,613'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will rise 4.5% (↑) in the next year.This home is valued 20.7% higher (↑) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/2807-S-Chadwick-St-E-Salt-Lake-City-UT-84106/2077541570_zpid/']]
# https://www.zillow.com/homedetails/4629-S-Quail-Vista-Cv-E-J-Salt-Lake-City-UT-84117/2077541577_zpid/
# [['Type', 'Condo'], ['Year built', '1978'], ['Heating', 'Forced air'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Price/sqft', '$250'], ['Total Price', '$169,900'], ['Address', '4629 S Quail Vista Cv E #J, Salt Lake City, UT 84117'], ['Square Feet', '680'], ['New construction', ' No'], ['Bedrooms', ' 1'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84117 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84117 will rise 3.4% (↑) in the next year.This home is valued 64.2% lower (↓) than the median home in 84117.The median Zestimate® for this neighborhood is $474,747.'], ['URL', 'https://www.zillow.com/homedetails/4629-S-Quail-Vista-Cv-E-J-Salt-Lake-City-UT-84117/2077541577_zpid/']]
# https://www.zillow.com/homedetails/1426-S-900-E-Salt-Lake-City-UT-84105/12769103_zpid/
# [['Type', 'Single Family'], ['Year built', '1919'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '6,098 sqft'], ['Price/sqft', '$331'], ['Total Price', '$949,900'], ['Address', '1426 S 900 E, Salt Lake City, UT 84105'], ['Square Feet', '2,872'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in East Central have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in East Central will rise 4.1% (↑) in the next year.This home is valued 100% higher (↑) than the median home in East Central.The median Zestimate® for this neighborhood is $475,000.'], ['URL', 'https://www.zillow.com/homedetails/1426-S-900-E-Salt-Lake-City-UT-84105/12769103_zpid/']]
# https://www.zillow.com/homedetails/102-E-7320-S-Midvale-UT-84047/65730465_zpid/
# [['Type', 'Townhouse'], ['Year built', '2005'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '1,306 sqft'], ['Price/sqft', '$164'], ['Total Price', '$330,000'], ['Address', '102 E 7320 S, Midvale, UT 84047'], ['Square Feet', '2,015'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['neighborhood_stats', 'Home values in 84047 have risen 4.5\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84047 will rise 4.8% (↑) in the next year.This home is valued 1% lower (↓) than the median home in 84047.The median Zestimate® for this neighborhood is $333,183.'], ['URL', 'https://www.zillow.com/homedetails/102-E-7320-S-Midvale-UT-84047/65730465_zpid/']]
# https://www.zillow.com/homedetails/6137-S-Oak-Knoll-Dr-8-Salt-Lake-City-UT-84121/2077541912_zpid/
# [['Type', 'Single Family'], ['Year built', '1987'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '3 spaces'], ['Lot', '0.31 Acres'], ['Price/sqft', '$294'], ['Total Price', '$1,400,000'], ['Address', '6137 S Oak Knoll Dr #8, Salt Lake City, UT 84121'], ['Square Feet', '4,756'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Murray have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84121 will increase 5.6% (↑) in the next year.This home is valued 272.9% higher (↑) than the median home in 84121.The median Zestimate® for this neighborhood is $375,448.'], ['URL', 'https://www.zillow.com/homedetails/6137-S-Oak-Knoll-Dr-8-Salt-Lake-City-UT-84121/2077541912_zpid/']]
# https://www.zillow.com/homedetails/10734-S-Topview-Rd-South-Jordan-UT-84009/89420920_zpid/
# [['Type', 'Condo'], ['Year built', '2008'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '1 space'], ['HOA', '$432/mo'], ['Price/sqft', '$195'], ['Total Price', '$230,000'], ['Address', '10734 S Topview Rd, South Jordan, UT 84009'], ['Square Feet', '1,181'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84009 have risen 3.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84009 will rise 3.6% (↑) in the next year.This home is valued 46.4% lower (↓) than the median home in 84009.The median Zestimate® for this neighborhood is $428,858.'], ['URL', 'https://www.zillow.com/homedetails/10734-S-Topview-Rd-South-Jordan-UT-84009/89420920_zpid/']]
# https://www.zillow.com/homedetails/7205-S-Macintosh-Ln-Cottonwood-Heights-UT-84121/12874965_zpid/
# [['Type', 'Single Family'], ['Year built', '1976'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '10,018 sqft'], ['Price/sqft', '$165'], ['Total Price', '$499,900'], ['Address', '7205 S Macintosh Ln, Cottonwood Heights, UT 84121'], ['Square Feet', '3,022'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/7205-S-Macintosh-Ln-Cottonwood-Heights-UT-84121/12874965_zpid/']]
# https://www.zillow.com/homedetails/3881-W-Ridgeview-Way-Taylorsville-UT-84129/12818628_zpid/
# [['Type', 'Single Family'], ['Year built', '1962'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '8,712 sqft'], ['Price/sqft', '$147'], ['Total Price', '$350,000'], ['Address', '3881 W Ridgeview Way, Taylorsville, UT 84129'], ['Square Feet', '2,376'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84129 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84129 will rise 5.7% (↑) in the next year.This home is valued 7.2% higher (↑) than the median home in 84129.The median Zestimate® for this neighborhood is $326,516.'], ['URL', 'https://www.zillow.com/homedetails/3881-W-Ridgeview-Way-Taylorsville-UT-84129/12818628_zpid/']]
# https://www.zillow.com/homedetails/1448-W-Countrywood-Ln-West-Jordan-UT-84088/12891570_zpid/
# [['Type', 'Single Family'], ['Year built', '1984'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '1 space'], ['Lot', '4,791 sqft'], ['Price/sqft', '$170'], ['Total Price', '$374,900'], ['Address', '1448 W Countrywood Ln, West Jordan, UT 84088'], ['Square Feet', '2,202'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in 84088 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84088 will increase 5.2% (↑) in the next year.This home is valued 1.1% lower (↓) than the median home in 84088.The median Zestimate® for this neighborhood is $378,893.'], ['URL', 'https://www.zillow.com/homedetails/1448-W-Countrywood-Ln-West-Jordan-UT-84088/12891570_zpid/']]
# https://www.zillow.com/homedetails/5191-W-Copeland-Dr-Herriman-UT-84096/2077542108_zpid/
# [['Type', 'Townhouse'], ['Year built', '2019'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '1,742 sqft'], ['Price/sqft', '$151'], ['Total Price', '$350,000'], ['Address', '5191 W Copeland Dr, Herriman, UT 84096'], ['Square Feet', '2,320'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84096 have risen 3.4\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84096 will rise 3.6% (↑) in the next year.This home is valued 20.1% lower (↓) than the median home in 84096.The median Zestimate® for this neighborhood is $437,903.'], ['URL', 'https://www.zillow.com/homedetails/5191-W-Copeland-Dr-Herriman-UT-84096/2077542108_zpid/']]
# https://www.zillow.com/homedetails/11047-S-Cadbury-Dr-South-Jordan-UT-84095/69225895_zpid/
# [['Type', 'Single Family'], ['Year built', '2006'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '7,840 sqft'], ['Price/sqft', '$141'], ['Total Price', '$525,000'], ['Address', '11047 S Cadbury Dr, South Jordan, UT 84095'], ['Square Feet', '3,729'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 33'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84095 have risen 3.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84095 will increase 3.7% (↑) in the next year.This home is valued 0.9% higher (↑) than the median home in 84095.The median Zestimate® for this neighborhood is $520,177.'], ['URL', 'https://www.zillow.com/homedetails/11047-S-Cadbury-Dr-South-Jordan-UT-84095/69225895_zpid/']]
# https://www.zillow.com/homedetails/4333-S-2900-E-Holladay-UT-84124/12850081_zpid/
# [['Type', 'Single Family'], ['Year built', '1957'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '8,276 sqft'], ['Price/sqft', '$184'], ['Total Price', '$445,000'], ['Address', '4333 S 2900 E, Holladay, UT 84124'], ['Square Feet', '2,416'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84124 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84124 will rise 3.3% (↑) in the next year.This home is valued 20% lower (↓) than the median home in 84124.The median Zestimate® for this neighborhood is $556,483.'], ['URL', 'https://www.zillow.com/homedetails/4333-S-2900-E-Holladay-UT-84124/12850081_zpid/']]
# https://www.zillow.com/homedetails/3853-W-8890-S-West-Jordan-UT-84088/12892617_zpid/
# [['Type', 'Single Family'], ['Year built', '1983'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '0.29 Acres'], ['Price/sqft', '$179'], ['Total Price', '$381,999'], ['Address', '3853 W 8890 S, West Jordan, UT 84088'], ['Square Feet', '2,132'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84088 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84088 will rise 5.2% (↑) in the next year.This home is valued 0.8% higher (↑) than the median home in 84088.The median Zestimate® for this neighborhood is $378,893.'], ['URL', 'https://www.zillow.com/homedetails/3853-W-8890-S-West-Jordan-UT-84088/12892617_zpid/']]
# https://www.zillow.com/homedetails/11003-S-Lake-Run-Rd-W-229-South-Jordan-UT-84009/2077542722_zpid/
# [['Type', 'Townhouse'], ['Year built', '2020'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '1,306 sqft'], ['Price/sqft', '$212'], ['Total Price', '$369,900'], ['Address', '11003 S Lake Run Rd W #229, South Jordan, UT 84009'], ['Square Feet', '1,741'], ['New construction', ' Yes'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84009 have risen 3.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84009 will increase 3.6% (↑) in the next year.This home is valued 13.7% lower (↓) than the median home in 84009.The median Zestimate® for this neighborhood is $428,858.'], ['URL', 'https://www.zillow.com/homedetails/11003-S-Lake-Run-Rd-W-229-South-Jordan-UT-84009/2077542722_zpid/']]
# https://www.zillow.com/homedetails/5759-S-Lakeside-Dr-Salt-Lake-City-UT-84121/12865225_zpid/
# [['Type', 'Single Family'], ['Year built', '1957'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Lot', '10,454 sqft'], ['Price/sqft', '$232'], ['Total Price', '$459,000'], ['Address', '5759 S Lakeside Dr, Salt Lake City, UT 84121'], ['Square Feet', '1,978'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Murray have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84121 will increase 5.6% (↑) in the next year.This home is valued 22.3% higher (↑) than the median home in 84121.The median Zestimate® for this neighborhood is $375,448.'], ['URL', 'https://www.zillow.com/homedetails/5759-S-Lakeside-Dr-Salt-Lake-City-UT-84121/12865225_zpid/']]
# https://www.zillow.com/homedetails/2786-E-Willow-Wick-Dr-Sandy-UT-84093/12907473_zpid/
# [['Type', 'Single Family'], ['Year built', '1976'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '10,454 sqft'], ['Price/sqft', '$222'], ['Total Price', '$519,000'], ['Address', '2786 E Willow Wick Dr, Sandy, UT 84093'], ['Square Feet', '2,334'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84093 have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84093 will rise 3.5% (↑) in the next year.This home is valued 2.9% higher (↑) than the median home in 84093.The median Zestimate® for this neighborhood is $504,212.'], ['URL', 'https://www.zillow.com/homedetails/2786-E-Willow-Wick-Dr-Sandy-UT-84093/12907473_zpid/']]
# https://www.zillow.com/homedetails/14311-S-Attleboro-Dr-Herriman-UT-84096/119547746_zpid/
# [['Type', 'Single Family'], ['Year built', '2013'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', '3 spaces'], ['Lot', '6,534 sqft'], ['Price/sqft', '$164'], ['Total Price', '$545,000'], ['Address', '14311 S Attleboro Dr, Herriman, UT 84096'], ['Square Feet', '3,323'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84096 have risen 3.4\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84096 will rise 3.6% (↑) in the next year.This home is valued 24.5% higher (↑) than the median home in 84096.The median Zestimate® for this neighborhood is $437,903.'], ['URL', 'https://www.zillow.com/homedetails/14311-S-Attleboro-Dr-Herriman-UT-84096/119547746_zpid/']]
# https://www.zillow.com/homedetails/2840-E-Willow-Creek-Dr-Sandy-UT-84093/12887521_zpid/
# [['Type', 'Single Family'], ['Year built', '1972'], ['Heating', 'Other, Gas'], ['Cooling', 'Central'], ['Parking', '4 spaces'], ['Lot', '0.29 Acres'], ['Price/sqft', '$209'], ['Total Price', '$900,000'], ['Address', '2840 E Willow Creek Dr, Sandy, UT 84093'], ['Square Feet', '4,298'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84093 have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84093 will rise 3.5% (↑) in the next year.This home is valued 78.5% higher (↑) than the median home in 84093.The median Zestimate® for this neighborhood is $504,212.'], ['URL', 'https://www.zillow.com/homedetails/2840-E-Willow-Creek-Dr-Sandy-UT-84093/12887521_zpid/']]
# https://www.zillow.com/homedetails/11017-S-Lake-Run-Rd-W-232-South-Jordan-UT-84009/2077543016_zpid/
# [['Type', 'Townhouse'], ['Year built', '2020'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '1,306 sqft'], ['Price/sqft', '$221'], ['Total Price', '$294,900'], ['Address', '11017 S Lake Run Rd W #232, South Jordan, UT 84009'], ['Square Feet', '1,332'], ['New construction', ' Yes'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84009 have risen 3.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84009 will rise 3.6% (↑) in the next year.This home is valued 31.2% lower (↓) than the median home in 84009.The median Zestimate® for this neighborhood is $428,858.'], ['URL', 'https://www.zillow.com/homedetails/11017-S-Lake-Run-Rd-W-232-South-Jordan-UT-84009/2077543016_zpid/']]
# https://www.zillow.com/homedetails/11011-S-Lake-Run-Rd-W-230-South-Jordan-UT-84009/2077543017_zpid/
# ...
# https://www.zillow.com/homedetails/1911-E-2100-S-Salt-Lake-City-UT-84106/12776819_zpid/
# [['Type', 'Single Family'], ['Year built', '1944'], ['Heating', 'Forced air, Other, Gas'], ['Cooling', 'Central'], ['Parking', '1 space'], ['Lot', '5,662 sqft'], ['Price/sqft', '$278'], ['Total Price', '$515,000'], ['Address', '1911 E 2100 S, Salt Lake City, UT 84106'], ['Square Feet', '1,850'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will increase 4.5% (↑) in the next year.This home is valued 10% higher (↑) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/1911-E-2100-S-Salt-Lake-City-UT-84106/12776819_zpid/']]
# https://www.zillow.com/homedetails/3298-E-Antler-Way-S-Salt-Lake-City-UT-84121/2077537464_zpid/
# [['Type', 'Single Family'], ['Year built', '1976'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '3 spaces'], ['Lot', '0.33 Acres'], ['Price/sqft', '$277'], ['Total Price', '$515,000'], ['Address', '3298 E Antler Way S, Salt Lake City, UT 84121'], ['Square Feet', '1,860'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/3298-E-Antler-Way-S-Salt-Lake-City-UT-84121/2077537464_zpid/']]
# https://www.zillow.com/homedetails/485-E-Henry-Day-Ct-Draper-UT-84020/12937659_zpid/
# [['Type', 'Single Family'], ['Year built', '1997'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '6,534 sqft'], ['Price/sqft', '$166'], ['Total Price', '$476,500'], ['Address', '485 E Henry Day Ct, Draper, UT 84020'], ['Square Feet', '2,873'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/485-E-Henry-Day-Ct-Draper-UT-84020/12937659_zpid/']]
# https://www.zillow.com/homedetails/8585-S-Top-Of-The-World-Cir-Cottonwood-Heights-UT-84121/12888304_zpid/
# [['Type', 'Single Family'], ['Year built', '1971'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '0.29 Acres'], ['Price/sqft', '$261'], ['Total Price', '$675,000'], ['Address', '8585 S Top Of The World Cir, Cottonwood Heights, UT 84121'], ['Square Feet', '2,589'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/8585-S-Top-Of-The-World-Cir-Cottonwood-Heights-UT-84121/12888304_zpid/']]
# https://www.zillow.com/homedetails/2327-S-600-E-Salt-Lake-City-UT-84106/12774305_zpid/
# [['Type', 'Single Family'], ['Year built', '1919'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', 'No Data'], ['Lot', '6,969 sqft'], ['Price/sqft', '$206'], ['Total Price', '$340,000'], ['Address', '2327 S 600 E, Salt Lake City, UT 84106'], ['Square Feet', '1,654'], ['New construction', ' No'], ['Bedrooms', ' 2'], ['Bathrooms', ' 1'], ['Full bathrooms', ' 1'], ['neighborhood_stats', 'Home values in Sugar House have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in Sugar House will rise 4.5% (↑) in the next year.This home is valued 27.4% lower (↓) than the median home in Sugar House.The median Zestimate® for this neighborhood is $468,204.'], ['URL', 'https://www.zillow.com/homedetails/2327-S-600-E-Salt-Lake-City-UT-84106/12774305_zpid/']]
# https://www.zillow.com/homedetails/5863-W-Vogue-Ct-S-Herriman-UT-84096/2077556144_zpid/
# [['Type', 'Single Family'], ['Year built', '2000'], ['Heating', 'Gas'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Lot', '0.31 Acres'], ['Price/sqft', '$150'], ['Total Price', '$390,000'], ['Address', '5863 W Vogue Ct S, Herriman, UT 84096'], ['Square Feet', '2,602'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84096 have risen 3.4\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84096 will rise 3.6% (↑) in the next year.This home is valued 10.9% lower (↓) than the median home in 84096.The median Zestimate® for this neighborhood is $437,903.'], ['URL', 'https://www.zillow.com/homedetails/5863-W-Vogue-Ct-S-Herriman-UT-84096/2077556144_zpid/']]
# https://www.zillow.com/homedetails/2952-W-Southpointe-Rd-South-Jordan-UT-84095/12896414_zpid/
# [['Type', 'Single Family'], ['Year built', '1994'], ['Heating', 'Other, Gas'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '0.34 Acres'], ['Price/sqft', '$162'], ['Total Price', '$530,000'], ['Address', '2952 W Southpointe Rd, South Jordan, UT 84095'], ['Square Feet', '3,280'], ['New construction', ' No'], ['Bedrooms', ' 7'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in 84095 have risen 3.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84095 will increase 3.7% (↑) in the next year.This home is valued 1.9% higher (↑) than the median home in 84095.The median Zestimate® for this neighborhood is $520,177.'], ['URL', 'https://www.zillow.com/homedetails/2952-W-Southpointe-Rd-South-Jordan-UT-84095/12896414_zpid/']]
# https://www.zillow.com/homedetails/3144-E-Banbury-Rd-Cottonwood-Heights-UT-84121/12874852_zpid/
# [['Type', 'Single Family'], ['Year built', '1985'], ['Heating', 'Other'], ['Cooling', 'None'], ['Parking', '2 spaces'], ['Lot', '0.57 Acres'], ['Price/sqft', '$199'], ['Total Price', '$549,000'], ['Address', '3144 E Banbury Rd, Cottonwood Heights, UT 84121'], ['Square Feet', '2,752'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 2'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/3144-E-Banbury-Rd-Cottonwood-Heights-UT-84121/12874852_zpid/']]
# https://www.zillow.com/homedetails/4516-W-11800-S-South-Jordan-UT-84009/69717683_zpid/
# [['Type', 'Townhouse'], ['Year built', '2005'], ['Heating', 'Other, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '3,484 sqft'], ['Price/sqft', '$142'], ['Total Price', '$309,900'], ['Address', '4516 W 11800 S, South Jordan, UT 84009'], ['Square Feet', '2,175'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84009 have risen 3.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84009 will increase 3.6% (↑) in the next year.This home is valued 27.7% lower (↓) than the median home in 84009.The median Zestimate® for this neighborhood is $428,858.'], ['URL', 'https://www.zillow.com/homedetails/4516-W-11800-S-South-Jordan-UT-84009/69717683_zpid/']]
# https://www.zillow.com/homedetails/11256-N-Shoreline-Dr-Highland-UT-84003/79764878_zpid/
# [['Type', 'Single Family'], ['Year built', '2006'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '3 spaces'], ['Lot', '8,712 sqft'], ['Price/sqft', '$178'], ['Total Price', '$765,000'], ['Address', '11256 N Shoreline Dr, Highland, UT 84003'], ['Square Feet', '4,295'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 5'], ['Full bathrooms', ' 4'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84003 have risen 5.5\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84003 will rise 5.6% (↑) in the next year.This home is valued 72.8% higher (↑) than the median home in 84003.The median Zestimate® for this neighborhood is $442,706.'], ['URL', 'https://www.zillow.com/homedetails/11256-N-Shoreline-Dr-Highland-UT-84003/79764878_zpid/']]
# https://www.zillow.com/homedetails/13281-S-Cedar-Park-Dr-Herriman-UT-84096/83825752_zpid/
# [['Type', 'Multiple Occupancy'], ['Year built', '2004'], ['Heating', 'Forced air'], ['Cooling', 'Other'], ['Parking', '2 spaces'], ['Price/sqft', '$134'], ['Total Price', '$325,000'], ['Address', '13281 S Cedar Park Dr, Herriman, UT 84096'], ['Square Feet', '2,433'], ['New construction', ' No'], ['Bedrooms', ' 3'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 2'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84096 have risen 3.4\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84096 will rise 3.6% (↑) in the next year.This home is valued 25.8% lower (↓) than the median home in 84096.The median Zestimate® for this neighborhood is $437,903.'], ['URL', 'https://www.zillow.com/homedetails/13281-S-Cedar-Park-Dr-Herriman-UT-84096/83825752_zpid/']]
# https://www.zillow.com/homedetails/4921-S-3655-W-Taylorsville-UT-84129/12818732_zpid/
# [['Type', 'Single Family'], ['Year built', '1974'], ['Heating', 'Forced air'], ['Cooling', 'None'], ['Parking', 'No Data'], ['Lot', '10,454 sqft'], ['Price/sqft', '$159'], ['Total Price', '$380,000'], ['Address', '4921 S 3655 W, Taylorsville, UT 84129'], ['Square Feet', '2,392'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84129 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84129 will increase 5.7% (↑) in the next year.This home is valued 16.4% higher (↑) than the median home in 84129.The median Zestimate® for this neighborhood is $326,516.'], ['URL', 'https://www.zillow.com/homedetails/4921-S-3655-W-Taylorsville-UT-84129/12818732_zpid/']]
# https://www.zillow.com/homedetails/481-E-Parowan-Way-Draper-UT-84020/12937926_zpid/
# [['Type', 'Single Family'], ['Year built', '1996'], ['Heating', 'Other'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '7,840 sqft'], ['Price/sqft', '$191'], ['Total Price', '$569,900'], ['Address', '481 E Parowan Way, Draper, UT 84020'], ['Square Feet', '2,978'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/481-E-Parowan-Way-Draper-UT-84020/12937926_zpid/']]
# https://www.zillow.com/homedetails/4176-S-Morris-St-Taylorsville-UT-84129/12810266_zpid/
# [['Type', 'Single Family'], ['Year built', '1962'], ['Heating', 'Other'], ['Cooling', 'No Data'], ['Parking', '2 spaces'], ['Lot', '8,276 sqft'], ['Price/sqft', '$174'], ['Total Price', '$340,000'], ['Address', '4176 S Morris St, Taylorsville, UT 84129'], ['Square Feet', '1,955'], ['New construction', ' No'], ['Bedrooms', ' 5'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 13'], ['/4'], [' bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84129 have risen 5.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84129 will increase 5.7% (↑) in the next year.This home is valued 4.1% higher (↑) than the median home in 84129.The median Zestimate® for this neighborhood is $326,516.'], ['URL', 'https://www.zillow.com/homedetails/4176-S-Morris-St-Taylorsville-UT-84129/12810266_zpid/']]
# https://www.zillow.com/homedetails/3121-W-Davencourt-Loop-Lehi-UT-84043/50928578_zpid/
# [['Type', 'Townhouse'], ['Year built', '1999'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central'], ['Parking', '2 spaces'], ['Lot', '1,742 sqft'], ['Price/sqft', '$148'], ['Total Price', '$296,000'], ['Address', '3121 W Davencourt Loop, Lehi, UT 84043'], ['Square Feet', '2,003'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 3'], ['neighborhood_stats', 'Home values in 84043 have risen 4.9\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84043 will rise 4.9% (↑) in the next year.This home is valued 24.6% lower (↓) than the median home in 84043.The median Zestimate® for this neighborhood is $392,315.'], ['URL', 'https://www.zillow.com/homedetails/3121-W-Davencourt-Loop-Lehi-UT-84043/50928578_zpid/']]
# https://www.zillow.com/homedetails/581-E-9400-S-Sandy-UT-84070/12913480_zpid/
# [['Type', 'Single Family'], ['Year built', '1954'], ['Heating', 'Forced air, Gas'], ['Cooling', 'None'], ['Parking', '8 spaces'], ['Lot', '0.26 Acres'], ['Price/sqft', '$194'], ['Total Price', '$369,900'], ['Address', '581 E 9400 S, Sandy, UT 84070'], ['Square Feet', '1,908'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 2'], ['Full bathrooms', ' 2'], ['neighborhood_stats', 'Home values in 84070 have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84070 will increase 5.3% (↑) in the next year.This home is valued 4.1% higher (↑) than the median home in 84070.The median Zestimate® for this neighborhood is $355,188.'], ['URL', 'https://www.zillow.com/homedetails/581-E-9400-S-Sandy-UT-84070/12913480_zpid/']]
# https://www.zillow.com/homedetails/1577-W-Preserve-Ct-Riverton-UT-84065/2077533410_zpid/
# [['Type', 'Single Family'], ['Year built', '2019'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', '4 spaces'], ['Lot', '0.32 Acres'], ['Price/sqft', '$241'], ['Total Price', '$1,350,000'], ['Address', '1577 W Preserve Ct, Riverton, UT 84065'], ['Square Feet', '5,612'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/1577-W-Preserve-Ct-Riverton-UT-84065/2077533410_zpid/']]
# https://www.zillow.com/homedetails/9949-S-Electra-Ln-Sandy-UT-84094/12916027_zpid/
# [['Type', 'Single Family'], ['Year built', '1985'], ['Heating', 'Forced air, Gas'], ['Cooling', 'Central, Evaporative'], ['Parking', '2 spaces'], ['Lot', '9,147 sqft'], ['Price/sqft', '$182'], ['Total Price', '$435,000'], ['Address', '9949 S Electra Ln, Sandy, UT 84094'], ['Square Feet', '2,393'], ['New construction', ' No'], ['Bedrooms', ' 4'], ['Bathrooms', ' 3'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84094 have risen 4.7\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84094 will increase 4.4% (↑) in the next year.This home is valued 18.4% higher (↑) than the median home in 84094.The median Zestimate® for this neighborhood is $367,478.'], ['URL', 'https://www.zillow.com/homedetails/9949-S-Electra-Ln-Sandy-UT-84094/12916027_zpid/']]
# https://www.zillow.com/homedetails/221-E-Sierra-Ave-Alpine-UT-84004/2077581039_zpid/
# [['Type', 'Single Family'], ['Year built', '2000'], ['Heating', 'No Data'], ['Cooling', 'No Data'], ['Parking', 'No Data'], ['Lot', '0.46 Acres'], ['Price/sqft', '$183'], ['Total Price', '$824,999'], ['Address', '221 E Sierra Ave, Alpine, UT 84004'], ['Square Feet', '4,500'], ['New construction', ' No'], ['Bedrooms', ' 7'], ['Bathrooms', ' 4'], ['Full bathrooms', ' 3'], ['Half bathrooms', ' 1'], ['neighborhood_stats', nan], ['URL', 'https://www.zillow.com/homedetails/221-E-Sierra-Ave-Alpine-UT-84004/2077581039_zpid/']]
# https://www.zillow.com/homedetails/11137-S-Alta-Crest-Dr-South-Jordan-UT-84095/69225839_zpid/
# [['Type', 'Single Family'], ['Year built', '2006'], ['Heating', 'Forced air'], ['Cooling', 'Central'], ['Parking', 'No Data'], ['Lot', '0.26 Acres'], ['Price/sqft', '$144'], ['Total Price', '$689,000'], ['Address', '11137 S Alta Crest Dr, South Jordan, UT 84095'], ['Square Feet', '4,800'], ['New construction', ' No'], ['Bedrooms', ' 6'], ['Full bathrooms', ' 23'], ['/4'], [' bathrooms', ' 1'], ['Half bathrooms', ' 1'], ['neighborhood_stats', 'Home values in 84095 have risen 3.3\u200a% (↑) over the past 12 months.Zillow predicts the home values in 84095 will rise 3.7% (↑) in the next year.This home is valued 32.5% higher (↑) than the median home in 84095.The median Zestimate® for this neighborhood is $520,177.'], ['URL', 'https://www.zillow.com/homedetails/11137-S-Alta-Crest-Dr-South-Jordan-UT-84095/69225839_zpid/']]

# %%
# pd.DataFrame(data_list)
# Out:
#               Type Year built          Heating  Cooling   Parking  \
# 0    Single Family       1968  Forced air, Gas  Central  2 spaces
# 1    Single Family       1999  Forced air, Gas  Central  3 spaces
# 2            Condo       1989       Forced air  Central   1 space
# 3    Single Family       1915              Gas  No Data   1 space
# 4    Single Family       1986          No Data  No Data  2 spaces
# ..             ...        ...              ...      ...       ...
# 372  Single Family       1921        Baseboard  Central   1 space
# 373      Townhouse       2020          No Data  No Data  2 spaces
# 374  Single Family       2020          No Data  No Data  2 spaces
# 375  Single Family       2020       Forced air  Central  3 spaces
# 376  Single Family       2016              Gas  Central  3 spaces
#
#              Lot Price/sqft Total Price  \
# 0    10,018 sqft       $191    $470,000
# 1     0.29 Acres       $160    $529,900
# 2            NaN       $187    $214,500
# 3    10,018 sqft       $626    $349,900
# 4     0.35 Acres       $217    $739,900
# ..           ...        ...         ...
# 372   8,372 sqft       $222    $599,900
# 373      No Data       $226    $494,588
# 374      No Data       $160    $540,990
# 375      No Data       $305    $901,168
# 376   0.28 Acres       $188    $649,500
#
#                                                Address Square Feet  \
# 0        928 Royal Blackheath Ct, Naperville, IL 60563       2,464
# 1                1452 Chelsea Ln, Naperville, IL 60565       3,305
# 2           1292 Rhodes Ln #1292, Naperville, IL 60540       1,149
# 3           1131 N Washington St, Naperville, IL 60563         559
# 4                512 Braemar Ave, Naperville, IL 60563       3,406
# ..                                                 ...         ...
# 372            215 S Columbia St, Naperville, IL 60540       2,702
# 373  Buildable plan: Metro, Columbia Park Townes, N...         NaN
# 374  Buildable plan: Castleton, Wagner Farms, Naper...         NaN
# 375  Buildable plan: The Abbey, DJK Custom Homes of...         NaN
# 376            1503 Alderleaf Ct, Naperville, IL 60563       3,459
#
#     New construction Bedrooms Bathrooms Full bathrooms Half bathrooms  \
# 0                 No        4         3              2              1
# 1                 No        4         4              3              1
# 2                 No        2         2              2            NaN
# 3                 No        1         1              1            NaN
# 4                 No        5         5              4              1
# ..               ...      ...       ...            ...            ...
# 372               No        4         4              4            NaN
# 373              Yes        3         3              2              1
# 374              Yes        4         3              2              1
# 375              Yes        4         3              2              1
# 376               No        4         3              2              1
#
#                                     neighborhood_stats  \
# 0    Home values in 60563 have risen 1.0 % (↑) over...
# 1    Home values in 60565 have risen 1.0 % (↑) over...
# 2    Home values in 60540 have risen 1.0 % (↑) over...
# 3    Home values in 60563 have risen 1.0 % (↑) over...
# 4    Home values in 60563 have risen 1.0 % (↑) over...
# ..                                                 ...
# 372  Home values in 60540 have risen 1.0 % (↑) over...
# 373  Home values in 60563 have risen 1.0 % (↑) over...
# 374  Home values in 60564 have risen 1.0 % (↑) over...
# 375  Home values in 60540 have risen 1.0 % (↑) over...
# 376  Home values in 60563 have risen 1.0 % (↑) over...
#
#                                                    URL         HOA   sqft
# 0    https://www.zillow.com/homedetails/928-Royal-B...         NaN    NaN
# 1    https://www.zillow.com/homedetails/1452-Chelse...         NaN    NaN
# 2    https://www.zillow.com/homedetails/1292-Rhodes...  $238/month    NaN
# 3    https://www.zillow.com/homedetails/1131-N-Wash...         NaN    NaN
# 4    https://www.zillow.com/homedetails/512-Braemar...         NaN    NaN
# ..                                                 ...         ...    ...
# 372  https://www.zillow.com/homedetails/215-S-Colum...         NaN    NaN
# 373  https://www.zillow.com/community/columbia-park...         NaN  2,185
# 374  https://www.zillow.com/community/wagner-farms/...         NaN  3,391
# 375  https://www.zillow.com/community/djk-custom-ho...         NaN  2,959
# 376  https://www.zillow.com/homedetails/1503-Alderl...         NaN    NaN
#
# [377 rows x 19 columns]

# %%
# data_list
df = pd.DataFrame(data_list)
# df.to_csv('sold_raw.csv', header=True)
# df.groupby('URL').size()

# %%
df.drop(columns=['sqft'], inplace=True)

# %%
df.columns.to_list()
# Out:
# ['Type',
#  'Year built',
#  'Heating',
#  'Cooling',
#  'Parking',
#  'Lot',
#  'Price/sqft',
#  'Total Price',
#  'Address',
#  'Square Feet',
#  'New construction',
#  'Bedrooms',
#  'Bathrooms',
#  'Full bathrooms',
#  'neighborhood_stats',
#  'URL',
#  'Half bathrooms',
#  'HOA']

# %%
df.Address
# Out:
# 0      513 W Aspen Peak Dr, South Jordan, UT 84095
# 1             485 E Henry Day Ct, Draper, UT 84020
# 2               250 S Main St #1, Alpine, UT 84004
# 3              250 S Main St #25, Alpine, UT 84004
# 4              250 S Main St #24, Alpine, UT 84004
#                           ...
# 582            481 E Parowan Way, Draper, UT 84020
# 583         3121 W Davencourt Loop, Lehi, UT 84043
# 584                  581 E 9400 S, Sandy, UT 84070
# 585         1577 W Preserve Ct, Riverton, UT 84065
# 586             221 E Sierra Ave, Alpine, UT 84004
# Name: Address, Length: 587, dtype: object

# %%
len(bum_links)
# Out:
# 213

# %%
df
# Out:
#               Type Year built          Heating  Cooling   Parking         Lot  \
# 0    Single Family       2011            Other  Central  2 spaces  5,227 sqft
# 1    Single Family       1997  Forced air, Gas  Central   No Data  6,534 sqft
# 2        Townhouse    No Data          No Data  No Data  2 spaces  1,742 sqft
# 3        Townhouse    No Data          No Data  No Data  2 spaces  1,742 sqft
# 4        Townhouse    No Data          No Data  No Data  2 spaces  1,742 sqft
# ..             ...        ...              ...      ...       ...         ...
# 582  Single Family       1996            Other  Central   No Data  7,840 sqft
# 583      Townhouse       1999  Forced air, Gas  Central  2 spaces  1,742 sqft
# 584  Single Family       1954  Forced air, Gas     None  8 spaces  0.26 Acres
# 585  Single Family       2019          No Data  No Data  4 spaces  0.32 Acres
# 586  Single Family       2000          No Data  No Data   No Data  0.46 Acres
#
#     Price/sqft Total Price                                      Address  \
# 0         $196    $598,900  513 W Aspen Peak Dr, South Jordan, UT 84095
# 1         $166    $476,500         485 E Henry Day Ct, Draper, UT 84020
# 2         $251    $814,900           250 S Main St #1, Alpine, UT 84004
# 3         $266    $864,900          250 S Main St #25, Alpine, UT 84004
# 4         $205    $999,900          250 S Main St #24, Alpine, UT 84004
# ..         ...         ...                                          ...
# 582       $191    $569,900          481 E Parowan Way, Draper, UT 84020
# 583       $148    $296,000       3121 W Davencourt Loop, Lehi, UT 84043
# 584       $194    $369,900                581 E 9400 S, Sandy, UT 84070
# 585       $241  $1,350,000       1577 W Preserve Ct, Riverton, UT 84065
# 586       $183    $824,999           221 E Sierra Ave, Alpine, UT 84004
#
#     Square Feet New construction Bedrooms Bathrooms Full bathrooms  \
# 0         3,062               No        4         3              3
# 1         2,873               No        5       NaN            NaN
# 2         3,248              Yes        3         3              2
# 3         3,248              Yes        3         3              2
# 4         4,889              Yes        3         4              3
# ..          ...              ...      ...       ...            ...
# 582       2,978               No        5         4              3
# 583       2,003               No        4         3              3
# 584       1,908               No        4         2              2
# 585       5,612               No        6         4              3
# 586       4,500               No        7         4              3
#
#                                     neighborhood_stats  \
# 0    Home values in 84095 have risen 3.3 % (↑) over...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 582                                                NaN
# 583  Home values in 84043 have risen 4.9 % (↑) over...
# 584  Home values in 84070 have risen 4.7 % (↑) over...
# 585                                                NaN
# 586                                                NaN
#
#                                                    URL Half bathrooms  HOA
# 0    https://www.zillow.com/homedetails/513-W-Aspen...            NaN  NaN
# 1    https://www.zillow.com/homedetails/485-E-Henry...            NaN  NaN
# 2    https://www.zillow.com/homedetails/250-S-Main-...              1  NaN
# 3    https://www.zillow.com/homedetails/250-S-Main-...              1  NaN
# 4    https://www.zillow.com/homedetails/250-S-Main-...              1  NaN
# ..                                                 ...            ...  ...
# 582  https://www.zillow.com/homedetails/481-E-Parow...              1  NaN
# 583  https://www.zillow.com/homedetails/3121-W-Dave...            NaN  NaN
# 584  https://www.zillow.com/homedetails/581-E-9400-...            NaN  NaN
# 585  https://www.zillow.com/homedetails/1577-W-Pres...              1  NaN
# 586  https://www.zillow.com/homedetails/221-E-Sierr...              1  NaN
#
# [587 rows x 18 columns]

# %%
df.to_csv('salt_lake_raw.csv')
